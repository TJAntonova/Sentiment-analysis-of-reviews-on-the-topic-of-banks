# %% [markdown]
# # Метод, основанный на правилах и словарях

# %% [markdown]
# Для определения эмоциональной окраски была создана обучающая и тестовая выборка. На основе обучающей выборки будет создан тезаурус эмоционально окрашенной лексики. Отзывы обучающей выборки не присутствуют в тестовой.
#
# **Описание данных:**
#
# - _text_ - отзыв пользователя
# - _rated_ - оценка пользователя
# - _coloring_ - эмоциональная окраска (определена вручную на основе оценок)
# - _date_ - дата размещения отзыва
# - _bank_ - банк, о котором написан отзыв
# - _theme_ - тема обращения
# - _name_ - имя пользователя
# - _sex_ - пол пользователя (определен вручную на основе имени)
#
#
# **Обучающая выборка**
#
#     Исходный датафрейм содержит отзывы о банках с первых 100 страниц веб-сайта Сравни.ру. Размер корпуса - 4116 отзывов.
#     Для составления словарей были выбраны отзывы с оценками '1' и '2' - для негативно окрашенной лексики (1329 отзыва), '5' - для позитивно окрашенной лексики (1357 отзыва).
#
#
# **Тестовая выборка**
#
#     Для проведения анализа были собраны отзывы со страниц 130-160. Размер корпуса - 696 отзывов. Корпус содержит отзывы с оценками 1-5 и метаданные, описанные выше.
#
# **Ход исследования:**
#
# 1. [Импорт библиотек](#1)
# 2. [Чтение и обзор файлов](#2)
# 3. [Составление тональных словарей](#3)
# 4. [Анализ тональности](#4)
# 5. [Оценка работы алгоритма](#5)
# 6. [Обнаруженные закономерности](#6)
# 7. [Результаты](#7)

# %% [markdown]
# ## Импорт необходимых библиотек <a id="1"></a>

# %%
import pandas as pd
from pymorphy2 import MorphAnalyzer
from pymorphy2.tokenizers import simple_word_tokenize
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Чтение файлов <a id="2"></a>

# %% [markdown]
# Загрузим корпус для проведения будущего анализа.

# %%
df = pd.read_csv('/Users/js/Desktop/disser/testtt_corpus.csv')
df = df[df['text'].notna()]
df = df.sort_values(by='text')
df = df.drop(df.columns[[0]], axis = 1)

# %%
df.head(10)
# Out:
#                                                   text  rated coloring  \
# 243                        А где реквизиты то взять???      2      bad
# 266  А как стоило открыть в Вашем банке счет – так ...      2      bad
# 142  Банк Траст в июне 2014 году выдал справку о за...      1      bad
# 625  Банк всегда готов помочь клиентам в решение пр...      5     good
# 373  Банк нравится, готова и дальше сотрудничать. П...      5     good
# 54   Банк обещает "4 мили за каждые 100 рублей" при...      1      bad
# 213  Банк предложил мне кредит наличными на погашен...      1      bad
# 207  Банк предложил рефинансирование кредита под ма...      1      bad
# 163  Банк пройдоха еще тот, сейчас буду подавать в ...      1      bad
# 177  Банк соответствует своему названию - Совковый,...      1      bad
#
#               date        bank              theme     name     sex
# 243  12 нояб, 2014    zapadnyj  Кредиты наличными      Яна  female
# 266  30 сент, 2014        rnkb       Обслуживание   Ленара    unkn
# 142  08 нояб, 2017       trast  Кредиты наличными    Елена  female
# 625   02 апр, 2022  sovkombank             Вклады    Елена  female
# 373   05 апр, 2022  sovkombank            Ипотека   Альфия    unkn
# 54    01 мар, 2018         vtb    Дебетовые карты  Наталья  female
# 213   20 авг, 2017         vtb  Кредиты наличными    Елена  female
# 207   28 авг, 2017         vtb  Кредиты наличными  Дмитрий    male
# 163   17 окт, 2017         vtb            Ипотека     Инна  female
# 177   06 окт, 2017  sovkombank             Вклады      NaN    unkn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 696 entries, 243 to 42
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      696 non-null    object
#  1   rated     696 non-null    int64
#  2   coloring  696 non-null    object
#  3   date      696 non-null    object
#  4   bank      696 non-null    object
#  5   theme     693 non-null    object
#  6   name      639 non-null    object
#  7   sex       696 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 48.9+ KB

# %% [markdown]
# Корпус <b>отрицательных</b> отзывов:

# %%
df_neg = pd.read_csv('/Users/js/neg_corp.csv')
df_neg = df_neg.drop(df_neg.columns[[0]], axis = 1)

# %%
df_neg.head(10)
# Out:
#                                                 text  rated coloring  \
# 0  Возмутительный способ обмана придумали крючкот...      1      bad
# 1  Не храните в нем деньги, ни коем случае! У мен...      1      bad
# 2  С 09.03.22 не могу получить средства с евро сч...      1      bad
# 3  Очень долгое обслуживание, сотрудники совершен...      1      bad
# 4  Звоню третий день по вопросу валюты. Оператор ...      1      bad
# 5  Опыт сложился негативный, Сегодня 3марта 2022 ...      1      bad
# 6  и 01.03.2022 приложения не работают. в 23ч при...      1      bad
# 7  ОАО Газпромбанк офис г. Новосибирск ул. Богдан...      1      bad
# 8  Мы с мамой обратились 24.02.2022 в отделение Г...      1      bad
# 9  Омск. С 24.02.22 невозможно снять наличные ден...      1      bad
#
#             date                 name         bank     sex
# 0   04 апр, 2022               Сергей          vtb    male
# 1   30 мар, 2022              Альбина      uralsib  female
# 2   24 мар, 2022                Ирина      uralsib  female
# 3   14 мар, 2022            Александр  gazprombank    male
# 4   14 мар, 2022  Сергей Владимирович  gazprombank    unkn
# 5   03 мар, 2022                 Илья  gazprombank    male
# 6   01 мар, 2022               Марина  gazprombank  female
# 7   01 мар, 2022             Виктория  gazprombank  female
# 8  26 февр, 2022                алена  gazprombank    unkn
# 9  26 февр, 2022                 Олег  gazprombank    male

# %%
df_neg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1329 entries, 0 to 1328
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      1329 non-null   object
#  1   rated     1329 non-null   int64
#  2   coloring  1329 non-null   object
#  3   date      1329 non-null   object
#  4   name      1227 non-null   object
#  5   bank      1329 non-null   object
#  6   sex       1329 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 72.8+ KB

# %% [markdown]
# Корпус <b>положительных</b> отзывов:

# %%
df_pos = pd.read_csv('/Users/js/pos_corp.csv')
df_pos = df_pos.drop(df_pos.columns[[0]], axis = 1)

# %%
df_pos.head(10)
# Out:
#                                                 text  rated coloring  \
# 0  Недавно Газпромбанк обновил приложение, и это ...      5     good
# 1  Сменил работу и зарплатный банк соответственно...      5     good
# 2  В Газпромбанке я получаю пенсию по потере корм...      5     good
# 3  По совету сестры заказала себе дебетовую карту...      5     good
# 4  Доброго времени суток, рассказываю об автокред...      5     good
# 5  Устроилась на первую серьезную работу после ун...      5     good
# 6  Открыл ИП через Точка Банк в 2019г. При этом н...      5     good
# 7  Пол года назад я смог рефинансировать свою ипо...      5     good
# 8  Хочу выразить благодарность ГазПромБанку за ка...      5     good
# 9  Привет зарплатникам Газпромбанка! В приложении...      5     good
#
#            date        name         bank   sex
# 0  15 апр, 2022  Константин  gazprombank  male
# 1  14 апр, 2022        Глеб  gazprombank  male
# 2  14 апр, 2022         NaN  gazprombank  unkn
# 3  14 апр, 2022        Лили  gazprombank  unkn
# 4  14 апр, 2022         NaN  gazprombank  unkn
# 5  14 апр, 2022       Алена  gazprombank  unkn
# 6  13 апр, 2022       Антон       tochka  male
# 7  13 апр, 2022     Аркадий  gazprombank  male
# 8  13 апр, 2022         NaN  gazprombank  unkn
# 9  13 апр, 2022         NaN  gazprombank  unkn

# %%
df_pos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1357 entries, 0 to 1356
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      1357 non-null   object
#  1   rated     1357 non-null   int64
#  2   coloring  1357 non-null   object
#  3   date      1357 non-null   object
#  4   name      1301 non-null   object
#  5   bank      1357 non-null   object
#  6   sex       1357 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 74.3+ KB

# %% [markdown]
# ## Составление тональных словарей <a id="3"></a>

# %% [markdown]
# Определим части речи и коллокации, которые войдут в словарь:

# %%
# позитивно и негативно окрашенные прилагательные, существительные, глаголы и наречия
pos_adj = {} 
pos_noun = {}
pos_verb = {}
pos_adv = {}
neg_adj = {}
neg_noun = {}
neg_verb = {}
neg_adv = {}
# позитивно и негативно окрашенные коллокации
# прилагательное+существительное, наречие+глагол,
# глагол+существительное косвенного падежа, существительное именительного падежа+глагол
pos_adj_noun = {}
neg_adj_noun= {} 
pos_adv_verb= {} 
neg_adv_verb = {} 
pos_verb_noun = {}
neg_verb_noun= {}
pos_noun_verb = {}
neg_noun_verb = {}

# %% [markdown]
# Создадим списки слов и частоту их встречаемости по корпусу с помощью функций:

# %%
def word_list(corpus,tone):
    
    '''
    Списки отдельных слов. 
    
    Функция принимает на вход датафрейм и нужную тональность (+/-),
    токенизирует каждый отзыв датафрейма, для каждого слова отзыва проводит морфологический анализ,
    далее заполняет словари по тегу части речи.
   
    '''
    
    
    m = MorphAnalyzer()
   
    for comment in corpus:
        for w in simple_word_tokenize(comment):
            w = m.parse(w)[0]
            n = w.normal_form

            my_dict={}
            if 'ADJF' in w.tag:
                if tone=='-':
                    my_dict=neg_adj
                else:
                    my_dict=pos_adj

            if 'NOUN' in w.tag:
                if tone=='-':
                    my_dict=neg_noun
                else:
                    my_dict=pos_noun

            if 'VERB' in w.tag:
                if tone=='-':
                    my_dict=neg_verb
                else:
                    my_dict=pos_verb

            if 'ADVB' in w.tag:
                if tone=='-':
                    my_dict=neg_adv
                else:
                    my_dict=pos_adv

            if n not in my_dict:
                my_dict[n]=1
            else:
                my_dict[n]+=1

# %%
def colloc_list(corpus,tone):
    
    ''' 
    Списки коллокаций. 
    
    Функция принимает на вход датафрейм и нужную тональность (+/-),
    токенизирует каждый отзыв датафрейма, для каждого слова отзыва проводит морфологический анализ,
    далее заполняет словари по тегу части речи слова и тегу слова, следующего за ним.
   
    '''
    
    m = MorphAnalyzer()
    
    for comment in corpus:
        comment = simple_word_tokenize(comment)
        for i in range (0, len(comment)-2):
            w1 = comment[i]
            w2 = comment[i+1]
            w3 = comment[i+2]
            w1 = m.parse(w1)[0]
            n1 = w1.normal_form
            w2 = m.parse(w2)[0]
            n2 = w2.normal_form
            w3 = m.parse(w3)[0]
            
            my_dict={}
            
            if ('ADJF' in w1.tag and 'NOUN' in w2.tag) or ('ADJF' in w2.tag and 'NOUN' in w1.tag):
                if (w1.tag.gender == w2.tag.gender) and (w1.tag.number == w2.tag.number) and (w1.tag.case == w2.tag.case):
                    if tone=='-':
                        my_dict=neg_adj_noun
                    else:
                        my_dict=pos_adj_noun
                        
                    n = n1+' '+n2           
                    if n not in my_dict:
                        my_dict[n]=1
                    else:
                        my_dict[n]+=1 
                        
                        
            if ('ADVB' in w1.tag and 'VERB' in w2.tag) or ('ADVB' in w2.tag and 'VERB' in w1.tag):
                if tone=='-':
                    my_dict=neg_adv_verb
                else:
                    my_dict=pos_adv_verb
                    
                n = n1+' '+n2           
                if n not in my_dict:
                    my_dict[n]=1
                
                else:
                    my_dict[n]+=1 
                          
                
            if 'VERB' in w1.tag and 'PREP' in w2.tag and 'NOUN' in w3.tag:
                if tone=='-':
                    my_dict=neg_verb_noun
                else:
                    my_dict=pos_verb_noun
                    
                n = n1+' '+n2+' '+comment[i+2]         
                if n not in my_dict:
                    my_dict[n]=1
                else:
                    my_dict[n]+=1 
                    
                    
            if 'NOUN' in w1.tag and 'VERB' in w2.tag:
                if w1.tag.case == 'nomn':
                    if tone=='-':
                        my_dict=neg_noun_verb
                    else:
                        my_dict=pos_noun_verb
            
                    n = comment[i]+' '+comment[i+1]  
                    if n not in my_dict:
                        my_dict[n]=1
                
                    else:
                        my_dict[n]+=1

# %%
colloc_list(df_neg['text'],tone='-')

# %%
colloc_list(df_pos['text'],tone='+')

# %%
word_list(df_neg['text'],tone='-')

# %%
word_list(df_pos['text'],tone='+')

# %% [markdown]
# Создадим два общих списка коллокаций:

# %%
pos = {**pos_adj_noun,**pos_adv_verb,**pos_verb_noun,**pos_noun_verb}
neg = {**neg_adj_noun,**neg_adv_verb,**neg_verb_noun,**neg_noun_verb}

# %%
print('neg_adj', neg_adj)
# Out:
# neg_adj {'возмутительный': 2, 'годовой': 49, 'свой': 653, 'минимальный': 25, 'первый': 193, 'самый': 140, 'накопительный': 46, 'некий': 16, 'который': 908, 'соседний': 14, 'основный': 21, 'открытый': 24, 'мой': 1209, 'такой': 594, 'кой': 9, 'новый': 188, 'любой': 81, 'этот': 806, 'всякий': 20, 'тот': 673, 'активный': 5, 'ручной': 1, 'каждый': 180, 'полный': 152, 'долгий': 27, 'третий': 71, 'профильный': 1, 'негативный': 24, 'технический': 84, 'четвёртый': 9, 'сей': 102, 'какой': 327, 'личный': 207, 'денежный': 183, 'другой': 474, 'хмельницкий': 1, 'ипотечный': 103, 'трёхкратный': 1, 'данный': 257, 'кредитный': 449, 'опознавательный': 1, 'рабочий': 108, 'готовый': 6, 'повышенный': 19, 'ваш': 313, 'весь': 453, 'интересный': 29, 'маленький': 30, 'сам': 306, 'служебный': 6,
'некорректный': 8, 'персональный': 41, 'семёновский': 2, 'профессиональный': 4, 'предыдущий': 23, 'знакомый': 25, 'ноябрьский': 1, 'декабрьский': 2, 'январский': 2, 'ультимативный': 2, 'удобный': 23, 'единственный': 29, 'выходной': 25, 'надёжный': 9, 'страховой': 123, 'остальной': 32, 'далёкий': 3, 'белый': 12, 'серый': 2, 'хвалёный': 1, 'ограниченный': 3, 'простой': 21, 'конский': 4, 'небольшой': 24, 'перечисленный': 5, 'чей': 11, 'собственный': 10, 'явный': 3, 'умный': 5, 'конкретный': 23, 'средсв': 1, 'клиентский': 13, 'гнилой': 2, 'пафосный': 3, 'местечковый': 1, 'карманн ...

# %% [markdown]
# Вычислим критерий согласия Пирсона:

# %%
def x_sq (dict1, dict2):
    
    '''
    Функция присваивает значения переменных для формулы хи-квадрат и вычисляет критерий согласия,
    далее добавляет слово и значение х2 в словарь, если частота лексемы в первом словаре больше, чем во втором 
    и возвращает отсортированный словарь.
    
    '''
    
    total1 = sum(dict1.values())
    total2 = sum(dict2.values())

    dict_sorted={}

    for word in dict1:
        a = dict1[word]
        b = 0
        if word in dict2:
            b = dict2[word]
            c = total1 - a
            d = total2 - b
            n = a+b+c+d
            x2 = (n*((a*d-b*c)**2))/((a+b)*(a+c)*(b+d)*(c+d))
            
            if a>b:
                dict_sorted[word] = x2

    l = lambda x: x[1]
    dict_sorted = sorted(dict_sorted.items(), key=l, reverse=True)
    return dict_sorted

# %%
a = x_sq(pos_adj, neg_adj)
aa = x_sq(neg_adj, pos_adj)
b = x_sq(pos_noun, neg_noun)
bb = x_sq(neg_noun, pos_noun)
c = x_sq(pos_verb, neg_verb)
cc = x_sq(neg_verb, pos_verb)
d = x_sq(pos_adv, neg_adv)
dd = x_sq(neg_adv, pos_adv)
e = x_sq(pos, neg)
ee = x_sq(neg, pos)

# %%
print(a, '\n\n', aa,'\n\n',b,'\n\n',bb,'\n\n',c,'\n\n',cc,'\n\n',d,'\n\n',dd,'\n\n',e,'\n\n',ee)
# Out:
# [('хороший', 789.0949478821026), ('удобный', 721.0179193086933), ('отличный', 434.51449478067633), ('выгодный', 312.4076418082152), ('вежливый', 309.37573212774976), ('приятный', 198.7122426413362), ('высокий', 138.53570608900577), ('быстрый', 131.66264772193344), ('заёмный', 117.96478907483966), ('бонусный', 110.35989855390115), ('понятный', 90.1389656520824), ('внимательный', 79.03059561513636), ('отзывчивый', 79.03059561513636), ('оперативный', 70.09534575721503), ('большой', 64.04796102139775), ('грамотный', 60.05813217727102), ('реальный', 59.75390932669219), ('собственный', 58.62554717579247), ('интересный', 57.11105326332213), ('знакомый', 54.98464181198011), ('положительный', 50.010655780350675), ('приветливый', 46.85478650547974), ('доброжелательный', 43.3735752394401), ('доступный', 42.59227514144516), ('супер', 39.82021540147462), ('оптимальный', 38.94107905272273), ('коммунальный', 38.94107905272273), ('бесплатный', 35.55212241980939), ('прекрасный', 35.09351032704231), ('неплохой', 31.234439350205733), ('лёгкий', 30.111124
#
#  [('только', 77.20324054358062), ('ничего', 76.20863561256374), ('почему', 71.18131626726924), ('ещё', 61.46095687263601), ('сегодня', 52.80578135018846), ('опять', 52.76963924312987), ('так', 50.51787420494259), ('снова', 38.716061038275605), ('далее', 38.22676648594379), ('где', 35.99090740750455), ('зачем', 22.02833060144789), ('никогда', 22.02141838147178), ('видимо', 21.393571999076823), ('потом', 20.84911835145852), ('тут', 19.360139147656366), ('теперь', 17.958335550608545), ('невозможно', 17.1932569445396), ('вообще', 15.853469911713676), ('туда', 13.356177412235795), ('там', 12.821712698963234), ('никак', 12.060599088683961), ('заранее', 12.019571860884783), ('затем', 10.984362175300491), ('ранее', 10.486676504633799), ('лично', 9.357587753850023), ('предварительно', 9.357587753850023), ('вчера', 8.920474339512538), ('крайне', 8.920474339512538), ('абсолютно', 8.58679195596166), ('нигде', 8.234996283581642), ('досрочно', 7.9390606640904045), ('везде', 7.929813674874681), ('тогда', 7.3715074923599415), ('вместе', 6.97767255234213), ('спокойно', 6.892927857150313), ('сколько', 6.630665863155589), ('соответственно', 6.370207054439123), ('примерно', 6.029750529196639), ('полностью', 5.7937487142996345), ('практически', 5.543427977856876), ('постоянно', 5.143069717163649), ('наконец', 5.073362937136952), ('хорошо', 4.877966536047281), ('почти', 4.875687621698886), ('бесплатно', 4.872493580986803), ('точно', 4.625342665230546), ('сразу', 4.582071102098887), ('уже', 4.399934875854614), ('регулярно', 4.050060109686247), ('ужасно', 3.8394992284018055), ('специально', 3.808435487013323), ('уж', 3.499094822672531), ('изначально', 3.47957296377102), ('как-то', 3.226663259228318), ('совсем', 3.15058889754919), ('корректно', 2.8913911911000922), ('прекрасно', 2.8390339210313784), ('вдруг', 2.746216824124681), ('реально', 2.6960739013519883), ('самостоятельно', 2.47150002728393), ('непонятно', 2.302125586315215), ('обязательно', 2.2289231172496105), ('правильно', 2.191445695958806), ('успешно', 2.1238922594856025), ('довольно', 2.1238922594856025), ('особо', 2.1238922594856025), ('назад', 1.9927337678286312), ('ровно', 1.941110767855048), ('настолько', 1.6497373567378506), ('чисто', 1.6497373567378506), ('внимательно', 1.6320453146994345), ('здесь', 1.6135831005652985), ('ежемесячно', 1.5991456400441146), ('смешно', 1.5954084453579094), ('прямо', 1.595353194688468), ('вовремя', 1.5227042901678969), ('чуть', 1.4994986557459946), ('интересно', 1.4677653876447365), ('частично', 1.4677653876447365), ('дважды', 1.4677653876447365), ('дополнительно', 1.4421138785783583), ('зря', 1.4421138785783583), ('исправно', 1.4421138785783583), ('поэтому', 1.335097434735146), ('нормально', 1.3169478582052008), ('сюда', 1.2961576541259796), ('одновременно', 1.2961576541259796), ('поздно', 1.2961576541259796
ратиться к сотрудникам', 0.4318646324791091), ('быть в отделение', 0.4318646324791091), ('приехать в автосалон', 0.4318646324791091), ('написать в службу', 0.4318646324791091), ('проблема была', 0.4318646324791091), ('банк был', 0.4318646324791091), ('банк начал', 0.4318646324791091), ('переплата составила', 0.4318646324791091), ('этот карта', 0.34842002109248765), ('сторонний банк', 0.3319155929518917), ('мой муж', 0.3319155929518917), ('каждый год', 0.3319155929518917), ('быть только', 0.3319155929518917), ('где быть', 0.3319155929518917), ('обращаться в банк', 0.3319155929518917), ('полный объём', 0.2757952199298484), ('свой карта', 0.2730205082658622), ('мобильный банк', 0.273020508265862 ...

# %% [markdown]
# Далее подберем оптимальное значение <b>критерия согласия Пирсона</b> для добавления слов в тезаурус.
# Преобразуем словари в датафреймы и определим первый квартиль, это значение будет пороговым для каждого словаря.

# %%
dict_list = [a,aa,b,bb,c,cc,d,dd,e,ee]
threshold = []
for i in dict_list:
    i = pd.DataFrame(i, columns=['w','x'])
    n = np.percentile(i.x, 25)
    threshold.append(n)

# %%
threshold
# Out:
# [12.507576828621886,
#  0.12214436242938595,
#  8.299354268914863,
#  0.20298328889912964,
#  6.772234142264276,
#  0.23180454537703205,
#  5.894387272924615,
#  0.17212468657163785,
#  4.587118202929423,
#  0.08529805806329623]

# %%
pos_adj = []
for key,value in a:
    if value > 12.5:
        pos_adj.append(key)
    
neg_adj = []
for key,value in aa:
    if value > 0.1:
        
        neg_adj.append(key)
    
pos_noun = []
for key,value in b:
    if value > 8.3:
        
        pos_noun.append(key)
    
neg_noun = []
for key,value in bb:
    if value > 0.2:
        
        neg_noun.append(key)
        
pos_adv = []
for key,value in d:
    if value > 6.8:
        
        pos_adv.append(key)
    
neg_adv = []
for key,value in dd:
    if value > 0.2:
        
        neg_adv.append(key)
    
pos_verb = []
for key,value in c:
    if value > 0.09:
        
        pos_verb.append(key)
    
neg_verb = []
for key,value in cc:
    if value > 1.2:
        
        neg_verb.append(key)
    
pos_colloc = []
for key,value in e:
    if value > 4.6:
        
        pos_colloc.append(key)

neg_colloc = []
for key,value in ee:
    if value > 0.09:
        
        neg_colloc.append(key)

# %%
print('pos_adj', pos_adj, '\n\n', 'pos_noun', pos_noun,'\n\n', 'pos_verb', pos_verb,'\n\n', 'pos_adv', pos_adv,'\n\n', 'neg_adj', neg_adj,'\n\n', 'neg_noun', neg_noun,'\n\n', 'neg_verb', neg_verb,'\n\n', 'neg_adv', neg_adv,'\n\n', 'pos_colloc', pos_colloc,'\n\n', 'neg_colloc', neg_colloc)
# Out:
# pos_adj ['хороший', 'удобный', 'отличный', 'выгодный', 'вежливый', 'приятный', 'высокий', 'быстрый', 'заёмный', 'бонусный', 'понятный', 'внимательный', 'отзывчивый', 'оперативный', 'большой', 'грамотный', 'реальный', 'собственный', 'интересный', 'знакомый', 'положительный', 'приветливый', 'доброжелательный', 'доступный', 'супер', 'оптимальный', 'коммунальный', 'бесплатный', 'прекрасный', 'неплохой', 'лёгкий', 'адекватный', 'умный', 'сложный', 'качественный', 'трудный', 'различный', 'беспроцентный', 'приличный', 'короткий', 'полезный', 'приемлемый', 'продуктовый', 'чёткий', 'достойный', 'привлекательный', 'крутой', 'прозрачный']
#
#  pos_noun ['халва', 'рассрочка', 'партнёр', 'покупка', 'кэшбэк', 'бонус', 'кэшбек', 'магазин', 'кешбек', 'остаток', 'кешбэк', 'акция', 'товар', 'использование', 'десяток', 'персонал', 'магазин-партнёр', 'скидка', 'пользование', 'подписка', 'кэш', 'нарекание', 'уровень', 'доктор', 'задание', 'преимущество', 'интерфейс', 'рада', 'выполнение', 'балл', 'переплата', 'удовольствие', 'жкх', 'кэшбэкома', 'бек', 'плюс', 'опция', 'плюшка', 'удобство', 'молодец', 'копилка', 'вещь', 'санкция', 'точка', 'техника', 'простота', 'игра', 'ремонт', 'замена', 'пользователь', 'шаг', 'контраст', 'зависимость', 'прохождение', 'коммуналка', 'процветание', 'накопление', 'бот', 'новость', 'кеш', 'увеличение', 'вкус', 'обстановка', 'мвидео', 'расположение', 'надбавка', 'мечта', 'бюджет', 'благодарность', 'дочь', 'профессионал', 'мебель', 'море', 'неприятность', 'класс', 'кухня', 'леруа']
#
#  pos_verb ['пользоваться', 'нравиться', 'помочь', 'рекомендовать', 'устраивать', 'помогать', 'выручать', 'понравиться', 'радовать', 'рассказать', 'подсказать', 'использовать', 'решаться', 'решать', 'выполнять', 'стараться', 'остановиться', 'разъяснить', 'сотрудничать', 'позволять', 'привыкнуть', 'увеличивать', 'перейти', 'порекомендовать', 'проконсультировать', 'пить', 'наткнуться', 'начислять', 'случаться', 'любить', 'напоминать', 'экономить', 'зависеть', 'сэкономить', 'выручить', 'доводить', 'переживать', 'погашать', 'обьяснить', 'осуществить', 'испытывать', 'убеждаться', 'дополнить', 'падать', 'компенсировать', 'пригодиться', 'расплатиться', 'обсудить', 'соврать', 'подобрать', 'курировать', 'затронуть', 'участвовать', 'развиваться', 'почувствовать']
#
#  pos_adv ['очень', 'удобно', 'быстро', 'всегда', 'оперативно', 'много', 'доступно', 'отлично', 'понятно', 'выгодно', 'приятно', 'особенно', 'легко', 'давно', 'грамотно', 'доходчиво', 'достаточно', 'подробно', 'чётко', 'наиболее', 'активно', 'часто', 'профессионально', 'честно', 'недавно', 'круто', 'весьма', 'вполне', 'дистанционно', 'доброжелательно']
#
#  neg_adj ['мой', 'любой', 'тот', 'этот', 'который', 'горячий', 'такой', 'весь', 'ваш', 'мобильный', 'самый', 'страховой', 'ипотечный', 'огромный', 'повышенный', 'какой', 'простой', 'досрочный', 'многий', 'данный', 'следующий', 'лишний', 'полный', 'крупный', 'рабочий', 'наш', 'личный', 'сей', 'технический', 'надёжный', 'лояльный', 'зарплатный', 'электронный', 'никакой', 'всякий', 'очередной', 'уважаемый', 'замечательный', 'один', 'персональный', 'указанный', 'больший', 'другой', 'денежный', 'определённый', 'каждый', 'обязательный', 'нужный', 'какой-то', 'прошлый', 'её', 'юридический', 'подробный', 'сам', 'целый', 'подходящий', 'долгий', 'дебетовый', 'платёжный', 'негативный', 'общий', 'разный', 'милый', 'внутренний', 'профессиональный', 'виртуальный', 'круглосуточный', 'третий', 'повторный', 'налоговый', 'процентный', 'второй', 'единственный', 'индивидуальный', 'возможный', 'свой', 'навязчивый', 'разумный', 'внятный', 'предварительный', 'открытый', 'сторонний', 'настоящий', 'постоянный', 'предыдущий', 'равный', 'специальный', 'хитрый', 'семейный', 'непонятный', 'наличный', 'инвестиционный', 'чёрный', 'ежемесячный', 'подобный', 'сегодняшний', 'готовый', 'моментальный', 'серьёзный', 'странный', '2-й', 'наглый', 'близкий', 'длительный', 'телефонный', 'льготный', 'выходной', 'небольшой', 'неприятный', 'паспортный', 'маленький', 'отдельный', 'лицевой', 'прочий', 'кассовый', 'месячный', 'таковой', 'остальной', 'плохой', 'обратный', 'дополнительный', 'первый', 'банковский', 'скорый', 'социальный', 'бесполезный', 'московский', 'малый', 'тяжёлый', 'детский', 'бывший', 'особый', 'дорогой', 'живой', 'пластиковый', 'ответственный', 'текущий', 'ежедневный', '1-й', 'мёртвый', 'безупречный', 'финальный', 'копеечный', 'достаточный', 'красивый', 'круглый', 'удачный', 'фирменный', 'долгожданный', 'великолепный', 'частый', 'альтернативный', 'зелёный', 'рядовой', 'народный', 'кой', 'четвёртый', 'срочный', 'вразумительный', 'накопительный', 'финансовый', 'какой-либо', 'чудесный', 'сплошной', 'годовой', 'минимальный', 'некоторый', 'твой', 'честной', 'цифровой', 'стандартный', 'частичный', 'кредитный', 'пенсионный', 'основной', 'первоначальный', 'расчётный', 'многочисленный', 'аналогичный', 'вобщий', 'конечный', 'материальный', 'известный', 'нижний', 'новый', 'ранний', 'далёкий', 'базовый', 'недавний', 'ценный', 'стабильный', 'иностранный', 'свинский', 'фин', 'совершенный', 'немаленький', 'региональный', 'громкий', 'знающий', 'заветный']
#
#  neg_noun ['карта', 'процент', 'вклад', 'приложение', 'условие', 'обслуживание', 'год', 'втб', 'совкомбанк', 'вопрос', 'чат', 'день', 'продукт', 'договор', 'заявление', 'номер', 'г', 'страховка', 'программа', 'оплата', 'документ', 'счёт', 'линия', 'звонок', 'час', 'возможность', 'поддержка', 'газпромбанк', 'консультация', 'друг', 'отказ', 'итог', 'консультант', 'главное', 'руб', 'смс', 'мес', 'ответ', 'адрес', 'обращение', 'сумма', 'неделя', 'страхование', 'лицо', 'человек', 'рубль', 'ул', 'долг', 'причина', 'помощь', 'москва', 'пополнение', 'течение', 'заявка', 'целое', 'отделение', 'общение', 'сотрудница', 'ипотека', 'функция', 'начисление', 'слово', 'жалоба', 'менеджер', 'ставка', 'рассмотрение', 'опыт', 'количество', 'право', 'выбор', 'этап', 'р', 'сделка', 'запрос', 'почта', 'претензия', 'представитель', 'ошибка', 'дата', 'паспорт', 'организация', 'деньга', 'наличные', 'март', 'касса', 'отдел', 'сообщение', 'необходимость', 'трата', 'ооо', 'просрочка', 'операция', 'пара', 'справка', 'август', 'вариант', 'тыс', 'списание', 'погашение', 'сбербанк', 'задолженность', 'взаимодействие', 'выгода', 'мошенник', 'сутки', 'требование', 'обмен', 'совет', 'ип', 'январь', 'пакет', 'карточка', 'рынок', 'проверка', 'данные', 'клиент', 'сравнение', 'рука', 'платёж', 'информация', 'пора', 'нерв', 'код', 'внимание', 'имя', 'основание', 'образ', 'разговор', 'кабинет', 'реквизит', 'отзыв', 'услуга', 'компания', 'сторона', 'сервис', 'инструкция', 'основное', 'взгляд', 'большинство', 'заблуждение', 'бумага', 'кассир', 'декабрь', 'проблема', 'автомобиль', 'лимит', 'бизнес', 'семья', 'стоимость', 'число', 'мелочь', 'поиск', 'зарплата', 'действие', 'апрель', 'центр', 'понимание', 'план', 'налог', 'минута', 'талон', 'квартира', 'безопасность', 'подтверждение', 'филиал', 'размер', 'эмоция', 'отличие', 'пин-код', 'выплата', 'отсутствие', 'улица', 'сотрудничество', 'факт', 'средство', 'февраль', 'место', 'связь', 'мошенничество', 'запись', 'бумажка', 'сайт', 'офис', 'елена', 'утро', 'млн', 'вывод', 'анкета', 'защита', 'заключение', 'тариф', 'город', 'протяжение', 'цб', 'ао', 'нюанс', 'завершение', 'обновление', 'улыбка', 'момент', 'квитанция', 'предоставление', 'автосалон', 'порядок', 'ирина', 'минус', 'режим', 'мина', 'проспект', 'подпись', 'отношение', 'конкурент', 'тонкость', 'пожелание', 'помощник', 'возвращение', 'история', 'база', 'руководство', 'валюта', 'зал', 'законодательство', 'ситуация', 'выдача', 'язык', 'ограничение', 'операционист', 'тип', 'оценка', 'обязательство', 'случай', 'срок', 'рефинансирование', 'авто', 'бог', 'газпром', 'должник', 'соглашение', 'россия', 'банк', 'блокировка', 'подход', 'начало', 'порог', 'наталья', '2019г', 'деятельность', 'рабочий', 'трудность', 'посещение', 'закрытие', 'половина', 'женщина', 'голова', 'желание', 'пароль', 'девочка', 'доход', 'доставка', 'гражданин', 'сергеевич', 'просьба', 'доступ', 'решение', 'подача', 'продавец', 'вложение', 'набор', 'годность', 'слияние', 'существо', 'родитель', 'круг', 'пин', 'наличие', 'интернет-банк', 'доходность', 'поход', 'наличка', 'спец', 'деталь', 'перевыпуск', 'сбер', 'курьер', 'раз', 'окно', 'пункт', 'доллар', 'баланс', 'пандемия', 'истечение', 'цель', 'график', 'одобрение', 'указание', 'анна', 'реклама', 'время', 'век', 'оборот', 'удивление', 'потеря', 'сбой', 'задержка', 'н', 'фио', 'цена', 'репутация', 'толк', 'девушка', 'форма', 'муж', 'тысяча', 'сила', 'отключение', 'профессионализм', 'техподдержка', 'совесть', 'извинение', 'труд', 'суббота', 'активация', 'суть', 'уточнение', 'готовность', 'рамка', 'сто', 'ноль', 'десятка', 'обьяснил', '5000р', 'предприниматель', 'малое', 'подруга', 'школа', 'коллектив', 'благо', 'материал', 'выезд', 'повышение', 'вежливость', 'кредитование', 'зачисление', 'положение', 'дом', 'п', 'будущее', 'служба', 'копейка', 'юр', 'политика', 'пеня', 'вознаграждение', 'снятие', 'расчёт', 'плата', 'обстоятельство', 'норма', 'окончание', 'система', 'телекарда', 'перевод', 'часть', 'вкладчик', 'инвестиция', 'гора', 'ощущение', 'евгений', 'с ...
#
#  neg_verb ['сказать', 'говорить', 'мочь', 'объяснить', 'звонить', 'советовать', 'оформить', 'хотеться', 'получать', 'объяснять', 'просить', 'ждать', 'быть', 'открыть', 'начисляться', 'возникать', 'сообщить', 'прийти', 'написать', 'отвечать', 'покупать', 'писать', 'работать', 'отказаться', 'оставаться', 'смочь', 'отправить', 'уйти', 'оплачивать', 'обслужить', 'видеть', 'перезвонить', 'купить', 'возвращаться', 'принять', 'пытаться', 'позвонить', 'сидеть', 'посоветовать', 'начаться', 'возвращать', 'показать', 'обращаться', 'приходить', 'подписать', 'оказываться', 'составить', 'приехать', 'приобрести', 'требовать', 'связаться', 'обьяснять', 'списать', 'находиться', 'реагировать', 'интересовать', 'предоставить', 'оформлять', 'поступить', 'выпустить', 'сработать', 'брать', 'воспользоваться', 'подключить', 'выполнить', 'обслуживаться', 'чувствовать', 'перевести', 'обратиться', 'указать', 'бояться', 'заниматься', 'произойти', 'закрыть', 'тратить', 'надеяться', 'выясниться', 'получиться', 'начинать', 'думать', 'понадобиться', 'спросить', 'согласиться', 'отказать', 'оставлять', 'повезти', 'зарабатывать', 'снять', 'называться', 'сообщать', 'уходить', 'подумать', 'оказаться', 'прислать', 'повысить', 'находить', 'привозить', 'накопить', 'расти', 'выслушать', 'консультироваться', 'отправлять', 'подать', 'оплатить', 'выбирать', 'появляться', 'связываться', 'обнаружить', 'пройти', 'привезти', 'направить', 'открывать', 'приходиться', 'уточнить', 'пояснить', 'вносить', 'меняться', 'увеличиваться', 'ездить', 'сменить', 'входить', 'предлагать', 'стоить', 'принимать', 'поехать', 'начать', 'принести', 'предоставлять', 'заканчиваться', 'рассказывать', 'являться', 'провести', 'разобраться', 'делаться', 'знать', 'подавать', 'нарушать', 'озвучить', 'планировать', 'убедиться', 'пополнять', 'владеть', 'отражаться', 'удаваться', 'переплачивать', 'бывать', 'рассмотреть', 'войти', 'рассчитать', 'нажать', 'остаться', 'давать', 'задать', 'уверить', 'разбираться', 'собираться', 'обещать', 'существовать', 'запросить', 'передать', 'совершать', 'составлять', 'поступать', 'читать', 'исправить', 'врать', 'пропасть', 'дождаться', 'случиться', 'отображаться', 'переводить', 'успеть', 'ответить', 'хранить', 'капать', 'рассчитывать', 'заплатить', 'погасить', 'игнорировать', 'подождать', 'утверждать', 'придумать', 'повестись', 'класть', 'управлять', 'выполняться', 'выбрать', 'решиться', 'требоваться', 'хватать', 'перечислить', 'проверять', 'отсутствовать', 'слышать', 'поставить', 'подойти', 'сделать', 'пойти', 'потерять']
#
#  neg_adv ['только', 'ничего', 'почему', 'ещё', 'сегодня', 'опять', 'так', 'снова', 'далее', 'где', 'зачем', 'никогда', 'видимо', 'потом', 'тут', 'теперь', 'невозможно', 'вообще', 'туда', 'там', 'никак', 'заранее', 'затем', 'ранее', 'лично', 'предварительно', 'вчера', 'крайне', 'абсолютно', 'нигде', 'досрочно', 'везде', 'тогда', 'вместе', 'спокойно', 'сколько', 'соответственно', 'примерно', 'полностью', 'практически', 'постоянно', 'наконец', 'хорошо', 'почти', 'бесплатно', 'точно', 'сразу', 'уже', 'регулярно', 'ужасно', 'специально', 'уж', 'изначально', 'как-то', 'совсем', 'корректно', 'прекрасно', 'вдруг', 'реально', 'самостоятельно', 'непонятно', 'обязательно', 'правильно', 'успешно', 'довольно', 'особо', 'назад', 'ровно', 'настолько', 'чисто', 'внимательно', 'здесь', 'ежемесячно', 'смешно', 'прямо', 'вовремя', 'чуть', 'интересно', 'частично', 'дважды', 'дополнительно', 'зря', 'исправно', 'поэтому', 'нормально', 'сюда', 'одновременно', 'поздно', 'столько', 'обычно', 'буквально', 'гораздо', 'периодически', 'онлайн', 'неудобно', 'случайно', 'неверно', 'несколько', 'пока', 'сейчас', 'мило', 'совместно', 'параллельно', 'ясно', 'вовсе', 'ежедневно', 'жалко', 'вскоре', 'резко', 'открыто', 'срочно', 'что-то', 'сначала', 'моментально', 'где-то', 'неправильно', 'рядом', 'нереально', 'трижды', 'дорого', 'печально', 'рано', 'искренне', 'трудно', 'вечно', 'выше', 'действительно']
#
#  pos_colloc ['удобный приложение', 'хороший банк', 'отличный банк', 'пользоваться уже', 'всегда помочь', 'давно пользоваться', 'хороший процент', 'хороший кэшбек', 'высокий процент', 'мобильный приложение', 'отвечать быстро', 'умный карта', 'решаться оперативно', 'хорошо работать', 'удобный банк', 'самый главное', 'короткий срок', 'банк хороший', 'оперативный решение', 'кредитный доктор', 'долгий время', 'работать с банком', 'повышенный процент', 'любой вопрос', 'быстрый оформление', 'виртуальный карта', 'большой количество', 'полный информация', 'отлично работать', 'всегда пользоваться', 'подробно объяснять', 'стать ещё', 'быстро ответить', 'обращаться по поводу', 'огромный количество', 'стать очень', 'неоднократно обращаться']
#
#  neg_colloc ['горячий линия', 'кредитный договор', 'досрочный погашение', 'зарплатный карта', 'личный кабинет', 'такой образ', 'ежемесячный платёж', 'замечательный банк', 'страховой компания', 'мой вопрос', 'прийти в банк', 'зарплатный клиент', 'мой обращение', 'кредитный лимит', 'полностью устраивать', 'обратиться в отделение', 'позвонить в банк', 'уже быть', 'надёжный банк', 'другой карта', 'весь сумма', 'ипотечный кредит', 'близкий время', 'мой карта', 'мой проблема', 'мой сторона', 'сам карта', 'подробно рассказать', 'погасить досрочно', 'приходить в офис', 'некоторый время', 'приехать в банк', 'мой заявка', 'каждый день', 'банковский карта', 'быть ещё', 'мой просьба', 'потребительский кредит', 'сам банк', 'сам дело', 'каждый месяц', 'данный банк', 'наш семья', 'ещё быть', 'обратиться в службу', 'рабочий место', 'финансовый защита', 'быть очень', 'один банк', 'технический поддержка', 'весь информация', 'новый карта', 'процентный ставка', 'этот операция', 'приходить в банк', 'данный карта', 'сей день', 'всегда быть', 'последний кредит', 'какой-то время', 'первый очередь', 'минимальный платёж', 'указанный сумма', 'пенсионный карта', 'этот история', 'обратный звонок', 'единственный банк', 'необходимый сумма', 'обязательный платёж', 'финансовый консультант', 'этот программа', 'весь история', 'видимо прийтись', 'быть срочно', 'назад быть', 'быть долго', 'пройти почти', 'работать уже', 'исправно платить', 'сказать сразу', 'платить вовремя', 'сегодня получить', 'пойти в офис', 'обратиться к сотрудникам', 'быть в отделение', 'приехать в автосалон', 'написать в службу', 'проблема была', 'банк был', 'банк начал', 'переплата составила', 'этот карта', 'сторонний банк', 'мой муж', 'каждый год', 'быть только', 'где быть', 'обращаться в банк', 'полный объём', 'свой карта', 'мобильный банк', 'обратный связь', 'один карта', 'определённый сумма', 'быть хорошо', 'быть в банке', 'ваш карта', 'идти в банк', 'мой случай', 'этот банк', 'тот число', 'данный момент', 'мобильный телефон', 'близкий отделение', 'паспортный данные', 'другой информация', 'частичный снятие', 'мой история', 'такой возможность', 'наш сделка', 'весь период', 'неудачный опыт', 'неоднократно звонить', 'пройти успешно', 'позвонить по телефону', 'звонить в службу', 'вернуться в банк', 'банк предложил', 'вопрос был', 'кредитный история', 'обратиться в банк']

# %% [markdown]
# ## Анализ тональности <a id="4"></a>

# %% [markdown]
# Для каждого комментария вычислим значение `score`, которое будет отражать количество использованной положительно и отрицательно окрашенной лексики.

# %%
def analisys(corpus):
    
    '''
    Функция принимает на вход датафрейм, токенизирует каждый отзыв датафрейма, 
    для каждого слова отзыва проводит морфологический анализ,
    далее, если это слово или коллокация есть в тональном словаре, 
    прибавляет или вычитает единицу к изначально нулевому значению score 
    (в зависимости от тональности слова и наличия частицы 'не').
    Заполняет список значениями score для каждого отзыва.
   
    '''
    m = MorphAnalyzer()
    hhh = []
    for comment in corpus:
        comment = simple_word_tokenize(comment)
        score = 0
        for i in range (0, len(comment)-2):
            w1 = comment[i]
            w2 = comment[i+1]
            w3 = comment[i+2]
            w1 = m.parse(w1)[0]
            n1 = w1.normal_form
            w2 = m.parse(w2)[0]
            n2 = w2.normal_form
            w3 = m.parse(w3)[0]
            n = n1+' '+n2 
            nn = n1+' '+n2+' '+comment[i+2]
        
        
            if ('ADJF' in w1.tag and 'NOUN' in w2.tag) or ('ADJF' in w2.tag and 'NOUN' in w1.tag):
                if (w1.tag.gender == w2.tag.gender) and (w1.tag.number == w2.tag.number) and (w1.tag.case == w2.tag.case):
                    
                    if n in pos_colloc:
                        score += 1
                    elif n in neg_colloc:
                        score += -1
                    else:
                        score += 0                     
            
            elif 'ADJF' in w2.tag:
                if n2 in pos_adj and w1 == 'не':
                    score += -1
                elif n2 in pos_adj and w1 != 'не':
                    score += 1
                elif n2 in neg_adj:
                    score += -1
                else:
                    score += 0
                
            elif 'NOUN' in w1.tag and 'VERB' in w2.tag:
                if nn in pos_colloc:
                    score += 1
                elif n in neg_colloc:
                    score += -1
                else:
                    score += 0 
        
            elif 'NOUN' in w2.tag:
                if n2 in pos_noun and w1 == 'не':
                    score += -1
                elif n2 in neg_noun and w1 == 'не':
                    score += 1
                elif n2 in neg_noun:
                    score += -1
                else:
                    score += 0
        
            elif 'VERB' in w1.tag and 'PREP' in w2.tag and 'NOUN' in w3.tag:
                if nn in pos_colloc:
                    score += 1
                elif n in neg_colloc:
                    score += -1
                else:
                    score += 0 
        
            elif 'VERB' in w2.tag:
                if n2 in pos_verb and w1 == 'не':
                    score += -1
                elif n2 in neg_verb and w1 == 'не':
                    score += 1
                elif n2 in neg_verb:
                    score += -1
                else:
                    score += 0
        
            elif ('ADVB' in w1.tag and 'VERB' in w2.tag) or ('ADVB' in w2.tag and 'VERB' in w1.tag):
                if n in pos_colloc:
                    score += 1
                elif n in neg_colloc:
                    score += -1
                else:
                    score += 0
                
            elif 'ADVB' in w2.tag:
                if n2 in pos_adv and w1 == 'не':
                    score += -1
                elif n2 in neg_adv and w1 == 'не':
                    score += 1
                elif n2 in neg_adv:
                    score += -1
                else:
                    score += 0
                
            else:
                score += 0
        
            
        
        hhh.append(score)
        
    return hhh

# %%
score = analisys(df['text'])

# %% [markdown]
# Добавим значения в датафрейм и заменим колонку `coloring` на `true`, которая будет отражать реальную оценку.

# %%
df['score'] = score

# %%
sent = []
for i in df['coloring']:
    if i == 'good':
        sent.append('pos')
    else:
        sent.append('neg')
df = df.drop(['coloring'], axis=1)
df['true'] = sent

# %% [markdown]
# Проведем анализ тональности для корпусов с положительными и отрицательными отзывами, чтобы определить пороговые значения `score` для предсказания оценки.

# %%
bad = analisys(df_neg['text'])
good = analisys(df_pos['text'])

# %%
bad = pd.DataFrame(bad, columns=['score'])
good = pd.DataFrame(good, columns=['score'])

# %%
bad.describe()
# Out:
#              score
# count  1329.000000
# mean    -49.147479
# std      40.936635
# min    -206.000000
# 25%     -65.000000
# 50%     -35.000000
# 75%     -20.000000
# max      -3.000000

# %%
good.describe()
# Out:
#              score
# count  1357.000000
# mean     -6.727340
# std       8.181889
# min    -133.000000
# 25%      -8.000000
# 50%      -5.000000
# 75%      -3.000000
# max       4.000000

# %% [markdown]
# Нормальные значения `score` для отрицательных отзывов от -71 до -21, для положительных от -8 до 4.
# Присвоим отзывам со значением score меньше или равному `-15` отрицательную оценку, остальным - положительную.

# %%
pred = []
for i in df['score']:
    if i <= -15:
        pred.append('neg')
    else:
        pred.append('pos')
df['predicted'] = pred

# %%
df
# Out:
#                                                   text  rated           date  \
# 243                        А где реквизиты то взять???      2  12 нояб, 2014
# 266  А как стоило открыть в Вашем банке счет – так ...      2  30 сент, 2014
# 142  Банк Траст в июне 2014 году выдал справку о за...      1  08 нояб, 2017
# 625  Банк всегда готов помочь клиентам в решение пр...      5   02 апр, 2022
# 373  Банк нравится, готова и дальше сотрудничать. П...      5   05 апр, 2022
# ..                                                 ...    ...            ...
# 287  я ответила, что была по девичьей фамилии, по и...      2  21 июня, 2014
# 269  я пришел брать одобренный мне кредит на сумму ...      2  03 сент, 2014
# 65   я являюсь клиентом этого банка, т.к зарплату м...      1  12 февр, 2018
# 67   января 2018 года в 18:44 в СПб на Нарвском 23 ...      1  08 февр, 2018
# 42   января 2018 года, я обратился в банк с претенз...      1   20 мар, 2018
#
#               bank              theme       name     sex  score true predicted
# 243       zapadnyj  Кредиты наличными        Яна  female     -2  neg       pos
# 266           rnkb       Обслуживание     Ленара    unkn    -25  neg       neg
# 142          trast  Кредиты наличными      Елена  female    -31  neg       neg
# 625     sovkombank             Вклады      Елена  female     -4  pos       pos
# 373     sovkombank            Ипотека     Альфия    unkn     -4  pos       pos
# ..             ...                ...        ...     ...    ...  ...       ...
# 287  lipeckkombank       Обслуживание         Ал    unkn    -74  neg       neg
# 269  promsvjazbank       Обслуживание     Руслан    male    -94  neg       neg
# 65     chelindbank  Кредиты наличными        Яна  female    -32  neg       neg
# 67      sovkombank       Обслуживание       Вера  female    -14  neg       pos
# 42             vtb       Обслуживание  Александр    male    -30  neg       neg
#
# [696 rows x 10 columns]

# %% [markdown]
# ## Оценка работы алгоритма <a id="5"></a>

# %% [markdown]
# Для оценки качества работы будем использовать метрики `accuracy`, `f-measure`, `f1-score`, `precision` и `recall`.

# %% [markdown]
# Посчитаем количество `TP` (*true positive*), `TN` (*true negative*), `FP` (*false positive*), `FN` (*false negative*).

# %%
a = []
b = []
for i in df['predicted']:
    a.append(i)
for i in df['true']:
    b.append(i)

# %%
tp = 0 
tn = 0 
fp = 0 
fn = 0
t_f = []
for i in range(0, len(a)):
    if a[i] == b[i]:
        if a[i] == 'pos':
            tp+=1
            t_f.append('tp')
        else:
            tn+=1
            t_f.append('tn')
    elif a[i] != b[i]:
        if a[i] == 'pos':
            fp+=1
            t_f.append('fp')
        else:
            fn+=1
            t_f.append('fn')

# %%
df['result'] = t_f

# %% [markdown]
# Вычислим метрики по формулам.

# %%
accuracy = (tp+tn)/len(df)
precision = tp/ (tp+fp)
recall = tp/(tp+fn)
f1 = 2/(1/precision+1/recall)
f_measure = 2*((precision*recall)/(precision+recall))

# %%
print('accuracy', accuracy)
print('precision', precision)
print('recall', recall)
print('f1-score', f1)
print('f-measure', f_measure)
# Out:
# accuracy 0.9267241379310345
# precision 0.9198966408268734
# recall 0.9468085106382979
# f1-score 0.9331585845347314
# f-measure 0.9331585845347313

# %%
df.head(10)
# Out:
#                                                   text  rated           date  \
# 243                        А где реквизиты то взять???      2  12 нояб, 2014
# 266  А как стоило открыть в Вашем банке счет – так ...      2  30 сент, 2014
# 142  Банк Траст в июне 2014 году выдал справку о за...      1  08 нояб, 2017
# 625  Банк всегда готов помочь клиентам в решение пр...      5   02 апр, 2022
# 373  Банк нравится, готова и дальше сотрудничать. П...      5   05 апр, 2022
# 54   Банк обещает "4 мили за каждые 100 рублей" при...      1   01 мар, 2018
# 213  Банк предложил мне кредит наличными на погашен...      1   20 авг, 2017
# 207  Банк предложил рефинансирование кредита под ма...      1   28 авг, 2017
# 163  Банк пройдоха еще тот, сейчас буду подавать в ...      1   17 окт, 2017
# 177  Банк соответствует своему названию - Совковый,...      1   06 окт, 2017
#
#            bank              theme     name     sex  score true predicted  \
# 243    zapadnyj  Кредиты наличными      Яна  female     -2  neg       pos
# 266        rnkb       Обслуживание   Ленара    unkn    -25  neg       neg
# 142       trast  Кредиты наличными    Елена  female    -31  neg       neg
# 625  sovkombank             Вклады    Елена  female     -4  pos       pos
# 373  sovkombank            Ипотека   Альфия    unkn     -4  pos       pos
# 54          vtb    Дебетовые карты  Наталья  female    -67  neg       neg
# 213         vtb  Кредиты наличными    Елена  female    -41  neg       neg
# 207         vtb  Кредиты наличными  Дмитрий    male    -14  neg       pos
# 163         vtb            Ипотека     Инна  female    -57  neg       neg
# 177  sovkombank             Вклады      NaN    unkn    -35  neg       neg
#
#     result
# 243     fp
# 266     tn
# 142     tn
# 625     tp
# 373     tp
# 54      tn
# 213     tn
# 207     fp
# 163     tn
# 177     tn

# %% [markdown]
# # Закономерности <a id="6"></a>

# %% [markdown]
# Посмотрим на отзывы, где алгоритм ошибочно определил оценку.

# %%
t_res = df.query('result == "tn" or result == "tp"')
f_res = df.query('result == "fn" or result == "fp"')

# %%
pd.options.display.max_colwidth = 10000
f_res = f_res.drop(['date', 'bank', 'theme', 'name', 'sex'], axis=1)

# %%
print(fp, fn)
# Out:
# 31 20

# %%
falsep = f_res.query('result == "fp"')
o = []
for i in df['text']:
    o.append(len(i))
pd.DataFrame(o).describe()
# Out:
#                 0
# count   696.00000
# mean    581.54023
# std     703.10123
# min      27.00000
# 25%     125.75000
# 50%     235.00000
# 75%     788.25000
# max    3758.00000

# %% [markdown]
# Ложноположительные отзывы имеют тенденцию быть довольно короткими по сравнению с другими отзывами выборки. Был выявлен максимальный размер отзыва в выборке ложноположительных, он составляет 416 слов, при этом среднее значение длины отзывов в исходном тестовом корпусе – 703, медианное значение – 581.
#
# На основании этого можно сделать вывод, что алгоритм лучше проявит себя при наличии большего количества текстов, содержащих более 580 слов, и наоборот, при оценке тональности более коротких текстов, результаты будут ниже. При этом, стоит отметить, что алгоритм определял отзыв как негативный при значении ‘score’ < -15. При определенных задачах заказчика, в которых необходимо выявить все отрицательные отзывы, порог может быть изменен до максимального.

# %%
f_res.query('result == "fn"')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        text  \
# 721                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Банком доволен на сто процентов , очень нравится оперативность решения вопросов через чат поддержку, последний раз столкнулся со случайным переводом заёмных средств на на другую карту , обратился в чат банка с просьбой отменить комиссию , так как деньги были свои на счету и платеж с кредитного счета был ошибочным , после нескольких минут ожиданий оператор отменила комиссию
# 406                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Быстро решили проблему с картой. Была утерена карта и проблемы со снятием своих денег. Менеджер выдала новую карту, объяснила изменения в тарифе. Помогла увеличить лимит снятия. Было нужно снять крупную сумму.
# 509                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             В банке была проблема с п.о. и баланс карты отображался не верно, соответственно воспользоваться своими деньгами Я не мог около 2х часов пока банк исправлял ошибку. После мне прислали промокод на 1000 рублей за доставленные неудобства.
# 403                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# 722                                                                                                                                                          У моего отца в апреле истекает срок годности карты, на которую н получает пенсию. А я даже рада, что заменим  этот древний пластик, потому что толку от нее ноль было, в большей степени, папа чаще всего снимал деньги и везде наликом расплачивался. Повела его в Газпромбанк, потому что сама там обслуживаюсь. Я не хотела систему Мир, но девушка меня переубедила. Это были мои предрассудки, да и за время они улучшили свои предложения. Так что карта, которую мы выбрали, имеет две платежки - Мир и JCB , наличиные можно снимать бесплатно в любых !! банкоматах и жкх удобно оплачивать без процентов. После такой презентации я пересмотрела свое отношение. Карту получили в отделении и через 2 недели пользования убеились, что условия приятные не только на словах. Даже я задумалась взять у них новую карту с двумя платёжками и бонусами
# 418  Хочется поделиться о моем отношении и опыте пользования услугами банка. Во первых так сложились жизненные обстоятельства, что у меня отрицательная кредитная история. Все на что я мог рассчитывать на судды МФО и то не у всех. При обращении в офис Совкомбанка мне предложили программу Кредитный доктор. У меня были сомнения и я отказался от этого предложения. Но изучив условия и отзывы других клиентов, решился и воспользовался данной услугой Кредитный доктор. Все свои  средства кооперирую на карте Халва с нее же делаю покупки, плачу за коммуналку выполняю все условия банка. На данный момент через месяц заканчивается 2 этап программы. Мне уже предоставили сумму 45000 заемных средств, пользуюсь ими в магазинах партнерах для покупок в рассрочку. Так же открыл срочный вклад и Копилку. Из банков стали поступать предложения кредитоваться со 100% одобрением, но я отказываюсь (это одно из условий Совкомбанка). Я уверен в банке и рассчитываю пользоваться его услугами в дальнейшем.
#
#      rated  score true predicted result
# 721      5    -19  pos       neg     fn
# 406      5    -16  pos       neg     fn
# 509      5    -15  pos       neg     fn
# 403      5    -32  pos       neg     fn
# 395      5    -22  pos       neg     fn
# 526      5    -26  pos       neg     fn
# 720      5    -27  pos       neg     fn
# 549      5    -20  pos       neg     fn
# 404      5    -21  pos       neg     fn
# 516      5    -15  pos       neg     fn
# 724      5    -20  pos       neg     fn
# 455      5    -19  pos       neg     fn
# 410      5    -16  pos       neg     fn
# 566      5    -16  pos       neg     fn
# 469      5    -17  pos       neg     fn
# 677      5    -35  pos       neg     fn
# 441      5    -18  pos       neg     fn
# 456      5    -15  pos       neg     fn
# 722      5    -41  pos       neg     fn
# 418      5    -43  pos       neg     fn

# %% [markdown]
# В ложноотрицательных отзывах пользователи часто описывают определенные проблемы, которые банк помог решить, либо сравнивают один банк с другим. Из-за этого слов и коллокаций с отрицательной тональностью в тексте больше, и алгоритм определяет его как негативный.
#
# В подобных отзывах слов и коллокаций с отрицательной тональностью в тексте больше, чем с положительной, и алгоритм определяет его как негативный. Точность алгоритма можно повысить добавлением триграмм в созданный тезаурус и учетом веса важности тональных слов в вычислении значения ‘score’ при проведении анализа. Эти задачи были оставлены для будущих работ.

# %%
pivot_bank = df.pivot_table(index = 'bank', values = 'score', aggfunc = 'mean').sort_values('score', ascending = False)
print('\nБанки, отзывы о которых содержат наименьшее количество негативной лексики:\n')
print(pivot_bank.head(10))
# Out:
# Банки, отзывы о которых содержат наименьшее количество негативной лексики:
#
#                         score
# bank
# cmrbank             -6.000000
# sovkombank          -8.525253
# mezhtopehnergobank  -9.000000
# zapadnyj           -13.000000
# russtrojbank       -13.000000
# venec              -15.000000
# sovetskij          -16.000000
# akibank            -17.000000
# akcept             -18.000000
# probiznesbank      -18.000000

# %%
print('\nБанки, отзывы о которых содержат наибольшее количество негативной лексики:\n')
print(pivot_bank.tail(10))
# Out:
# Банки, отзывы о которых содержат наибольшее количество негативной лексики:
#
#                 score
# bank
# jugra           -67.0
# citibank        -74.5
# pervomajskij    -79.5
# tatfondbank     -94.0
# krajinvestbank  -98.0
# primore        -105.0
# baltinvestbank -115.0
# finam          -132.0
# otkrytie       -138.0
# siab           -140.0

# %%
pivot_theme = df.pivot_table(index = 'theme', values = 'score', aggfunc = 'mean').sort_values('score', ascending = False)
pivot_theme
# Out:
#                                 score
# theme
# Рефинансирование ипотеки    -5.000000
# Дистанционное обслуживание  -7.023810
# Кредитные карты            -10.835366
# Обмен валют                -16.000000
# Другое                     -16.761905
# Вклады                     -23.769231
# Дебетовые карты            -23.871795
# Автокредиты                -31.384615
# Обслуживание               -35.530612
# Ипотека                    -46.448276
# Кредиты наличными          -47.628571
# Рефинансирование кредитов  -70.000000

# %% [markdown]
# Видим, что рефинансирование ипотеки и дистанционное обслуживание вызывает у пользователей меньше негативных эмоций, чем вопросы связанные с обслуживанием в отделении и кредитом, что ожидаемо.

# %%
pivot_sex = df.pivot_table(index = 'sex', values = 'score', aggfunc = 'mean').sort_values('score', ascending = False)
pivot_sex
# Out:
#             score
# sex
# female -24.033835
# male   -27.062780
# unkn   -29.845411

# %%
len(df.query('sex== "male"'))
# Out:
# 223

# %%
len(df.query('sex== "female"'))
# Out:
# 266

# %% [markdown]
# ## Общий вывод <a id="7"></a>

# %% [markdown]
# В ходе работы мы получили следующие результаты:
#
# - Был создан тезаурус эмоционально окрашенной лексики на тему банков.
#
#
# - Были созданы правила для проведения анализа тональности отзывов.
#
#
# - Алгоритм хорошо справился с задачей. При оценке качества работы использовались метрики accuracy, f-measure, f1-score, precision и recall. Получены следующие значения:
#
#
#     accuracy 0.93
#     precision 0.92
#     recall 0.95
#     f1-score 0.93
#     f-measure 0.93
#
#
# - В ложноотрицательных отзывах пользователи часто описывают определенные проблемы, которые банк помог решить, либо сравнивают один банк с другим. Из-за этого слов и коллокаций с отрицательной тональностью в тексте больше, и алгоритм определяет его как негативный.
#
#
# - В ложноположительных отзывах заметили, что все они довольно короткие. Алгоритму не хватило общего количества слов в отзыве, для правильного определения оценки.
#
#
# - Наименьшее количество негативной лексики содержат отзывы о банках: СМП-Банк, Совкомбанк, Межтопэнергобанк. Наибольшее количество - отзывы о банках: Югра, Ситибанк, Первомайский.
#
#
# - Рефинансирование ипотеки и дистанционное обслуживание вызывает у пользователей меньше негативных эмоций, чем вопросы связанные с обслуживанием в отделении и кредитом.
