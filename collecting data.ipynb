# %% [markdown]
# # Сбор текстов с сайта Сравни.ру

# %% [markdown]
#     Для реализации большинства алгоритмов анализа тональности необходим обучающий массив данных (набор отзывов, для которых известна эмоциональная окраска). Так как на сегодняшний день существует очень мало публичных русскоязычных коллекций отзывов, которые можно было бы использовать для решения задачи классификации текстов, и не обнаружено ни одной русскоязычной публичной коллекции отзывов о банках, было принято решение подготовить собственный корпус текстов.
#
#     На сайте Сравни.ру оценки пользователей напрямую связаны с тональностью текста: оценка «5» соответствует только отзывам, содержащим описание положительных характеристик банка, продукта или услуги или выражение благодарности сотрудникам банка, поэтому данный веб-сайт был выбран для составления корпуса.

# %% [markdown]
# ### Импорт библиотек

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# ### Сбор корпуса

# %% [markdown]
#     Изучив структуру сайта Сравни.ру, обнаружили, что полный текст каждого отдельного отзыва находится в соответствующем ему HTML-файле, поэтому сначала необходимо собрать все ссылки на необходимые файлы.

# %%
def links(page_number):
    # для нашего исследования было важно оставить возможность подставлять в код отдельные страницы и оценки
    url = f'https://www.sravni.ru/banki/otzyvy?page={page_number}&rated=five&reviewObjectId=' 
    response = requests.get(url, headers = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'})
    soup = BeautifulSoup(response.text, 'html')
    quotes = soup.find_all('span', class_='sc-1fxln1u-27 cPAIqy')
    
    return quotes

# %%
data = []
for page_number in range(130, 160):
    urls = links(page_number=page_number)
    data.append(urls)

# %%
data = " ".join(map(str,data))
print(data)
# Out:
# [<span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526561"><div class="sc-1fxln1u-19 cNhSll">Отличная работа службы поддержки клиентов</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526559"><div class="sc-1fxln1u-19 cNhSll">Как я забирал дебетовую карту</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526557"><div class="sc-1fxln1u-19 cNhSll">Переход на валютные платежи с контрагентом</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526555"><div class="sc-1fxln1u-19 cNhSll">Вопросы по обслуживанию: заказ справок, карт и пр.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526554"><div class="sc-1fxln1u-19 cNhSll">Обслуживание клиентов в приложении</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526553"><div class="sc-1fxln1u-19 cNhSll">Мое мнение об этом банке крайне положительное!</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526552"><div class="sc-1fxln1u-19 cNhSll">Обратился в банк за консультацией по премиальному обслуживанию и накопительному счету</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526549"><div class="sc-1fxln1u-19 cNhSll">Все устраивает. Пока проблем не было.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526549"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526548"><div class="sc-1fxln1u-19 cNhSll">Дебетовая карта tinkoff black</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526545"><div class="sc-1fxln1u-19 cNhSll">Специалист Лилия очень помогла!
# Ее внутренний номер 6905561</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526544"><div class="sc-1fxln1u-19 cNhSll">Выпуск карты</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526542"><div class="sc-1fxln1u-19 cNhSll">Дебетовая карта</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526541"><div class="sc-1fxln1u-19 cNhSll">Отзыв о TINKOFF банке.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526541"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526540"><div class="sc-1fxln1u-19 cNhSll">Декларация, взносы</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526539"><div class="sc-1fxln1u-19 cNhSll">Lounge key</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526538"><div class="sc-1fxln1u-19 cNhSll">О моем опыте клиента</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526538"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526537"><div class="sc-1fxln1u-19 cNhSll">Тинькофф Блэк.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526537"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526536"><div class="sc-1fxln1u-19 cNhSll">Халва Десятка</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526535"><div class="sc-1fxln1u-19 cNhSll">Отзыв о Халве</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526526"><div class="sc-1fxln1u-19 cNhSll">Положительный отзыв.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526526"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>] [<span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526524"><div class="sc-1fxln1u-19 cNhSll">Работа службы поддержки</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526518"><div class="sc-1fxln1u-19 cNhSll">Хороший тариф по вкладу</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526517"><div class="sc-1fxln1u-19 cNhSll">Дистанционное обслуживание</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526515"><div class="sc-1fxln1u-19 cNhSll">Приложение совкомбанка</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526510"><div class="sc-1fxln1u-19 cNhSll">Все хорошо</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526507"><div class="sc-1fxln1u-19 cNhSll">Обслуживание</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526503"><div class="sc-1fxln1u-19 cNhSll">Карта халва</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526496"><div class="sc-1fxln1u-19 cNhSll">Удобное приложение и вежливые сотрудники</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526494"><div class="sc-1fxln1u-19 cNhSll">Подключение Премиум</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526492"><div class="sc-1fxln1u-19 cNhSll">Хотела бы узнать, готов ли банк одобрить мне ипотеку и под какой процент.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/526484"><div class="sc-1fxln1u-19 cNhSll">Благодарность</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/526481"><div class="sc-1fxln1u-19 cNhSll">Дебетовая карта и приложение Тинькофф.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/52 ...
# Тинькофф - он такой один.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/525148"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525142"><div class="sc-1fxln1u-19 cNhSll">Доброжелательные сотрудники, всегда подскадут</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525139"><div class="sc-1fxln1u-19 cNhSll">Грамотные специалисты</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525138"><div class="sc-1fxln1u-19 cNhSll">Услуги банка и карта Халва.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525137"><div class="sc-1fxln1u-19 cNhSll">Кредитный прогресс</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525134"><div class="sc-1fxln1u-19 cNhSll">Очень довольна картой халва</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525132"><div class="sc-1fxln1u-19 cNhSll">Пользуюсь картой " Халва"</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525130"><div class="sc-1fxln1u-19 cNhSll">Использование карты Халва</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525125"><div class="sc-1fxln1u-19 cNhSll">Мнение на работу Совкомбанка</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525123"><div class="sc-1fxln1u-19 cNhSll">Рекомендую</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525122"><div class="sc-1fxln1u-19 cNhSll">Я довольна услугами и продуктами банка</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525114"><div class="sc-1fxln1u-19 cNhSll">Восстановление карты</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525112"><div class="sc-1fxln1u-19 cNhSll">Совкомбанк - мой лучший банк!!!</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525112"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/525111"><div class="sc-1fxln1u-19 cNhSll">Просто молодцы ребята относятся по человечески им пониманием</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525105"><div class="sc-1fxln1u-19 cNhSll">Пользование приложением Совкамбанк</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525104"><div class="sc-1fxln1u-19 cNhSll">Работа банка с клиентами.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/525103"><div class="sc-1fxln1u-19 cNhSll">Благодарность!!!</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/525103"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/525102"><div class="sc-1fxln1u-19 cNhSll">Опротестование списания ₽</div></a></span>] [<span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525100"><div class="sc-1fxln1u-19 cNhSll">Рекомендую</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525098"><div class="sc-1fxln1u-19 cNhSll">О карте Халва и службе поддержки банка</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525097"><div class="sc-1fxln1u-19 cNhSll">Хороший продукт</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525094"><div class="sc-1fxln1u-19 cNhSll">Дебетовая карта выгодна в использовании.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/525085"><div class="sc-1fxln1u-19 cNhSll">Карта халва</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/525082"><div class="sc-1fxln1u-19 cNh ...
# (номер 6902022), спасибо)</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524994"><div class="sc-1fxln1u-19 cNhSll">Карта халва</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524992"><div class="sc-1fxln1u-19 cNhSll">Отзыв любви и благодарности!</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524983"><div class="sc-1fxln1u-19 cNhSll">Лучший банк</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524982"><div class="sc-1fxln1u-19 cNhSll">Открытие ИП</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524979"><div class="sc-1fxln1u-19 cNhSll">Наверное самые большие проценты 23% на вклад сроком на 3 месяца.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524979"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524978"><div class="sc-1fxln1u-19 cNhSll">Акция по карте тинькоф Драйв</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524978"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524977"><div class="sc-1fxln1u-19 cNhSll">Отличный банк по России</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524975"><div class="sc-1fxln1u-19 cNhSll">Отзыв об обслуживание тинькофф банка.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524972"><div class="sc-1fxln1u-19 cNhSll">Халва - помощница моя</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524968"><div class="sc-1fxln1u-19 cNhSll">Отзыв о работе</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524968"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524967"><div class="sc-1fxln1u-19 cNhSll">Решение проблемы</div></a></span>] [<span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524965"><div class="sc-1fxln1u-19 cNhSll">Пользование картой</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524960"><div class="sc-1fxln1u-19 cNhSll">Хочу выразить благодарность операторам службы поддержки</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524960"><span class="sc-1fxln1u-21 cvjEMi">Читать</span></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524958"><div class="sc-1fxln1u-19 cNhSll">Обслуживание  в отделении банка.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524954"><div class="sc-1fxln1u-19 cNhSll">Быстро решили проблему через чат</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524953"><div class="sc-1fxln1u-19 cNhSll">Валютный контроль прошел за день.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524952"><div class="sc-1fxln1u-19 cNhSll">Карта Халва</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/sovkombank/otzyvy/524951"><div class="sc-1fxln1u-19 cNhSll">Открыла вклад.</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524948"><div class="sc-1fxln1u-19 cNhSll">Персональный менеджер</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524938"><div class="sc-1fxln1u-19 cNhSll">В приложении были сбои с частичным погашением рассрочки написал в чат сразу решили проблему. Спасибо</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-bank/otzyvy/524937"><div class="sc-1fxln1u-19 cNhSll">Дистанционное обслуживание</div></a></span>, <span class="sc-1fxln1u-27 cPAIqy"><a href="/bank/tinkoff-ba ...

# %% [markdown]
#     Регулярным выражением удаляем из списка названия тегов для дальнейшей работы.

# %%
result = re.findall(r'/bank/\w+/otzyvy/......', data)
print(result)
# Out:
# ['/bank/sovkombank/otzyvy/526542', '/bank/sovkombank/otzyvy/526536', '/bank/sovkombank/otzyvy/526535', '/bank/sovkombank/otzyvy/526524', '/bank/sovkombank/otzyvy/526518', '/bank/sovkombank/otzyvy/526517', '/bank/sovkombank/otzyvy/526515', '/bank/sovkombank/otzyvy/526507', '/bank/sovkombank/otzyvy/526503', '/bank/sovkombank/otzyvy/526496', '/bank/sovkombank/otzyvy/526492', '/bank/sovkombank/otzyvy/526484', '/bank/sovkombank/otzyvy/526475', '/bank/sovkombank/otzyvy/526474', '/bank/sovkombank/otzyvy/526471', '/bank/sovkombank/otzyvy/526447', '/bank/sovkombank/otzyvy/526444', '/bank/sovkombank/otzyvy/526443', '/bank/sovkombank/otzyvy/526438', '/bank/sovkombank/otzyvy/526437', '/bank/sovkombank/otzyvy/526428', '/bank/sovkombank/otzyvy/526427', '/bank/sovkombank/otzyvy/526421', '/bank/sovkombank/otzyvy/526418', '/bank/sovkombank/otzyvy/526415', '/bank/sovkombank/otzyvy/526399', '/bank/sovkombank/otzyvy/526386', '/bank/sovkombank/otzyvy/526384', '/bank/sovkombank/otzyvy/526382', '/bank/sovkombank/otzyvy/526381', '/bank/sovkombank/otzyvy/526367', '/bank/sovkombank/otzyvy/526352', '/bank/sovkombank/otzyvy/526348', '/bank/sovkombank/otzyvy/526348', '/bank/sovkombank/otzyvy/526344', '/bank/sovkombank/otzyvy/526340', '/bank/sovkombank/otzyvy/526335', '/bank/sovkombank/otzyvy/526326', '/bank/sovkombank/otzyvy/526320', '/bank/sovkombank/otzyvy/526315', '/bank/sovkombank/otzyvy/526310', '/bank/gazprombank/otzyvy/526309', '/bank/gazprombank/otzyvy/526309', '/bank/gazprombank/otzyvy/526307', '/bank/gazprombank/otzyvy/526307', '/bank/sovkombank/otzyvy/526304', '/bank/sovkombank/otzyvy/526301', '/bank/sovkombank/otzyvy/526297', '/bank/sovkombank/otzyvy/526296', '/bank/sovkombank/otzyvy/526294', '/bank/sovkombank/otzyvy/526294', '/bank/sovkombank/otzyvy/526293', '/bank/sovkombank/otzyvy/526293', '/bank/sovkombank/otzyvy/526279', '/bank/sovkombank/otzyvy/526277', '/bank/sovkombank/otzyvy/526273', '/bank/sovkombank/otzyvy/526271', '/bank/sovkombank/otzyvy/526269', '/bank/sovkombank/otzyvy/526266', '/bank/sovkombank/otzyvy/526265', '/bank/sovkombank/otzyvy/526263', '/bank/sovkombank/otzyvy/526263', '/bank/sovkombank/otzyvy/526262', '/bank/sovkombank/otzyvy/526255', '/bank/sovkombank/otzyvy/526252', '/bank/sovkombank/otzyvy/526249', '/bank/sovkombank/otzyvy/526233', '/bank/sovkombank/otzyvy/526231', '/bank/sovkombank/otzyvy/526229', '/bank/sovkombank/otzyvy/526223', '/bank/sovkombank/otzyvy/526219', '/bank/sovkombank/otzyvy/526216', '/bank/sovkombank/otzyvy/526214', '/bank/sovkombank/otzyvy/526198', '/bank/sovkombank/otzyvy/526193', '/bank/sovkombank/otzyvy/526192', '/bank/sovkombank/otzyvy/526191', '/bank/sovkombank/otzyvy/526186', '/bank/sovkombank/otzyvy/526183', '/bank/sovkombank/otzyvy/526175', '/bank/sovkombank/otzyvy/526166', '/bank/sovkombank/otzyvy/526160', '/bank/sovkombank/otzyvy/526137', '/bank/sovkombank/otzyvy/526132', '/bank/sovkombank/otzyvy/526129', '/bank/sovkombank/otzyvy/526129', '/bank/sovkombank/otzyvy/526125', '/bank/sovkombank/otzyvy/526123', '/bank/sovkombank/otzyvy/526121', '/bank/sovkombank/otzyvy/526114', '/bank/sovkombank/otzyvy/526109', '/bank/sovkombank/otzyvy/526107', '/bank/sovkombank/otzyvy/526101', '/bank/sovkombank/otzyvy/526094', '/bank/sovkombank/otzyvy/526082', '/bank/sovkombank/otzyvy/526075', '/bank/sovkombank/otzyvy/526073', '/bank/sovkombank/otzyvy/526038', '/bank/sovkombank/otzyvy/526036', '/bank/gazprombank/otzyvy/526035', '/bank/gazprombank/otzyvy/526035', '/bank/gazprombank/otzyvy/526029', '/bank/gazprombank/otzyvy/526029', '/bank/sovkombank/otzyvy/526024', '/bank/sovkombank/otzyvy/526024', '/bank/sovkombank/otzyvy/526019', '/bank/sovkombank/otzyvy/526012', '/bank/sovkombank/otzyvy/526001', '/bank/sovkombank/otzyvy/525957', '/bank/sovkombank/otzyvy/525954', '/bank/sovkombank/otzyvy/525940', '/bank/sovkombank/otzyvy/525935', '/bank/sovkombank/otzyvy/525929', '/bank/sovkombank/otzyvy/525927', '/bank/sovkombank/otzyvy/525924', '/bank/sovkombank/otzyvy/525921', '/bank/sovkombank/otzyvy/525917', '/bank/sovkom ...

# %%
column_values = pd.Series(result)

# %% [markdown]
#     Далее, тем же методом с кода страниц, находящихся по каждой из полученных ссылок, сохраняем сам текст отзыва  и соответствующие ему метаданные, а именно: дату написания отзыва, имя пользователя, тему обращения и название банка.

# %%
text = []
date = []
name = []
theme = []
for i in column_values:
    url = ('https://www.sravni.ru'+i)
    response = requests.get(url, headers = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'})
    soup = BeautifulSoup(response.text, 'lxml')
    quotes = soup.find_all('div', class_='sc-lpzn2g-13 eCTrNq')
    d = soup.find_all('span', class_='sc-lpzn2g-8 hgjOYK')
    c = soup.find_all('span', class_='sc-lpzn2g-6 nXSPo')
    n = soup.find_all('span', class_='sc-lpzn2g-5 hgMCyH')
    t = soup.find_all('div', class_='sc-lpzn2g-15 bhGCHf')
    
    text.append(quotes)
    date.append(d)
    name.append(n)
    theme.append(t)
bank = []
for i in column_values:
    bank.append(i.split('/')[2])

# %% [markdown]
#     Собранные данные очищаем с помощью регулярных выражений и на основе них формируем датафрейм.

# %%
n = []
for i in range(0, len(name)):
    string = ' '.join(re.findall(r'[А-Яа-я]+', str(name[i])))
    string = re.sub('</span>','', str(string))
    string = string.capitalize()
    n.append(string)

# %%
d = []
for i in range(0, len(date)):
    string = ' '.join(re.findall(r'...[А-Яа-я]+......', str(date[i])))
    string = re.sub('</span>','', str(string))
    d.append(string)

# %%
u = []
for i in range(0, len(text)):
    string = ' '.join(re.findall(r'[А-Яа-я].+', str(text[i])))
    string = re.sub('</p>','', str(string))
    
    u.append(string)

# %%
t = []
for i in range(0, len(theme)):
    string = ' '.join(re.findall(r'[А-Яа-я]+', str(theme[i])))
    string = re.sub('</span>','', str(string))
    t.append(string)

# %%
u = {"text":u}
df = pd.DataFrame(u)
df['rated'] = 1
df['coloring'] = 'bad'
df['date'] = d
df['bank'] = bank
df['theme'] = t

# %%
nn = []
for i in n:
    i = i.split(' ')
    nn.append(i[0])

# %% [markdown]
#     Для возможности проведения большего количества статистических исследований на основе корпуса было принято решение добавить колонку с полом пользователя. Для определения пола пользователя мы сохранили списки женских и мужских имен с сайта Википедия. По наличию каждого имени датафрейма в этих списках проставляем теги ‘female’ для женских имен, ‘male’ для мужских и ‘unkn’ для пользователей, не указавших имя.

# %%
with open('fem.txt', 'r', encoding='utf-8') as f:
        fem = f.read()
fem = re.findall(r'[А-Яа-я]+', str(fem))
with open('male.txt', 'r', encoding='utf-8') as m:
        male = m.read()
male = re.findall(r'[А-Яа-я]+', str(male))

# %%
df['name'] = nn

# %%
def names(name):   
    if name in fem or name == 'Ирина' or name == 'Ольга' or name == 'Надя':
        return 'female'
    elif name in male or name =='Слава':
        return 'male'
    else:
        return 'unkn'
df['sex'] = df['name'].apply(names)

# %%
df = df.drop_duplicates()

# %%
df.to_csv('test_five.csv')
