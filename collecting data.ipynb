# %% [markdown]
# # Сбор текстов с сайта Банки.ру

# %% [markdown]
#     Для реализации большинства алгоритмов анализа тональности необходим обучающий массив данных (набор отзывов, для которых известна эмоциональная окраска). Так как на сегодняшний день существует очень мало публичных русскоязычных коллекций отзывов, которые можно было бы использовать для решения задачи классификации текстов, и не обнаружено ни одной русскоязычной публичной коллекции отзывов о банках, было принято решение подготовить собственный корпус текстов.
#
#     На сайте Банки.ру оценки пользователей напрямую связаны с тональностью текста: оценка «5» соответствует только отзывам, содержащим описание положительных характеристик банка, продукта или услуги или выражение благодарности сотрудникам банка, поэтому данный веб-сайт был выбран для составления корпуса.

# %% [markdown]
# ### Импорт библиотек

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

import nest_asyncio
import aiohttp
import asyncio

# %% [markdown]
# ### Сбор корпуса

# %% [markdown]
#     Изучив структуру сайта Банки.ру, обнаружили, что полный текст каждого отдельного отзыва находится в соответствующем ему HTML-файле, поэтому сначала необходимо собрать все ссылки на необходимые файлы.

# %%
def links(page_number, rate):
    url = f'https://www.banki.ru/services/responses/list/?page={page_number}&is_countable=on&rate={rate}'
    response = requests.get(url, headers={'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'})
    
    if response.status_code != 200:
        print(f"Ошибка при запросе страницы {page_number}: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    links = []
    h3_elements = soup.find_all('h3', class_='text-weight-medium text-size-3 ldecc766d')
    
    for h3 in h3_elements:
        a_element = h3.find('a', class_='link-simple')
        if a_element:
            link = a_element['href']
            full_link = f"https://www.banki.ru{link}" 
            links.append(full_link)
    
    return links

# %%
pos_data = []

for page_number in range(1, 200):
    print(f"Обрабатываем страницу {page_number}...")
    urls = links(page_number=page_number, rate=5)  
    if not urls:  
        break
    pos_data.extend(urls)  

print(f"Собрано ссылок: {len(pos_data)}")
# Out:
# Обрабатываем страницу 1...
# Обрабатываем страницу 2...
# Обрабатываем страницу 3...
# Обрабатываем страницу 4...
# Обрабатываем страницу 5...
# Обрабатываем страницу 6...
# Обрабатываем страницу 7...
# Обрабатываем страницу 8...
# Обрабатываем страницу 9...
# Обрабатываем страницу 10...
# Обрабатываем страницу 11...
# Обрабатываем страницу 12...
# Обрабатываем страницу 13...
# Обрабатываем страницу 14...
# Обрабатываем страницу 15...
# Обрабатываем страницу 16...
# Обрабатываем страницу 17...
# Обрабатываем страницу 18...
# Обрабатываем страницу 19...
# Обрабатываем страницу 20...
# Обрабатываем страницу 21...
# Обрабатываем страницу 22...
# Обрабатываем страницу 23...
# Обрабатываем страницу 24...
# Обрабатываем страницу 25...
# Обрабатываем страницу 26...
# Обрабатываем страницу 27...
# Обрабатываем страницу 28...
# Обрабатываем страницу 29...
# Обрабатываем страницу 30...
# Обрабатываем страницу 31...
# Обрабатываем страницу 32...
# Обрабатываем страницу 33...
# Обрабатываем страницу 34...
# Обрабатываем страницу 35...
# Обрабатываем страницу 36...
# Обрабатываем страницу 37...
# Обрабатываем страницу 38...
# Обрабатываем страницу 39...
# Обрабатываем страницу 40...
# Обрабатываем страницу 41...
# Обрабатываем страницу 42...
# Обрабатываем страницу 43...
# Обрабатываем страницу 44...
# Обрабатываем страницу 45...
# Обрабатываем страницу 46...
# Обрабатываем страницу 47...
# Обрабатываем страницу 48...
# Обрабатываем страницу 49...
# Обрабатываем страницу 50...
# Обрабатываем страницу 51...
# Обрабатываем страницу 52...
# Обрабатываем страницу 53...
# Обрабатываем страницу 54...
# Обрабатываем страницу 55...
# Обрабатываем страницу 56...
# Обрабатываем страницу 57...
# Обрабатываем страницу 58...
# Обрабатываем страницу 59...
# Обрабатываем страницу 60...
# Обрабатываем страницу 61...
# Обрабатываем страницу 62...
# Обрабатываем страницу 63...
# Обрабатываем страницу 64...
# Обрабатываем страницу 65...
# Обрабатываем страницу 66...
# Обрабатываем страницу 67...
# Обрабатываем страницу 68...
# Обрабатываем страницу 69...
# Обрабатываем страницу 70...
# Обрабатываем страницу 71...
# Обрабатываем страницу 72...
# Обрабатываем страницу 73...
# Обрабатываем страницу 74...
# Обрабатываем страницу 75...
# Обрабатываем страницу 76...
# Обрабатываем страницу 77...
# Обрабатываем страницу 78...
# Обрабатываем страницу 79...
# Обрабатываем страницу 80...
# Обрабатываем страницу 81...
# Обрабатываем страницу 82...
# Обрабатываем страницу 83...
# Обрабатываем страницу 84...
# Обрабатываем страницу 85...
# Обрабатываем страницу 86...
# Обрабатываем страницу 87...
# Обрабатываем страницу 88...
# Обрабатываем страницу 89...
# Обрабатываем страницу 90...
# Обрабатываем страницу 91...
# Обрабатываем страницу 92...
# Обрабатываем страницу 93...
# Обрабатываем страницу 94...
# Обрабатываем страницу 95...
# Обрабатываем страницу 96...
# Обрабатываем страницу 97...
# Обрабатываем страницу 98...
# Обрабатываем страницу 99...
# Обрабатываем страницу 100...
# Обрабатываем страницу 101...
# Обрабатываем страницу 102...
# Обрабатываем страницу 103...
# Обрабатываем страницу 104...
# Обрабатываем страницу 105...
# Обрабатываем страницу 106...
# Обрабатываем страницу 107...
# Обрабатываем страницу 108...
# Обрабатываем страницу 109...
# Обрабатываем страницу 110...
# Обрабатываем страницу 111...
# Обрабатываем страницу 112...
# Обрабатываем страницу 113...
# Обрабатываем страницу 114...
# Обрабатываем страницу 115...
# Обрабатываем страницу 116...
# Обрабатываем страницу 117...
# Обрабатываем страницу 118...
# Обрабатываем страницу 119...
# Обрабатываем страницу 120...
# Обрабатываем страницу 121...
# Обрабатываем страницу 122...
# Обрабатываем страницу 123...
# Обрабатываем страницу 124...
# Обрабатываем страницу 125...
# Обрабатываем страницу 126...
# Обрабатываем страницу 127...
# Обрабатываем страницу 128...
# Обрабатываем страницу 129...
# Обрабатываем страницу 130...
# Обрабатываем страницу 131...
# Обрабатываем страницу 132...
# Обрабатываем страницу 133...
# Обрабатываем страницу 134...
# Обрабатываем страницу 135...
# Обрабатываем страницу 136...
# Обрабатываем страницу 137...
# Обрабатываем страницу 138...
# Обрабатываем страницу 139...
# Обрабатываем страницу 140...
# Обрабатываем страницу 141...
# Обрабатываем страницу 142...
# Обрабатываем страницу 143...
# Обрабатываем страницу 144...
# Обрабатываем страницу 145...
# Обрабатываем страницу 146...
# Обрабатываем страницу 147...
# Обрабатываем страницу 148...
# Обрабатываем страницу 149...
# Обрабатываем страницу 150...
# Обрабатываем страницу 151...
# Обрабатываем страницу 152...
# Обрабатываем страницу 153...
# Обрабатываем страницу 154...
# Обрабатываем страницу 155...
# Обрабатываем страницу 156...
# Обрабатываем страницу 157...
# Обрабатываем страницу 158...
# Обрабатываем страницу 159...
# Обрабатываем страницу 160...
# Обрабатываем страницу 161...
# Обрабатываем страницу 162...
# Обрабатываем страницу 163...
# Обрабатываем страницу 164...
# Обрабатываем страницу 165...
# Обрабатываем страницу 166...
# Обрабатываем страницу 167...
# Обрабатываем страницу 168...
# Обрабатываем страницу 169...
# Обрабатываем страницу 170...
# Обрабатываем страницу 171...
# Обрабатываем страницу 172...
# Обрабатываем страницу 173...
# Обрабатываем страницу 174...
# Обрабатываем страницу 175...
# Обрабатываем страницу 176...
# Обрабатываем страницу 177...
# Обрабатываем страницу 178...
# Обрабатываем страницу 179...
# Обрабатываем страницу 180...
# Обрабатываем страницу 181...
# Обрабатываем страницу 182...
# Обрабатываем страницу 183...
# Обрабатываем страницу 184...
# Обрабатываем страницу 185...
# Обрабатываем страницу 186...
# Обрабатываем страницу 187...
# Обрабатываем страницу 188...
# Обрабатываем страницу 189...
# Обрабатываем страницу 190...
# Обрабатываем страницу 191...
# Обрабатываем страницу 192...
# Обрабатываем страницу 193...
# Обрабатываем страницу 194...
# Обрабатываем страницу 195...
# Обрабатываем страницу 196...
# Обрабатываем страницу 197...
# Обрабатываем страницу 198...
# Обрабатываем страницу 199...
# Собрано ссылок: 4975

# %%
neg_data = []

for page_number in range(1, 200):
    print(f"Обрабатываем страницу {page_number}...")
    urls = links(page_number=page_number, rate=1)  
    if not urls:  
        break
    neg_data.extend(urls)  

print(f"Собрано ссылок: {len(pos_data)}")
# Out:
# Обрабатываем страницу 1...
# Обрабатываем страницу 2...
# Обрабатываем страницу 3...
# Обрабатываем страницу 4...
# Обрабатываем страницу 5...
# Обрабатываем страницу 6...
# Обрабатываем страницу 7...
# Обрабатываем страницу 8...
# Обрабатываем страницу 9...
# Обрабатываем страницу 10...
# Обрабатываем страницу 11...
# Обрабатываем страницу 12...
# Обрабатываем страницу 13...
# Обрабатываем страницу 14...
# Обрабатываем страницу 15...
# Обрабатываем страницу 16...
# Обрабатываем страницу 17...
# Обрабатываем страницу 18...
# Обрабатываем страницу 19...
# Обрабатываем страницу 20...
# Обрабатываем страницу 21...
# Обрабатываем страницу 22...
# Обрабатываем страницу 23...
# Обрабатываем страницу 24...
# Обрабатываем страницу 25...
# Обрабатываем страницу 26...
# Обрабатываем страницу 27...
# Обрабатываем страницу 28...
# Обрабатываем страницу 29...
# Обрабатываем страницу 30...
# Обрабатываем страницу 31...
# Обрабатываем страницу 32...
# Обрабатываем страницу 33...
# Обрабатываем страницу 34...
# Обрабатываем страницу 35...
# Обрабатываем страницу 36...
# Обрабатываем страницу 37...
# Обрабатываем страницу 38...
# Обрабатываем страницу 39...
# Обрабатываем страницу 40...
# Обрабатываем страницу 41...
# Обрабатываем страницу 42...
# Обрабатываем страницу 43...
# Обрабатываем страницу 44...
# Обрабатываем страницу 45...
# Обрабатываем страницу 46...
# Обрабатываем страницу 47...
# Обрабатываем страницу 48...
# Обрабатываем страницу 49...
# Обрабатываем страницу 50...
# Обрабатываем страницу 51...
# Обрабатываем страницу 52...
# Обрабатываем страницу 53...
# Обрабатываем страницу 54...
# Обрабатываем страницу 55...
# Обрабатываем страницу 56...
# Обрабатываем страницу 57...
# Обрабатываем страницу 58...
# Обрабатываем страницу 59...
# Обрабатываем страницу 60...
# Обрабатываем страницу 61...
# Обрабатываем страницу 62...
# Обрабатываем страницу 63...
# Обрабатываем страницу 64...
# Обрабатываем страницу 65...
# Обрабатываем страницу 66...
# Обрабатываем страницу 67...
# Обрабатываем страницу 68...
# Обрабатываем страницу 69...
# Обрабатываем страницу 70...
# Обрабатываем страницу 71...
# Обрабатываем страницу 72...
# Обрабатываем страницу 73...
# Обрабатываем страницу 74...
# Обрабатываем страницу 75...
# Обрабатываем страницу 76...
# Обрабатываем страницу 77...
# Обрабатываем страницу 78...
# Обрабатываем страницу 79...
# Обрабатываем страницу 80...
# Обрабатываем страницу 81...
# Обрабатываем страницу 82...
# Обрабатываем страницу 83...
# Обрабатываем страницу 84...
# Обрабатываем страницу 85...
# Обрабатываем страницу 86...
# Обрабатываем страницу 87...
# Обрабатываем страницу 88...
# Обрабатываем страницу 89...
# Обрабатываем страницу 90...
# Обрабатываем страницу 91...
# Обрабатываем страницу 92...
# Обрабатываем страницу 93...
# Обрабатываем страницу 94...
# Обрабатываем страницу 95...
# Обрабатываем страницу 96...
# Обрабатываем страницу 97...
# Обрабатываем страницу 98...
# Обрабатываем страницу 99...
# Обрабатываем страницу 100...
# Обрабатываем страницу 101...
# Обрабатываем страницу 102...
# Обрабатываем страницу 103...
# Обрабатываем страницу 104...
# Обрабатываем страницу 105...
# Обрабатываем страницу 106...
# Обрабатываем страницу 107...
# Обрабатываем страницу 108...
# Обрабатываем страницу 109...
# Обрабатываем страницу 110...
# Обрабатываем страницу 111...
# Обрабатываем страницу 112...
# Обрабатываем страницу 113...
# Обрабатываем страницу 114...
# Обрабатываем страницу 115...
# Обрабатываем страницу 116...
# Обрабатываем страницу 117...
# Обрабатываем страницу 118...
# Обрабатываем страницу 119...
# Обрабатываем страницу 120...
# Обрабатываем страницу 121...
# Обрабатываем страницу 122...
# Обрабатываем страницу 123...
# Обрабатываем страницу 124...
# Обрабатываем страницу 125...
# Обрабатываем страницу 126...
# Обрабатываем страницу 127...
# Обрабатываем страницу 128...
# Обрабатываем страницу 129...
# Обрабатываем страницу 130...
# Обрабатываем страницу 131...
# Обрабатываем страницу 132...
# Обрабатываем страницу 133...
# Обрабатываем страницу 134...
# Обрабатываем страницу 135...
# Обрабатываем страницу 136...
# Обрабатываем страницу 137...
# Обрабатываем страницу 138...
# Обрабатываем страницу 139...
# Обрабатываем страницу 140...
# Обрабатываем страницу 141...
# Обрабатываем страницу 142...
# Обрабатываем страницу 143...
# Обрабатываем страницу 144...
# Обрабатываем страницу 145...
# Обрабатываем страницу 146...
# Обрабатываем страницу 147...
# Обрабатываем страницу 148...
# Обрабатываем страницу 149...
# Обрабатываем страницу 150...
# Обрабатываем страницу 151...
# Обрабатываем страницу 152...
# Обрабатываем страницу 153...
# Обрабатываем страницу 154...
# Обрабатываем страницу 155...
# Обрабатываем страницу 156...
# Обрабатываем страницу 157...
# Обрабатываем страницу 158...
# Обрабатываем страницу 159...
# Обрабатываем страницу 160...
# Обрабатываем страницу 161...
# Обрабатываем страницу 162...
# Обрабатываем страницу 163...
# Обрабатываем страницу 164...
# Обрабатываем страницу 165...
# Обрабатываем страницу 166...
# Обрабатываем страницу 167...
# Обрабатываем страницу 168...
# Обрабатываем страницу 169...
# Обрабатываем страницу 170...
# Обрабатываем страницу 171...
# Обрабатываем страницу 172...
# Обрабатываем страницу 173...
# Обрабатываем страницу 174...
# Обрабатываем страницу 175...
# Обрабатываем страницу 176...
# Обрабатываем страницу 177...
# Обрабатываем страницу 178...
# Обрабатываем страницу 179...
# Обрабатываем страницу 180...
# Обрабатываем страницу 181...
# Обрабатываем страницу 182...
# Обрабатываем страницу 183...
# Обрабатываем страницу 184...
# Обрабатываем страницу 185...
# Обрабатываем страницу 186...
# Обрабатываем страницу 187...
# Обрабатываем страницу 188...
# Обрабатываем страницу 189...
# Обрабатываем страницу 190...
# Обрабатываем страницу 191...
# Обрабатываем страницу 192...
# Обрабатываем страницу 193...
# Обрабатываем страницу 194...
# Обрабатываем страницу 195...
# Обрабатываем страницу 196...
# Обрабатываем страницу 197...
# Обрабатываем страницу 198...
# Обрабатываем страницу 199...
# Собрано ссылок: 4975

# %%
pos_data[:10]
# Out:
# ['https://www.banki.ru/services/responses/bank/response/11747735/',
#  'https://www.banki.ru/services/responses/bank/response/11746786/',
#  'https://www.banki.ru/services/responses/bank/response/11745617/',
#  'https://www.banki.ru/services/responses/bank/response/11745592/',
#  'https://www.banki.ru/services/responses/bank/response/11745555/',
#  'https://www.banki.ru/services/responses/bank/response/11745506/',
#  'https://www.banki.ru/services/responses/bank/response/11743852/',
#  'https://www.banki.ru/services/responses/bank/response/11743442/',
#  'https://www.banki.ru/services/responses/bank/response/11743377/',
#  'https://www.banki.ru/services/responses/bank/response/11743050/']

# %%
neg_data[:10]
# Out:
# ['https://www.banki.ru/services/responses/bank/response/11748640/',
#  'https://www.banki.ru/services/responses/bank/response/11747156/',
#  'https://www.banki.ru/services/responses/bank/response/11745363/',
#  'https://www.banki.ru/services/responses/bank/response/11744968/',
#  'https://www.banki.ru/services/responses/bank/response/11744538/',
#  'https://www.banki.ru/services/responses/bank/response/11744500/',
#  'https://www.banki.ru/services/responses/bank/response/11744160/',
#  'https://www.banki.ru/services/responses/bank/response/11743394/',
#  'https://www.banki.ru/services/responses/bank/response/11743198/',
#  'https://www.banki.ru/services/responses/bank/response/11743172/']

# %% [markdown]
#     Далее, тем же методом с кода страниц, находящихся по каждой из полученных ссылок, сохраняем сам текст отзыва  и соответствующие ему метаданные, а именно: дату написания отзыва, тему обращения, название банка и город.

# %%
nest_asyncio.apply()  

async def fetch(session, url):
    async with session.get(url, headers={'User-agent': 'Mozilla/5.0'}) as response:
        return await response.text()

async def bank_data(urls):
    async with aiohttp.ClientSession() as session:
        tasks = [fetch(session, url) for url in urls]
        pages = await asyncio.gather(*tasks)
        a = 0

        results = []
        for a, page in enumerate(pages):
            if page:
                print(f"Обрабатываем ссылку {a + 1} / 4975...")
                soup = BeautifulSoup(page, 'html.parser')

                text = [div.text for div in soup.find_all('div', class_='lb1789875 markdown-inside markdown-inside--list-type_circle-fill')]
                date = soup.find_all('span', class_='l10fac986')[0].text if soup.find_all('span', class_='l10fac986') else None
                city = [span.text for span in soup.find_all('span', class_='l3a372298')]
                bank_name = [div.text for div in soup.find_all('div', class_='l5b3cd260')]
                theme = soup.find_all('h1', class_='text-header-0 le856f50c')[0].text if soup.find_all('h1', class_='text-header-0 le856f50c') else None

                results.append({
                    'url': urls[a],
                    'text': text,
                    'date': date,
                    'city': city,
                    'bank_name': bank_name,
                    'theme': theme
                })

        return results


urls = [i for i in pos_data]
results_pos = await bank_data(urls)
# Out:
# Обрабатываем ссылку 1 / 4975...
# Обрабатываем ссылку 2 / 4975...
# Обрабатываем ссылку 3 / 4975...
# Обрабатываем ссылку 4 / 4975...
# Обрабатываем ссылку 5 / 4975...
# Обрабатываем ссылку 6 / 4975...
# Обрабатываем ссылку 7 / 4975...
# Обрабатываем ссылку 8 / 4975...
# Обрабатываем ссылку 9 / 4975...
# Обрабатываем ссылку 10 / 4975...
# Обрабатываем ссылку 11 / 4975...
# Обрабатываем ссылку 12 / 4975...
# Обрабатываем ссылку 13 / 4975...
# Обрабатываем ссылку 14 / 4975...
# Обрабатываем ссылку 15 / 4975...
# Обрабатываем ссылку 16 / 4975...
# Обрабатываем ссылку 17 / 4975...
# Обрабатываем ссылку 18 / 4975...
# Обрабатываем ссылку 19 / 4975...
# Обрабатываем ссылку 20 / 4975...
# Обрабатываем ссылку 21 / 4975...
# Обрабатываем ссылку 22 / 4975...
# Обрабатываем ссылку 23 / 4975...
# Обрабатываем ссылку 24 / 4975...
# Обрабатываем ссылку 25 / 4975...
# Обрабатываем ссылку 26 / 4975...
# Обрабатываем ссылку 27 / 4975...
# Обрабатываем ссылку 28 / 4975...
# Обрабатываем ссылку 29 / 4975...
# Обрабатываем ссылку 30 / 4975...
# Обрабатываем ссылку 31 / 4975...
# Обрабатываем ссылку 32 / 4975...
# Обрабатываем ссылку 33 / 4975...
# Обрабатываем ссылку 34 / 4975...
# Обрабатываем ссылку 35 / 4975...
# Обрабатываем ссылку 36 / 4975...
# Обрабатываем ссылку 37 / 4975...
# Обрабатываем ссылку 38 / 4975...
# Обрабатываем ссылку 39 / 4975...
# Обрабатываем ссылку 40 / 4975...
# Обрабатываем ссылку 41 / 4975...
# Обрабатываем ссылку 42 / 4975...
# Обрабатываем ссылку 43 / 4975...
# Обрабатываем ссылку 44 / 4975...
# Обрабатываем ссылку 45 / 4975...
# Обрабатываем ссылку 46 / 4975...
# Обрабатываем ссылку 47 / 4975...
# Обрабатываем ссылку 48 / 4975...
# Обрабатываем ссылку 49 / 4975...
# Обрабатываем ссылку 50 / 4975...
# Обрабатываем ссылку 51 / 4975...
# Обрабатываем ссылку 52 / 4975...
# Обрабатываем ссылку 53 / 4975...
# Обрабатываем ссылку 54 / 4975...
# Обрабатываем ссылку 55 / 4975...
# Обрабатываем ссылку 56 / 4975...
# Обрабатываем ссылку 57 / 4975...
# Обрабатываем ссылку 58 / 4975...
# Обрабатываем ссылку 59 / 4975...
# Обрабатываем ссылку 60 / 4975...
# Обрабатываем ссылку 61 / 4975...
# Обрабатываем ссылку 62 / 4975...
# Обрабатываем ссылку 63 / 4975...
# Обрабатываем ссылку 64 / 4975...
# Обрабатываем ссылку 65 / 4975...
# Обрабатываем ссылку 66 / 4975...
# Обрабатываем ссылку 67 / 4975...
# Обрабатываем ссылку 68 / 4975...
# Обрабатываем ссылку 69 / 4975...
# Обрабатываем ссылку 70 / 4975...
# Обрабатываем ссылку 71 / 4975...
# Обрабатываем ссылку 72 / 4975...
# Обрабатываем ссылку 73 / 4975...
# Обрабатываем ссылку 74 / 4975...
# Обрабатываем ссылку 75 / 4975...
# Обрабатываем ссылку 76 / 4975...
# Обрабатываем ссылку 77 / 4975...
# Обрабатываем ссылку 78 / 4975...
# Обрабатываем ссылку 79 / 4975...
# Обрабатываем ссылку 80 / 4975...
# Обрабатываем ссылку 81 / 4975...
# Обрабатываем ссылку 82 / 4975...
# Обрабатываем ссылку 83 / 4975...
# Обрабатываем ссылку 84 / 4975...
# Обрабатываем ссылку 85 / 4975...
# Обрабатываем ссылку 86 / 4975...
# Обрабатываем ссылку 87 / 4975...
# Обрабатываем ссылку 88 / 4975...
# Обрабатываем ссылку 89 / 4975...
# Обрабатываем ссылку 90 / 4975...
# Обрабатываем ссылку 91 / 4975...
# Обрабатываем ссылку 92 / 4975...
# Обрабатываем ссылку 93 / 4975...
# Обрабатываем ссылку 94 / 4975...
# Обрабатываем ссылку 95 / 4975...
# Обрабатываем ссылку 96 / 4975...
# Обрабатываем ссылку 97 / 4975...
# Обрабатываем ссылку 98 / 4975...
# Обрабатываем ссылку 99 / 4975...
# Обрабатываем ссылку 100 / 4975...
# Обрабатываем ссылку 101 / 4975...
# Обрабатываем ссылку 102 / 4975...
# Обрабатываем ссылку 103 / 4975...
# Обрабатываем ссылку 104 / 4975...
# Обрабатываем ссылку 105 / 4975...
# Обрабатываем ссылку 106 / 4975...
# Обрабатываем ссылку 107 / 4975...
# Обрабатываем ссылку 108 / 4975...
# Обрабатываем ссылку 109 / 4975...
# Обрабатываем ссылку 110 / 4975...
# Обрабатываем ссылку 111 / 4975...
# Обрабатываем ссылку 112 / 4975...
# Обрабатываем ссылку 113 / 4975...
# Обрабатываем ссылку 114 / 4975...
# Обрабатываем ссылку 115 / 4975...
# Обрабатываем ссылку 116 / 4975...
# Обрабатываем ссылку 117 / 4975...
# Обрабатываем ссылку 118 / 4975...
# Обрабатываем ссылку 119 / 4975...
# Обрабатываем ссылку 120 / 4975...
# Обрабатываем ссылку 121 / 4975...
# Обрабатываем ссылку 122 / 4975...
# Обрабатываем ссылку 123 / 4975...
# Обрабатываем ссылку 124 / 4975...
# Обрабатываем ссылку 125 / 4975...
# Обрабатываем ссылку 126 / 4975...
# Обрабатываем ссылку 127 / 4975...
# Обрабатываем ссылку 128 / 4975...
# Обрабатываем ссылку 129 / 4975...
# Обрабатываем ссылку 130 / 4975...
# Обрабатываем ссылку 131 / 4975...
# Обрабатываем ссылку 132 / 4975...
# Обрабатываем ссылку 133 / 4975...
# Обрабатываем ссылку 134 / 4975...
# Обрабатываем ссылку 135 / 4975...
# Обрабатываем ссылку 136 / 4975...
# Обрабатываем ссылку 137 / 4975...
# Обрабатываем ссылку 138 / 4975...
# Обрабатываем ссылку 139 / 4975...
# Обрабатываем ссылку 140 / 4975...
# Обрабатываем ссылку 141 / 4975...
# Обрабатываем ссылку 142 / 4975...
# Обрабатываем ссылку 143 / 4975...
# Обрабатываем ссылку 144 / 4975...
# Обрабатываем ссылку 145 / 4975...
# Обрабатываем ссылку 146 / 4975...
# Обрабатываем ссылку 147 / 4975...
# Обрабатываем ссылку 148 / 4975...
# Обрабатываем ссылку 149 / 4975...
# Обрабатываем ссылку 150 / 4975...
# Обрабатываем ссылку 151 / 4975...
# Обрабатываем ссылку 152 / 4975...
# Обрабатываем ссылку 153 / 4975...
# Обрабатываем ссылку 154 / 4975...
# Обрабатываем ссылку 155 / 4975...
# Обрабатываем ссылку 156 / 4975...
# Обрабатываем ссылку 157 / 4975...
# Обрабатываем ссылку 158 / 4975...
# Обрабатываем ссылку 159 / 4975...
# Обрабатываем ссылку 160 / 4975...
# Обрабатываем ссылку 161 / 4975...
# Обрабатываем ссылку 162 / 4975...
# Обрабатываем ссылку 163 / 4975...
# Обрабатываем ссылку 164 / 4975...
# Обрабатываем ссылку 165 / 4975...
# Обрабатываем ссылку 166 / 4975...
# Обрабатываем ссылку 167 / 4975...
# Обрабатываем ссылку 168 / 4975...
# Обрабатываем ссылку 169 / 4975...
# Обрабатываем ссылку 170 / 4975...
# Обрабатываем ссылку 171 / 4975...
# Обрабатываем ссылку 172 / 4975...
# Обрабатываем ссылку 173 / 4975...
# Обрабатываем ссылку 174 / 4975...
# Обрабатываем ссылку 175 / 4975...
# Обрабатываем ссылку 176 / 4975...
# Обрабатываем ссылку 177 / 4975...
# Обрабатываем ссылку 178 / 4975...
# Обрабатываем ссылку 179 / 4975...
# Обрабатываем ссылку 180 / 4975...
# Обрабатываем ссылку 181 / 4975...
# Обрабатываем ссылку 182 / 4975...
# Обрабатываем ссылку 183 / 4975...
# Обрабатываем ссылку 184 / 4975...
# Обрабатываем ссылку 185 / 4975...
# Обрабатываем ссылку 186 / 4975...
# Обрабатываем ссылку 187 / 4975...
# Обрабатываем ссылку 188 / 4975...
# Обрабатываем ссылку 189 / 4975...
# Обрабатываем ссылку 190 / 4975...
# Обрабатываем ссылку 191 / 4975...
# Обрабатываем ссылку 192 / 4975...
# Обрабатываем ссылку 193 / 4975...
# Обрабатываем ссылку 194 / 4975...
# Обрабатываем ссылку 195 / 4975...
# Обрабатываем ссылку 196 / 4975...
# Обрабатываем ссылку 197 / 4975...
# Обрабатываем ссылку 198 / 4975...
# Обрабатываем ссылку 199 / 4975...
# Обрабатываем ссылку 200 / 4975...
# Обрабатываем ссылку 201 / 4975...
# Обрабатываем ссылку 202 / 4975...
# Обрабатываем ссылку 203 / 4975...
# Обрабатываем ссылку 204 / 4975...
# Обрабатываем ссылку 205 / 4975...
# Обрабатываем ссылку 206 / 4975...
# Обрабатываем ссылку 207 / 4975...
# Обрабатываем ссылку 208 / 4975...
# Обрабатываем ссылку 209 / 4975...
# Обрабатываем ссылку 210 / 4975...
# Обрабатываем ссылку 211 / 4975...
# Обрабатываем ссылку 212 / 4975...
# Обрабатываем ссылку 213 / 4975...
# Обрабатываем ссылку 214 / 4975...
# Обрабатываем ссылку 215 / 4975...
# Обрабатываем ссылку 216 / 4975...
# Обрабатываем ссылку 217 / 4975...
# Обрабатываем ссылку 218 / 4975...
# Обрабатываем ссылку 219 / 4975...
# Обрабатываем ссылку 220 / 4975...
# Обрабатываем ссылку 221 / 4975...
# Обрабатываем ссылку 222 / 4975...
# Обрабатываем ссылку 223 / 4975...
# Обрабатываем ссылку 224 / 4975...
# Обрабатываем ссылку 225 / 4975...
# Обрабатываем ссылку 226 / 4975...
# Обрабатываем ссылку 227 / 4975...
# Обрабатываем ссылку 228 / 4975...
# Обрабатываем ссылку 229 / 4975...
# Обрабатываем ссылку 230 / 4975...
# Обрабатываем ссылку 231 / 4975...
# Обрабатываем ссылку 232 / 4975...
# Обрабатываем ссылку 233 / 4975...
# Обрабатываем ссылку 234 / 4975...
# Обрабатываем ссылку 235 / 4975...
# Обрабатываем ссылку 236 / 4975...
# Обрабатываем ссылку 237 / 4975...
# Обрабатываем ссылку 238 / 4975...
# Обрабатываем ссылку 239 / 4975...
# Обрабатываем ссылку 240 / 4975...
# Обрабатываем ссылку 241 / 4975...
# Обрабатываем ссылку 242 / 4975...
# Обрабатываем ссылку 243 / 4975...
# Обрабатываем ссылку 244 / 4975...
# Обрабатываем ссылку 245 / 4975...
# Обрабатываем ссылку 246 / 4975...
# Обрабатываем ссылку 247 / 4975...
# Обрабатываем ссылку 248 / 4975...
# Обрабатываем ссылку 249 / 4975...
# Обрабатываем ссылку 250 / 4975...
# Обрабатываем ссылку 251 / 4975...
# Обрабатываем ссылку 252 / 4975...
# Обрабатываем ссылку 253 / 4975...
# Обрабатываем ссылку 254 / 4975...
# Обрабатываем ссылку 255 / 4975...
# Обрабатываем ссылку 256 / 4975...
# Обрабатываем ссылку 257 / 4975...
# Обрабатываем ссылку 258 / 4975...
# Обрабатываем ссылку 259 / 4975...
# Обрабатываем ссылку 260 / 4975...
# Обрабатываем ссылку 261 / 4975...
# Обрабатываем ссылку 262 / 4975...
# Обрабатываем ссылку 263 / 4975...
# Обрабатываем ссылку 264 / 4975...
# Обрабатываем ссылку 265 / 4975...
# Обрабатываем ссылку 266 / 4975...
# Обрабатываем ссылку 267 / 4975...
# Обрабатываем ссылку 268 / 4975...
# Обрабатываем ссылку 269 / 4975...
# Обрабатываем ссылку 270 / 4975...
# Обрабатываем ссылку 271 / 4975...
# Обрабатываем ссылку 272 / 4975...
# Обрабатываем ссылку 273 / 4975...
# Обрабатываем ссылку 274 / 4975...
# Обрабатываем ссылку 275 / 4975...
# Обрабатываем ссылку 276 / 4975...
# Обрабатываем ссылку 277 / 4975...
# Обрабатываем ссылку 278 / 4975...
# Обрабатываем ссылку 279 / 4975...
# Обрабатываем ссылку 280 / 4975...
# Обрабатываем ссылку 281 / 4975...
# Обрабатываем ссылку 282 / 4975...
# Обрабатываем ссылку 283 / 4975...
# Обрабатываем ссылку 284 / 4975...
# Обрабатываем ссылку 285 / 4975...
# Обрабатываем ссылку 286 / 4975...
# Обрабатываем ссылку 287 / 4975...
# Обрабатываем ссылку 288 / 4975...
# Обрабатываем ссылку 289 / 4975...
# Обрабатываем ссылку 290 / 4975...
# Обрабатываем ссылку 291 / 4975...
# Обрабатываем ссылку 292 / 4975...
# Обрабатываем ссылку 293 / 4975...
# Обрабатываем ссылку 294 / 4975...
# Обрабатываем ссылку 295 / 4975...
# Обрабатываем ссылку 296 / 4975...
# Обрабатываем ссылку 297 / 4975...
# Обрабатываем ссылку 298 / 4975...
# Обрабатываем ссылку 299 / 4975...
# Обрабатываем ссылку 300 / 4975...
# Обрабатываем ссылку 301 / 4975...
# Обрабатываем ссылку 302 / 4975...
# Обрабатываем ссылку 303 / 4975...
# Обрабатываем ссылку 304 / 4975...
# Обрабатываем ссылку 305 / 4975...
# Обрабатываем ссылку 306 / 4975...
# Обрабатываем ссылку 307 / 4975...
# Обрабатываем ссылку 308 / 4975...
# Обрабатываем ссылку 309 / 4975...
# Обрабатываем ссылку 310 / 4975...
# Обрабатываем ссылку 311 / 4975...
# Обрабатываем ссылку 312 / 4975...
# Обрабатываем ссылку 313 / 4975...
# Обрабатываем ссылку 314 / 4975...
# Обрабатываем ссылку 315 / 4975...
# Обрабатываем ссылку 316 / 4975...
# Обрабатываем ссылку 317 / 4975...
# Обрабатываем ссылку 318 / 4975...
# Обрабатываем ссылку 319 / 4975...
# Обрабатываем ссылку 320 / 4975...
# Обрабатываем ссылку 321 / 4975...
# Обрабатываем ссылку 322 / 4975...
# Обрабатываем ссылку 323 / 4975...
# Обрабатываем ссылку 324 / 4975...
# Обрабатываем ссылку 325 / 4975...
# Обрабатываем ссылку 326 / 4975...
# Обрабатываем ссылку 327 / 4975...
# Обрабатываем ссылку 328 / 4975...
# Обрабатываем ссылку 329 / 4975...
# Обрабатываем ссылку 330 / 4975...
# Обрабатываем ссылку 331 / 4975...
# Обрабатываем ссылку 332 / 4975...
# Обрабатываем ссылку 333 / 4975...
# Обрабатываем ссылку 334 / 4975...
# Обрабатываем ссылку 335 / 4975...
# Обрабатываем ссылку 336 / 4975...
# Обрабатываем ссылку 337 / 4975...
# Обрабатываем ссылку 338 / 4975...
# Обрабатываем ссылку 339 / 4975...
# Обрабатываем ссылку 340 / 4975...
# Обрабатываем ссылку 341 / 4975...
# Обрабатываем ссылку 342 / 4975...
# Обрабатываем ссылку 343 / 4975...
# Обрабатываем ссылку 344 / 4975...
# Обрабатываем ссылку 345 / 4975...
# Обрабатываем ссылку 346 / 4975...
# Обрабатываем ссылку 347 / 4975...
# Обрабатываем ссылку 348 / 4975...
# Обрабатываем ссылку 349 / 4975...
# Обрабатываем ссылку 350 / 4975...
# Обрабатываем ссылку 351 / 4975...
# Обрабатываем ссылку 352 / 4975...
# Обрабатываем ссылку 353 / 4975...
# Обрабатываем ссылку 354 / 4975...
# Обрабатываем ссылку 355 / 4975...
# Обрабатываем ссылку 356 / 4975...
# Обрабатываем ссылку 357 / 4975...
# Обрабатываем ссылку 358 / 4975...
# Обрабатываем ссылку 359 / 4975...
# Обрабатываем ссылку 360 / 4975...
# Обрабатываем ссылку 361 / 4975...
# Обрабатываем ссылку 362 / 4975...
# Обрабатываем ссылку 363 / 4975...
# Обрабатываем ссылку 364 / 4975...
# Обрабатываем ссылку 365 / 4975...
# Обрабатываем ссылку 366 / 4975...
# Обрабатываем ссылку 367 / 4975...
# Обрабатываем ссылку 368 / 4975...
# Обрабатываем ссылку 369 / 4975...
# Обрабатываем ссылку 370 / 4975...
# Обрабатываем ссылку 371 / 4975...
# Обрабатываем ссылку 372 / 4975...
# Обрабатываем ссылку 373 / 4975...
# Обрабатываем ссылку 374 / 4975...
# Обрабатываем ссылку 375 / 4975...
# Обрабатываем ссылку 376 / 4975...
# Обрабатываем ссылку 377 / 4975...
# Обрабатываем ссылку 378 / 4975...
# Обрабатываем ссылку 379 / 4975...
# Обрабатываем ссылку 380 / 4975...
# Обрабатываем ссылку 381 / 4975...
# Обрабатываем ссылку 382 / 4975...
# Обрабатываем ссылку 383 / 4975...
# Обрабатываем ссылку 384 / 4975...
# Обрабатываем ссылку 385 / 4975...
# Обрабатываем ссылку 386 / 4975...
# Обрабатываем ссылку 387 / 4975...
# Обрабатываем ссылку 388 / 4975...
# Обрабатываем ссылку 389 / 4975...
# Обрабатываем ссылку 390 / 4975...
# Обрабатываем ссылку 391 / 4975...
# Обрабатываем ссылку 392 / 4975...
# Обрабатываем ссылку 393 / 4975...
# Обрабатываем ссылку 394 / 4975...
# Обрабатываем ссылку 395 / 4975...
# Обрабатываем ссылку 396 / 4975...
# Обрабатываем ссылку 397 / 4975...
# Обрабатываем ссылку 398 / 4975...
# Обрабатываем ссылку 399 / 4975...
# Обрабатываем ссылку 400 / 4975...
# Обрабатываем ссылку 401 / 4975...
# Обрабатываем ссылку 402 / 4975...
# Обрабатываем ссылку 403 / 4975...
# Обрабатываем ссылку 404 / 4975...
# Обрабатываем ссылку 405 / 4975...
# Обрабатываем ссылку 406 / 4975...
# Обрабатываем ссылку 407 / 4975...
# Обрабатываем ссылку 408 / 4975...
# Обрабатываем ссылку 409 / 4975...
# Обрабатываем ссылку 410 / 4975...
# Обрабатываем ссылку 411 / 4975...
# Обрабатываем ссылку 412 / 4975...
# Обрабатываем ссылку 413 / 4975...
# Обрабатываем ссылку 414 / 4975...
# Обрабатываем ссылку 415 / 4975...
# Обрабатываем ссылку 416 / 4975...
# Обрабатываем ссылку 417 / 4975...
# Обрабатываем ссылку 418 / 4975...
# Обрабатываем ссылку 419 / 4975...
# Обрабатываем ссылку 420 / 4975...
# Обрабатываем ссылку 421 / 4975...
# Обрабатываем ссылку 422 / 4975...
# Обрабатываем ссылку 423 / 4975...
# Обрабатываем ссылку 424 / 4975...
# Обрабатываем ссылку 425 / 4975...
# Обрабатываем ссылку 426 / 4975...
# Обрабатываем ссылку 427 / 4975...
# Обрабатываем ссылку 428 / 4975...
# Обрабатываем ссылку 429 / 4975...
# Обрабатываем ссылку 430 / 4975...
# Обрабатываем ссылку 431 / 4975...
# Обрабатываем ссылку 432 / 4975...
# Обрабатываем ссылку 433 / 4975...
# Обрабатываем ссылку 434 / 4975...
# Обрабатываем ссылку 435 / 4975...
# Обрабатываем ссылку 436 / 4975...
# Обрабатываем ссылку 437 / 4975...
# Обрабатываем ссылку 438 / 4975...
# Обрабатываем ссылку 439 / 4975...
# Обрабатываем ссылку 440 / 4975...
# Обрабатываем ссылку 441 / 4975...
# Обрабатываем ссылку 442 / 4975...
# Обрабатываем ссылку 443 / 4975...
# Обрабатываем ссылку 444 / 4975...
# Обрабатываем ссылку 445 / 4975...
# Обрабатываем ссылку 446 / 4975...
# Обрабатываем ссылку 447 / 4975...
# Обрабатываем ссылку 448 / 4975...
# Обрабатываем ссылку 449 / 4975...
# Обрабатываем ссылку 450 / 4975...
# Обрабатываем ссылку 451 / 4975...
# Обрабатываем ссылку 452 / 4975...
# Обрабатываем ссылку 453 / 4975...
# Обрабатываем ссылку 454 / 4975...
# Обрабатываем ссылку 455 / 4975...
# Обрабатываем ссылку 456 / 4975...
# Обрабатываем ссылку 457 / 4975...
# Обрабатываем ссылку 458 / 4975...
# Обрабатываем ссылку 459 / 4975...
# Обрабатываем ссылку 460 / 4975...
# Обрабатываем ссылку 461 / 4975...
# Обрабатываем ссылку 462 / 4975...
# Обрабатываем ссылку 463 / 4975...
# Обрабатываем ссылку 464 / 4975...
# Обрабатываем ссылку 465 / 4975...
# Обрабатываем ссылку 466 / 4975...
# Обрабатываем ссылку 467 / 4975...
# Обрабатываем ссылку 468 / 4975...
# Обрабатываем ссылку 469 / 4975...
# Обрабатываем ссылку 470 / 4975...
# Обрабатываем ссылку 471 / 4975...
# Обрабатываем ссылку 472 / 4975...
# Обрабатываем ссылку 473 / 4975...
# Обрабатываем ссылку 474 / 4975...
# Обрабатываем ссылку 475 / 4975...
# Обрабатываем ссылку 476 / 4975...
# Обрабатываем ссылку 477 / 4975...
# Обрабатываем ссылку 478 / 4975...
# Обрабатываем ссылку 479 / 4975...
# Обрабатываем ссылку 480 / 4975...
# Обрабатываем ссылку 481 / 4975...
# Обрабатываем ссылку 482 / 4975...
# Обрабатываем ссылку 483 / 4975...
# Обрабатываем ссылку 484 / 4975...
# Обрабатываем ссылку 485 / 4975...
# Обрабатываем ссылку 486 / 4975...
# Обрабатываем ссылку 487 / 4975...
# Обрабатываем ссылку 488 / 4975...
# Обрабатываем ссылку 489 / 4975...
# Обрабатываем ссылку 490 / 4975...
# Обрабатываем ссылку 491 / 4975...
# Обрабатываем ссылку 492 / 4975...
# Обрабатываем ссылку 493 / 4975...
# Обрабатываем ссылку 494 / 4975...
# Обрабатываем ссылку 495 / 4975...
# Обрабатываем ссылку 496 / 4975...
# Обрабатываем ссылку 497 / 4975...
# Обрабатываем ссылку 498 / 4975...
# Обрабатываем ссылку 499 / 4975...
# Обрабатываем ссылку 500 / 4975...
# Обрабатываем ссылку 501 / 4975...
# Обрабатываем ссылку 502 / 4975...
# Обрабатываем ссылку 503 / 4975...
# Обрабатываем ссылку 504 / 4975...
# Обрабатываем ссылку 505 / 4975...
# Обрабатываем ссылку 506 / 4975...
# Обрабатываем ссылку 507 / 4975...
# Обрабатываем ссылку 508 / 4975...
# Обрабатываем ссылку 509 / 4975...
# Обрабатываем ссылку 510 / 4975...
# Обрабатываем ссылку 511 / 4975...
# Обрабатываем ссылку 512 / 4975...
# Обрабатываем ссылку 513 / 4975...
# Обрабатываем ссылку 514 / 4975...
# Обрабатываем ссылку 515 / 4975...
# Обрабатываем ссылку 516 / 4975...
# Обрабатываем ссылку 517 / 4975...
# Обрабатываем ссылку 518 / 4975...
# Обрабатываем ссылку 519 / 4975...
# Обрабатываем ссылку 520 / 4975...
# Обрабатываем ссылку 521 / 4975...
# Обрабатываем ссылку 522 / 4975...
# Обрабатываем ссылку 523 / 4975...
# Обрабатываем ссылку 524 / 4975...
# Обрабатываем ссылку 525 / 4975...
# Обрабатываем ссылку 526 / 4975...
# Обрабатываем ссылку 527 / 4975...
# Обрабатываем ссылку 528 / 4975...
# Обрабатываем ссылку 529 / 4975...
# Обрабатываем ссылку 530 / 4975...
# Обрабатываем ссылку 531 / 4975...
# Обрабатываем ссылку 532 / 4975...
# Обрабатываем ссылку 533 / 4975...
# Обрабатываем ссылку 534 / 4975...
# Обрабатываем ссылку 535 / 4975...
# Обрабатываем ссылку 536 / 4975...
# Обрабатываем ссылку 537 / 4975...
# Обрабатываем ссылку 538 / 4975...
# Обрабатываем ссылку 539 / 4975...
# Обрабатываем ссылку 540 / 4975...
# Обрабатываем ссылку 541 / 4975...
# Обрабатываем ссылку 542 / 4975...
# Обрабатываем ссылку 543 / 4975...
# Обрабатываем ссылку 544 / 4975...
# Обрабатываем ссылку 545 / 4975...
# Обрабатываем ссылку 546 / 4975...
# Обрабатываем ссылку 547 / 4975...
# Обрабатываем ссылку 548 / 4975...
# Обрабатываем ссылку 549 / 4975...
# Обрабатываем ссылку 550 / 4975...
# Обрабатываем ссылку 551 / 4975...
# Обрабатываем ссылку 552 / 4975...
# Обрабатываем ссылку 553 / 4975...
# Обрабатываем ссылку 554 / 4975...
# Обрабатываем ссылку 555 / 4975...
# Обрабатываем ссылку 556 / 4975...
# Обрабатываем ссылку 557 / 4975...
# Обрабатываем ссылку 558 / 4975...
# Обрабатываем ссылку 559 / 4975...
# Обрабатываем ссылку 560 / 4975...
# Обрабатываем ссылку 561 / 4975...
# Обрабатываем ссылку 562 / 4975...
# Обрабатываем ссылку 563 / 4975...
# Обрабатываем ссылку 564 / 4975...
# Обрабатываем ссылку 565 / 4975...
# Обрабатываем ссылку 566 / 4975...
# Обрабатываем ссылку 567 / 4975...
# Обрабатываем ссылку 568 / 4975...
# Обрабатываем ссылку 569 / 4975...
# Обрабатываем ссылку 570 / 4975...
# Обрабатываем ссылку 571 / 4975...
# Обрабатываем ссылку 572 / 4975...
# Обрабатываем ссылку 573 / 4975...
# Обрабатываем ссылку 574 / 4975...
# Обрабатываем ссылку 575 / 4975...
# Обрабатываем ссылку 576 / 4975...
# Обрабатываем ссылку 577 / 4975...
# Обрабатываем ссылку 578 / 4975...
# Обрабатываем ссылку 579 / 4975...
# Обрабатываем ссылку 580 / 4975...
# Обрабатываем ссылку 581 / 4975...
# Обрабатываем ссылку 582 / 4975...
# Обрабатываем ссылку 583 / 4975...
# Обрабатываем ссылку 584 / 4975...
# Обрабатываем ссылку 585 / 4975...
# Обрабатываем ссылку 586 / 4975...
# Обрабатываем ссылку 587 / 4975...
# Обрабатываем ссылку 588 / 4975...
# Обрабатываем ссылку 589 / 4975...
# Обрабатываем ссылку 590 / 4975...
# Обрабатываем ссылку 591 / 4975...
# Обрабатываем ссылку 592 / 4975...
# Обрабатываем ссылку 593 / 4975...
# Обрабатываем ссылку 594 / 4975...
# Обрабатываем ссылку 595 / 4975...
# Обрабатываем ссылку 596 / 4975...
# Обрабатываем ссылку 597 / 4975...
# Обрабатываем ссылку 598 / 4975...
# Обрабатываем ссылку 599 / 4975...
# Обрабатываем ссылку 600 / 4975...
# Обрабатываем ссылку 601 / 4975...
# Обрабатываем ссылку 602 / 4975...
# Обрабатываем ссылку 603 / 4975...
# Обрабатываем ссылку 604 / 4975...
# Обрабатываем ссылку 605 / 4975...
# Обрабатываем ссылку 606 / 4975...
# Обрабатываем ссылку 607 / 4975...
# Обрабатываем ссылку 608 / 4975...
# Обрабатываем ссылку 609 / 4975...
# Обрабатываем ссылку 610 / 4975...
# Обрабатываем ссылку 611 / 4975...
# Обрабатываем ссылку 612 / 4975...
# Обрабатываем ссылку 613 / 4975...
# Обрабатываем ссылку 614 / 4975...
# Обрабатываем ссылку 615 / 4975...
# Обрабатываем ссылку 616 / 4975...
# Обрабатываем ссылку 617 / 4975...
# Обрабатываем ссылку 618 / 4975...
# Обрабатываем ссылку 619 / 4975...
# Обрабатываем ссылку 620 / 4975...
# Обрабатываем ссылку 621 / 4975...
# Обрабатываем ссылку 622 / 4975...
# Обрабатываем ссылку 623 / 4975...
# Обрабатываем ссылку 624 / 4975...
# Обрабатываем ссылку 625 / 4975...
# Обрабатываем ссылку 626 / 4975...
# Обрабатываем ссылку 627 / 4975...
# Обрабатываем ссылку 628 / 4975...
# Обрабатываем ссылку 629 / 4975...
# Обрабатываем ссылку 630 / 4975...
# Обрабатываем ссылку 631 / 4975...
# Обрабатываем ссылку 632 / 4975...
# Обрабатываем ссылку 633 / 4975...
# Обрабатываем ссылку 634 / 4975...
# Обрабатываем ссылку 635 / 4975...
# Обрабатываем ссылку 636 / 4975...
# Обрабатываем ссылку 637 / 4975...
# Обрабатываем ссылку 638 / 4975...
# Обрабатываем ссылку 639 / 4975...
# Обрабатываем ссылку 640 / 4975...
# Обрабатываем ссылку 641 / 4975...
# Обрабатываем ссылку 642 / 4975...
# Обрабатываем ссылку 643 / 4975...
# Обрабатываем ссылку 644 / 4975...
# Обрабатываем ссылку 645 / 4975...
# Обрабатываем ссылку 646 / 4975...
# Обрабатываем ссылку 647 / 4975...
# Обрабатываем ссылку 648 / 4975...
# Обрабатываем ссылку 649 / 4975...
# Обрабатываем ссылку 650 / 4975...
# Обрабатываем ссылку 651 / 4975...
# Обрабатываем ссылку 652 / 4975...
# Обрабатываем ссылку 653 / 4975...
# Обрабатываем ссылку 654 / 4975...
# Обрабатываем ссылку 655 / 4975...
# Обрабатываем ссылку 656 / 4975...
# Обрабатываем ссылку 657 / 4975...
# Обрабатываем ссылку 658 / 4975...
# Обрабатываем ссылку 659 / 4975...
# Обрабатываем ссылку 660 / 4975...
# Обрабатываем ссылку 661 / 4975...
# Обрабатываем ссылку 662 / 4975...
# Обрабатываем ссылку 663 / 4975...
# Обрабатываем ссылку 664 / 4975...
# Обрабатываем ссылку 665 / 4975...
# Обрабатываем ссылку 666 / 4975...
# Обрабатываем ссылку 667 / 4975...
# Обрабатываем ссылку 668 / 4975...
# Обрабатываем ссылку 669 / 4975...
# Обрабатываем ссылку 670 / 4975...
# Обрабатываем ссылку 671 / 4975...
# Обрабатываем ссылку 672 / 4975...
# Обрабатываем ссылку 673 / 4975...
# Обрабатываем ссылку 674 / 4975...
# Обрабатываем ссылку 675 / 4975...
# Обрабатываем ссылку 676 / 4975...
# Обрабатываем ссылку 677 / 4975...
# Обрабатываем ссылку 678 / 4975...
# Обрабатываем ссылку 679 / 4975...
# Обрабатываем ссылку 680 / 4975...
# Обрабатываем ссылку 681 / 4975...
# Обрабатываем ссылку 682 / 4975...
# Обрабатываем ссылку 683 / 4975...
# Обрабатываем ссылку 684 / 4975...
# Обрабатываем ссылку 685 / 4975...
# Обрабатываем ссылку 686 / 4975...
# Обрабатываем ссылку 687 / 4975...
# Обрабатываем ссылку 688 / 4975...
# Обрабатываем ссылку 689 / 4975...
# Обрабатываем ссылку 690 / 4975...
# Обрабатываем ссылку 691 / 4975...
# Обрабатываем ссылку 692 / 4975...
# Обрабатываем ссылку 693 / 4975...
# Обрабатываем ссылку 694 / 4975...
# Обрабатываем ссылку 695 / 4975...
# Обрабатываем ссылку 696 / 4975...
# Обрабатываем ссылку 697 / 4975...
# Обрабатываем ссылку 698 / 4975...
# Обрабатываем ссылку 699 / 4975...
# Обрабатываем ссылку 700 / 4975...
# Обрабатываем ссылку 701 / 4975...
# Обрабатываем ссылку 702 / 4975...
# Обрабатываем ссылку 703 / 4975...
# Обрабатываем ссылку 704 / 4975...
# Обрабатываем ссылку 705 / 4975...
# Обрабатываем ссылку 706 / 4975...
# Обрабатываем ссылку 707 / 4975...
# Обрабатываем ссылку 708 / 4975...
# Обрабатываем ссылку 709 / 4975...
# Обрабатываем ссылку 710 / 4975...
# Обрабатываем ссылку 711 / 4975...
# Обрабатываем ссылку 712 / 4975...
# Обрабатываем ссылку 713 / 4975...
# Обрабатываем ссылку 714 / 4975...
# Обрабатываем ссылку 715 / 4975...
# Обрабатываем ссылку 716 / 4975...
# Обрабатываем ссылку 717 / 4975...
# Обрабатываем ссылку 718 / 4975...
# Обрабатываем ссылку 719 / 4975...
# Обрабатываем ссылку 720 / 4975...
# Обрабатываем ссылку 721 / 4975...
# Обрабатываем ссылку 722 / 4975...
# Обрабатываем ссылку 723 / 4975...
# Обрабатываем ссылку 724 / 4975...
# Обрабатываем ссылку 725 / 4975...
# Обрабатываем ссылку 726 / 4975...
# Обрабатываем ссылку 727 / 4975...
# Обрабатываем ссылку 728 / 4975...
# Обрабатываем ссылку 729 / 4975...
# Обрабатываем ссылку 730 / 4975...
# Обрабатываем ссылку 731 / 4975...
# Обрабатываем ссылку 732 / 4975...
# Обрабатываем ссылку 733 / 4975...
# Обрабатываем ссылку 734 / 4975...
# Обрабатываем ссылку 735 / 4975...
# Обрабатываем ссылку 736 / 4975...
# Обрабатываем ссылку 737 / 4975...
# Обрабатываем ссылку 738 / 4975...
# Обрабатываем ссылку 739 / 4975...
# Обрабатываем ссылку 740 / 4975...
# Обрабатываем ссылку 741 / 4975...
# Обрабатываем ссылку 742 / 4975...
# Обрабатываем ссылку 743 / 4975...
# Обрабатываем ссылку 744 / 4975...
# Обрабатываем ссылку 745 / 4975...
# Обрабатываем ссылку 746 / 4975...
# Обрабатываем ссылку 747 / 4975...
# Обрабатываем ссылку 748 / 4975...
# Обрабатываем ссылку 749 / 4975...
# Обрабатываем ссылку 750 / 4975...
# Обрабатываем ссылку 751 / 4975...
# Обрабатываем ссылку 752 / 4975...
# Обрабатываем ссылку 753 / 4975...
# Обрабатываем ссылку 754 / 4975...
# Обрабатываем ссылку 755 / 4975...
# Обрабатываем ссылку 756 / 4975...
# Обрабатываем ссылку 757 / 4975...
# Обрабатываем ссылку 758 / 4975...
# Обрабатываем ссылку 759 / 4975...
# Обрабатываем ссылку 760 / 4975...
# Обрабатываем ссылку 761 / 4975...
# Обрабатываем ссылку 762 / 4975...
# Обрабатываем ссылку 763 / 4975...
# Обрабатываем ссылку 764 / 4975...
# Обрабатываем ссылку 765 / 4975...
# Обрабатываем ссылку 766 / 4975...
# Обрабатываем ссылку 767 / 4975...
# Обрабатываем ссылку 768 / 4975...
# Обрабатываем ссылку 769 / 4975...
# Обрабатываем ссылку 770 / 4975...
# Обрабатываем ссылку 771 / 4975...
# Обрабатываем ссылку 772 / 4975...
# Обрабатываем ссылку 773 / 4975...
# Обрабатываем ссылку 774 / 4975...
# Обрабатываем ссылку 775 / 4975...
# Обрабатываем ссылку 776 / 4975...
# Обрабатываем ссылку 777 / 4975...
# Обрабатываем ссылку 778 / 4975...
# Обрабатываем ссылку 779 / 4975...
# Обрабатываем ссылку 780 / 4975...
# Обрабатываем ссылку 781 / 4975...
# Обрабатываем ссылку 782 / 4975...
# Обрабатываем ссылку 783 / 4975...
# Обрабатываем ссылку 784 / 4975...
# Обрабатываем ссылку 785 / 4975...
# Обрабатываем ссылку 786 / 4975...
# Обрабатываем ссылку 787 / 4975...
# Обрабатываем ссылку 788 / 4975...
# Обрабатываем ссылку 789 / 4975...
# Обрабатываем ссылку 790 / 4975...
# Обрабатываем ссылку 791 / 4975...
# Обрабатываем ссылку 792 / 4975...
# Обрабатываем ссылку 793 / 4975...
# Обрабатываем ссылку 794 / 4975...
# Обрабатываем ссылку 795 / 4975...
# Обрабатываем ссылку 796 / 4975...
# Обрабатываем ссылку 797 / 4975...
# Обрабатываем ссылку 798 / 4975...
# Обрабатываем ссылку 799 / 4975...
# Обрабатываем ссылку 800 / 4975...
# Обрабатываем ссылку 801 / 4975...
# Обрабатываем ссылку 802 / 4975...
# Обрабатываем ссылку 803 / 4975...
# Обрабатываем ссылку 804 / 4975...
# Обрабатываем ссылку 805 / 4975...
# Обрабатываем ссылку 806 / 4975...
# Обрабатываем ссылку 807 / 4975...
# Обрабатываем ссылку 808 / 4975...
# Обрабатываем ссылку 809 / 4975...
# Обрабатываем ссылку 810 / 4975...
# Обрабатываем ссылку 811 / 4975...
# Обрабатываем ссылку 812 / 4975...
# Обрабатываем ссылку 813 / 4975...
# Обрабатываем ссылку 814 / 4975...
# Обрабатываем ссылку 815 / 4975...
# Обрабатываем ссылку 816 / 4975...
# Обрабатываем ссылку 817 / 4975...
# Обрабатываем ссылку 818 / 4975...
# Обрабатываем ссылку 819 / 4975...
# Обрабатываем ссылку 820 / 4975...
# Обрабатываем ссылку 821 / 4975...
# Обрабатываем ссылку 822 / 4975...
# Обрабатываем ссылку 823 / 4975...
# Обрабатываем ссылку 824 / 4975...
# Обрабатываем ссылку 825 / 4975...
# Обрабатываем ссылку 826 / 4975...
# Обрабатываем ссылку 827 / 4975...
# Обрабатываем ссылку 828 / 4975...
# Обрабатываем ссылку 829 / 4975...
# Обрабатываем ссылку 830 / 4975...
# Обрабатываем ссылку 831 / 4975...
# Обрабатываем ссылку 832 / 4975...
# Обрабатываем ссылку 833 / 4975...
# Обрабатываем ссылку 834 / 4975...
# Обрабатываем ссылку 835 / 4975...
# Обрабатываем ссылку 836 / 4975...
# Обрабатываем ссылку 837 / 4975...
# Обрабатываем ссылку 838 / 4975...
# Обрабатываем ссылку 839 / 4975...
# Обрабатываем ссылку 840 / 4975...
# Обрабатываем ссылку 841 / 4975...
# Обрабатываем ссылку 842 / 4975...
# Обрабатываем ссылку 843 / 4975...
# Обрабатываем ссылку 844 / 4975...
# Обрабатываем ссылку 845 / 4975...
# Обрабатываем ссылку 846 / 4975...
# Обрабатываем ссылку 847 / 4975...
# Обрабатываем ссылку 848 / 4975...
# Обрабатываем ссылку 849 / 4975...
# Обрабатываем ссылку 850 / 4975...
# Обрабатываем ссылку 851 / 4975...
# Обрабатываем ссылку 852 / 4975...
# Обрабатываем ссылку 853 / 4975...
# Обрабатываем ссылку 854 / 4975...
# Обрабатываем ссылку 855 / 4975...
# Обрабатываем ссылку 856 / 4975...
# Обрабатываем ссылку 857 / 4975...
# Обрабатываем ссылку 858 / 4975...
# Обрабатываем ссылку 859 / 4975...
# Обрабатываем ссылку 860 / 4975...
# Обрабатываем ссылку 861 / 4975...
# Обрабатываем ссылку 862 / 4975...
# Обрабатываем ссылку 863 / 4975...
# Обрабатываем ссылку 864 / 4975...
# Обрабатываем ссылку 865 / 4975...
# Обрабатываем ссылку 866 / 4975...
# Обрабатываем ссылку 867 / 4975...
# Обрабатываем ссылку 868 / 4975...
# Обрабатываем ссылку 869 / 4975...
# Обрабатываем ссылку 870 / 4975...
# Обрабатываем ссылку 871 / 4975...
# Обрабатываем ссылку 872 / 4975...
# Обрабатываем ссылку 873 / 4975...
# Обрабатываем ссылку 874 / 4975...
# Обрабатываем ссылку 875 / 4975...
# Обрабатываем ссылку 876 / 4975...
# Обрабатываем ссылку 877 / 4975...
# Обрабатываем ссылку 878 / 4975...
# Обрабатываем ссылку 879 / 4975...
# Обрабатываем ссылку 880 / 4975...
# Обрабатываем ссылку 881 / 4975...
# Обрабатываем ссылку 882 / 4975...
# Обрабатываем ссылку 883 / 4975...
# Обрабатываем ссылку 884 / 4975...
# Обрабатываем ссылку 885 / 4975...
# Обрабатываем ссылку 886 / 4975...
# Обрабатываем ссылку 887 / 4975...
# Обрабатываем ссылку 888 / 4975...
# Обрабатываем ссылку 889 / 4975...
# Обрабатываем ссылку 890 / 4975...
# Обрабатываем ссылку 891 / 4975...
# Обрабатываем ссылку 892 / 4975...
# Обрабатываем ссылку 893 / 4975...
# Обрабатываем ссылку 894 / 4975...
# Обрабатываем ссылку 895 / 4975...
# Обрабатываем ссылку 896 / 4975...
# Обрабатываем ссылку 897 / 4975...
# Обрабатываем ссылку 898 / 4975...
# Обрабатываем ссылку 899 / 4975...
# Обрабатываем ссылку 900 / 4975...
# Обрабатываем ссылку 901 / 4975...
# Обрабатываем ссылку 902 / 4975...
# Обрабатываем ссылку 903 / 4975...
# Обрабатываем ссылку 904 / 4975...
# Обрабатываем ссылку 905 / 4975...
# Обрабатываем ссылку 906 / 4975...
# Обрабатываем ссылку 907 / 4975...
# Обрабатываем ссылку 908 / 4975...
# Обрабатываем ссылку 909 / 4975...
# Обрабатываем ссылку 910 / 4975...
# Обрабатываем ссылку 911 / 4975...
# Обрабатываем ссылку 912 / 4975...
# Обрабатываем ссылку 913 / 4975...
# Обрабатываем ссылку 914 / 4975...
# Обрабатываем ссылку 915 / 4975...
# Обрабатываем ссылку 916 / 4975...
# Обрабатываем ссылку 917 / 4975...
# Обрабатываем ссылку 918 / 4975...
# Обрабатываем ссылку 919 / 4975...
# Обрабатываем ссылку 920 / 4975...
# Обрабатываем ссылку 921 / 4975...
# Обрабатываем ссылку 922 / 4975...
# Обрабатываем ссылку 923 / 4975...
# Обрабатываем ссылку 924 / 4975...
# Обрабатываем ссылку 925 / 4975...
# Обрабатываем ссылку 926 / 4975...
# Обрабатываем ссылку 927 / 4975...
# Обрабатываем ссылку 928 / 4975...
# Обрабатываем ссылку 929 / 4975...
# Обрабатываем ссылку 930 / 4975...
# Обрабатываем ссылку 931 / 4975...
# Обрабатываем ссылку 932 / 4975...
# Обрабатываем ссылку 933 / 4975...
# Обрабатываем ссылку 934 / 4975...
# Обрабатываем ссылку 935 / 4975...
# Обрабатываем ссылку 936 / 4975...
# Обрабатываем ссылку 937 / 4975...
# Обрабатываем ссылку 938 / 4975...
# Обрабатываем ссылку 939 / 4975...
# Обрабатываем ссылку 940 / 4975...
# Обрабатываем ссылку 941 / 4975...
# Обрабатываем ссылку 942 / 4975...
# Обрабатываем ссылку 943 / 4975...
# Обрабатываем ссылку 944 / 4975...
# Обрабатываем ссылку 945 / 4975...
# Обрабатываем ссылку 946 / 4975...
# Обрабатываем ссылку 947 / 4975...
# Обрабатываем ссылку 948 / 4975...
# Обрабатываем ссылку 949 / 4975...
# Обрабатываем ссылку 950 / 4975...
# Обрабатываем ссылку 951 / 4975...
# Обрабатываем ссылку 952 / 4975...
# Обрабатываем ссылку 953 / 4975...
# Обрабатываем ссылку 954 / 4975...
# Обрабатываем ссылку 955 / 4975...
# Обрабатываем ссылку 956 / 4975...
# Обрабатываем ссылку 957 / 4975...
# Обрабатываем ссылку 958 / 4975...
# Обрабатываем ссылку 959 / 4975...
# Обрабатываем ссылку 960 / 4975...
# Обрабатываем ссылку 961 / 4975...
# Обрабатываем ссылку 962 / 4975...
# Обрабатываем ссылку 963 / 4975...
# Обрабатываем ссылку 964 / 4975...
# Обрабатываем ссылку 965 / 4975...
# Обрабатываем ссылку 966 / 4975...
# Обрабатываем ссылку 967 / 4975...
# Обрабатываем ссылку 968 / 4975...
# Обрабатываем ссылку 969 / 4975...
# Обрабатываем ссылку 970 / 4975...
# Обрабатываем ссылку 971 / 4975...
# Обрабатываем ссылку 972 / 4975...
# Обрабатываем ссылку 973 / 4975...
# Обрабатываем ссылку 974 / 4975...
# Обрабатываем ссылку 975 / 4975...
# Обрабатываем ссылку 976 / 4975...
# Обрабатываем ссылку 977 / 4975...
# Обрабатываем ссылку 978 / 4975...
# Обрабатываем ссылку 979 / 4975...
# Обрабатываем ссылку 980 / 4975...
# Обрабатываем ссылку 981 / 4975...
# Обрабатываем ссылку 982 / 4975...
# Обрабатываем ссылку 983 / 4975...
# Обрабатываем ссылку 984 / 4975...
# Обрабатываем ссылку 985 / 4975...
# Обрабатываем ссылку 986 / 4975...
# Обрабатываем ссылку 987 / 4975...
# Обрабатываем ссылку 988 / 4975...
# Обрабатываем ссылку 989 / 4975...
# Обрабатываем ссылку 990 / 4975...
# Обрабатываем ссылку 991 / 4975...
# Обрабатываем ссылку 992 / 4975...
# Обрабатываем ссылку 993 / 4975...
# Обрабатываем ссылку 994 / 4975...
# Обрабатываем ссылку 995 / 4975...
# Обрабатываем ссылку 996 / 4975...
# Обрабатываем ссылку 997 / 4975...
# Обрабатываем ссылку 998 / 4975...
# Обрабатываем ссылку 999 / 4975...
# Обрабатываем ссылку 1000 / 4975...
# Обрабатываем ссылку 1001 / 4975...
# Обрабатываем ссылку 1002 / 4975...
# Обрабатываем ссылку 1003 / 4975...
# Обрабатываем ссылку 1004 / 4975...
# Обрабатываем ссылку 1005 / 4975...
# Обрабатываем ссылку 1006 / 4975...
# Обрабатываем ссылку 1007 / 4975...
# Обрабатываем ссылку 1008 / 4975...
# Обрабатываем ссылку 1009 / 4975...
# Обрабатываем ссылку 1010 / 4975...
# Обрабатываем ссылку 1011 / 4975...
# Обрабатываем ссылку 1012 / 4975...
# Обрабатываем ссылку 1013 / 4975...
# Обрабатываем ссылку 1014 / 4975...
# Обрабатываем ссылку 1015 / 4975...
# Обрабатываем ссылку 1016 / 4975...
# Обрабатываем ссылку 1017 / 4975...
# Обрабатываем ссылку 1018 / 4975...
# Обрабатываем ссылку 1019 / 4975...
# Обрабатываем ссылку 1020 / 4975...
# Обрабатываем ссылку 1021 / 4975...
# Обрабатываем ссылку 1022 / 4975...
# Обрабатываем ссылку 1023 / 4975...
# Обрабатываем ссылку 1024 / 4975...
# Обрабатываем ссылку 1025 / 4975...
# Обрабатываем ссылку 1026 / 4975...
# Обрабатываем ссылку 1027 / 4975...
# Обрабатываем ссылку 1028 / 4975...
# Обрабатываем ссылку 1029 / 4975...
# Обрабатываем ссылку 1030 / 4975...
# Обрабатываем ссылку 1031 / 4975...
# Обрабатываем ссылку 1032 / 4975...
# Обрабатываем ссылку 1033 / 4975...
# Обрабатываем ссылку 1034 / 4975...
# Обрабатываем ссылку 1035 / 4975...
# Обрабатываем ссылку 1036 / 4975...
# Обрабатываем ссылку 1037 / 4975...
# Обрабатываем ссылку 1038 / 4975...
# Обрабатываем ссылку 1039 / 4975...
# Обрабатываем ссылку 1040 / 4975...
# Обрабатываем ссылку 1041 / 4975...
# Обрабатываем ссылку 1042 / 4975...
# Обрабатываем ссылку 1043 / 4975...
# Обрабатываем ссылку 1044 / 4975...
# Обрабатываем ссылку 1045 / 4975...
# Обрабатываем ссылку 1046 / 4975...
# Обрабатываем ссылку 1047 / 4975...
# Обрабатываем ссылку 1048 / 4975...
# Обрабатываем ссылку 1049 / 4975...
# Обрабатываем ссылку 1050 / 4975...
# Обрабатываем ссылку 1051 / 4975...
# Обрабатываем ссылку 1052 / 4975...
# Обрабатываем ссылку 1053 / 4975...
# Обрабатываем ссылку 1054 / 4975...
# Обрабатываем ссылку 1055 / 4975...
# Обрабатываем ссылку 1056 / 4975...
# Обрабатываем ссылку 1057 / 4975...
# Обрабатываем ссылку 1058 / 4975...
# Обрабатываем ссылку 1059 / 4975...
# Обрабатываем ссылку 1060 / 4975...
# Обрабатываем ссылку 1061 / 4975...
# Обрабатываем ссылку 1062 / 4975...
# Обрабатываем ссылку 1063 / 4975...
# Обрабатываем ссылку 1064 / 4975...
# Обрабатываем ссылку 1065 / 4975...
# Обрабатываем ссылку 1066 / 4975...
# Обрабатываем ссылку 1067 / 4975...
# Обрабатываем ссылку 1068 / 4975...
# Обрабатываем ссылку 1069 / 4975...
# Обрабатываем ссылку 1070 / 4975...
# Обрабатываем ссылку 1071 / 4975...
# Обрабатываем ссылку 1072 / 4975...
# Обрабатываем ссылку 1073 / 4975...
# Обрабатываем ссылку 1074 / 4975...
# Обрабатываем ссылку 1075 / 4975...
# Обрабатываем ссылку 1076 / 4975...
# Обрабатываем ссылку 1077 / 4975...
# Обрабатываем ссылку 1078 / 4975...
# Обрабатываем ссылку 1079 / 4975...
# Обрабатываем ссылку 1080 / 4975...
# Обрабатываем ссылку 1081 / 4975...
# Обрабатываем ссылку 1082 / 4975...
# Обрабатываем ссылку 1083 / 4975...
# Обрабатываем ссылку 1084 / 4975...
# Обрабатываем ссылку 1085 / 4975...
# Обрабатываем ссылку 1086 / 4975...
# Обрабатываем ссылку 1087 / 4975...
# Обрабатываем ссылку 1088 / 4975...
# Обрабатываем ссылку 1089 / 4975...
# Обрабатываем ссылку 1090 / 4975...
# Обрабатываем ссылку 1091 / 4975...
# Обрабатываем ссылку 1092 / 4975...
# Обрабатываем ссылку 1093 / 4975...
# Обрабатываем ссылку 1094 / 4975...
# Обрабатываем ссылку 1095 / 4975...
# Обрабатываем ссылку 1096 / 4975...
# Обрабатываем ссылку 1097 / 4975...
# Обрабатываем ссылку 1098 / 4975...
# Обрабатываем ссылку 1099 / 4975...
# Обрабатываем ссылку 1100 / 4975...
# Обрабатываем ссылку 1101 / 4975...
# Обрабатываем ссылку 1102 / 4975...
# Обрабатываем ссылку 1103 / 4975...
# Обрабатываем ссылку 1104 / 4975...
# Обрабатываем ссылку 1105 / 4975...
# Обрабатываем ссылку 1106 / 4975...
# Обрабатываем ссылку 1107 / 4975...
# Обрабатываем ссылку 1108 / 4975...
# Обрабатываем ссылку 1109 / 4975...
# Обрабатываем ссылку 1110 / 4975...
# Обрабатываем ссылку 1111 / 4975...
# Обрабатываем ссылку 1112 / 4975...
# Обрабатываем ссылку 1113 / 4975...
# Обрабатываем ссылку 1114 / 4975...
# Обрабатываем ссылку 1115 / 4975...
# Обрабатываем ссылку 1116 / 4975...
# Обрабатываем ссылку 1117 / 4975...
# Обрабатываем ссылку 1118 / 4975...
# Обрабатываем ссылку 1119 / 4975...
# Обрабатываем ссылку 1120 / 4975...
# Обрабатываем ссылку 1121 / 4975...
# Обрабатываем ссылку 1122 / 4975...
# Обрабатываем ссылку 1123 / 4975...
# Обрабатываем ссылку 1124 / 4975...
# Обрабатываем ссылку 1125 / 4975...
# Обрабатываем ссылку 1126 / 4975...
# Обрабатываем ссылку 1127 / 4975...
# Обрабатываем ссылку 1128 / 4975...
# Обрабатываем ссылку 1129 / 4975...
# Обрабатываем ссылку 1130 / 4975...
# Обрабатываем ссылку 1131 / 4975...
# Обрабатываем ссылку 1132 / 4975...
# Обрабатываем ссылку 1133 / 4975...
# Обрабатываем ссылку 1134 / 4975...
# Обрабатываем ссылку 1135 / 4975...
# Обрабатываем ссылку 1136 / 4975...
# Обрабатываем ссылку 1137 / 4975...
# Обрабатываем ссылку 1138 / 4975...
# Обрабатываем ссылку 1139 / 4975...
# Обрабатываем ссылку 1140 / 4975...
# Обрабатываем ссылку 1141 / 4975...
# Обрабатываем ссылку 1142 / 4975...
# Обрабатываем ссылку 1143 / 4975...
# Обрабатываем ссылку 1144 / 4975...
# Обрабатываем ссылку 1145 / 4975...
# Обрабатываем ссылку 1146 / 4975...
# Обрабатываем ссылку 1147 / 4975...
# Обрабатываем ссылку 1148 / 4975...
# Обрабатываем ссылку 1149 / 4975...
# Обрабатываем ссылку 1150 / 4975...
# Обрабатываем ссылку 1151 / 4975...
# Обрабатываем ссылку 1152 / 4975...
# Обрабатываем ссылку 1153 / 4975...
# Обрабатываем ссылку 1154 / 4975...
# Обрабатываем ссылку 1155 / 4975...
# Обрабатываем ссылку 1156 / 4975...
# Обрабатываем ссылку 1157 / 4975...
# Обрабатываем ссылку 1158 / 4975...
# Обрабатываем ссылку 1159 / 4975...
# Обрабатываем ссылку 1160 / 4975...
# Обрабатываем ссылку 1161 / 4975...
# Обрабатываем ссылку 1162 / 4975...
# Обрабатываем ссылку 1163 / 4975...
# Обрабатываем ссылку 1164 / 4975...
# Обрабатываем ссылку 1165 / 4975...
# Обрабатываем ссылку 1166 / 4975...
# Обрабатываем ссылку 1167 / 4975...
# Обрабатываем ссылку 1168 / 4975...
# Обрабатываем ссылку 1169 / 4975...
# Обрабатываем ссылку 1170 / 4975...
# Обрабатываем ссылку 1171 / 4975...
# Обрабатываем ссылку 1172 / 4975...
# Обрабатываем ссылку 1173 / 4975...
# Обрабатываем ссылку 1174 / 4975...
# Обрабатываем ссылку 1175 / 4975...
# Обрабатываем ссылку 1176 / 4975...
# Обрабатываем ссылку 1177 / 4975...
# Обрабатываем ссылку 1178 / 4975...
# Обрабатываем ссылку 1179 / 4975...
# Обрабатываем ссылку 1180 / 4975...
# Обрабатываем ссылку 1181 / 4975...
# Обрабатываем ссылку 1182 / 4975...
# Обрабатываем ссылку 1183 / 4975...
# Обрабатываем ссылку 1184 / 4975...
# Обрабатываем ссылку 1185 / 4975...
# Обрабатываем ссылку 1186 / 4975...
# Обрабатываем ссылку 1187 / 4975...
# Обрабатываем ссылку 1188 / 4975...
# Обрабатываем ссылку 1189 / 4975...
# Обрабатываем ссылку 1190 / 4975...
# Обрабатываем ссылку 1191 / 4975...
# Обрабатываем ссылку 1192 / 4975...
# Обрабатываем ссылку 1193 / 4975...
# Обрабатываем ссылку 1194 / 4975...
# Обрабатываем ссылку 1195 / 4975...
# Обрабатываем ссылку 1196 / 4975...
# Обрабатываем ссылку 1197 / 4975...
# Обрабатываем ссылку 1198 / 4975...
# Обрабатываем ссылку 1199 / 4975...
# Обрабатываем ссылку 1200 / 4975...
# Обрабатываем ссылку 1201 / 4975...
# Обрабатываем ссылку 1202 / 4975...
# Обрабатываем ссылку 1203 / 4975...
# Обрабатываем ссылку 1204 / 4975...
# Обрабатываем ссылку 1205 / 4975...
# Обрабатываем ссылку 1206 / 4975...
# Обрабатываем ссылку 1207 / 4975...
# Обрабатываем ссылку 1208 / 4975...
# Обрабатываем ссылку 1209 / 4975...
# Обрабатываем ссылку 1210 / 4975...
# Обрабатываем ссылку 1211 / 4975...
# Обрабатываем ссылку 1212 / 4975...
# Обрабатываем ссылку 1213 / 4975...
# Обрабатываем ссылку 1214 / 4975...
# Обрабатываем ссылку 1215 / 4975...
# Обрабатываем ссылку 1216 / 4975...
# Обрабатываем ссылку 1217 / 4975...
# Обрабатываем ссылку 1218 / 4975...
# Обрабатываем ссылку 1219 / 4975...
# Обрабатываем ссылку 1220 / 4975...
# Обрабатываем ссылку 1221 / 4975...
# Обрабатываем ссылку 1222 / 4975...
# Обрабатываем ссылку 1223 / 4975...
# Обрабатываем ссылку 1224 / 4975...
# Обрабатываем ссылку 1225 / 4975...
# Обрабатываем ссылку 1226 / 4975...
# Обрабатываем ссылку 1227 / 4975...
# Обрабатываем ссылку 1228 / 4975...
# Обрабатываем ссылку 1229 / 4975...
# Обрабатываем ссылку 1230 / 4975...
# Обрабатываем ссылку 1231 / 4975...
# Обрабатываем ссылку 1232 / 4975...
# Обрабатываем ссылку 1233 / 4975...
# Обрабатываем ссылку 1234 / 4975...
# Обрабатываем ссылку 1235 / 4975...
# Обрабатываем ссылку 1236 / 4975...
# Обрабатываем ссылку 1237 / 4975...
# Обрабатываем ссылку 1238 / 4975...
# Обрабатываем ссылку 1239 / 4975...
# Обрабатываем ссылку 1240 / 4975...
# Обрабатываем ссылку 1241 / 4975...
# Обрабатываем ссылку 1242 / 4975...
# Обрабатываем ссылку 1243 / 4975...
# Обрабатываем ссылку 1244 / 4975...
# Обрабатываем ссылку 1245 / 4975...
# Обрабатываем ссылку 1246 / 4975...
# Обрабатываем ссылку 1247 / 4975...
# Обрабатываем ссылку 1248 / 4975...
# Обрабатываем ссылку 1249 / 4975...
# Обрабатываем ссылку 1250 / 4975...
# Обрабатываем ссылку 1251 / 4975...
# Обрабатываем ссылку 1252 / 4975...
# Обрабатываем ссылку 1253 / 4975...
# Обрабатываем ссылку 1254 / 4975...
# Обрабатываем ссылку 1255 / 4975...
# Обрабатываем ссылку 1256 / 4975...
# Обрабатываем ссылку 1257 / 4975...
# Обрабатываем ссылку 1258 / 4975...
# Обрабатываем ссылку 1259 / 4975...
# Обрабатываем ссылку 1260 / 4975...
# Обрабатываем ссылку 1261 / 4975...
# Обрабатываем ссылку 1262 / 4975...
# Обрабатываем ссылку 1263 / 4975...
# Обрабатываем ссылку 1264 / 4975...
# Обрабатываем ссылку 1265 / 4975...
# Обрабатываем ссылку 1266 / 4975...
# Обрабатываем ссылку 1267 / 4975...
# Обрабатываем ссылку 1268 / 4975...
# Обрабатываем ссылку 1269 / 4975...
# Обрабатываем ссылку 1270 / 4975...
# Обрабатываем ссылку 1271 / 4975...
# Обрабатываем ссылку 1272 / 4975...
# Обрабатываем ссылку 1273 / 4975...
# Обрабатываем ссылку 1274 / 4975...
# Обрабатываем ссылку 1275 / 4975...
# Обрабатываем ссылку 1276 / 4975...
# Обрабатываем ссылку 1277 / 4975...
# Обрабатываем ссылку 1278 / 4975...
# Обрабатываем ссылку 1279 / 4975...
# Обрабатываем ссылку 1280 / 4975...
# Обрабатываем ссылку 1281 / 4975...
# Обрабатываем ссылку 1282 / 4975...
# Обрабатываем ссылку 1283 / 4975...
# Обрабатываем ссылку 1284 / 4975...
# Обрабатываем ссылку 1285 / 4975...
# Обрабатываем ссылку 1286 / 4975...
# Обрабатываем ссылку 1287 / 4975...
# Обрабатываем ссылку 1288 / 4975...
# Обрабатываем ссылку 1289 / 4975...
# Обрабатываем ссылку 1290 / 4975...
# Обрабатываем ссылку 1291 / 4975...
# Обрабатываем ссылку 1292 / 4975...
# Обрабатываем ссылку 1293 / 4975...
# Обрабатываем ссылку 1294 / 4975...
# Обрабатываем ссылку 1295 / 4975...
# Обрабатываем ссылку 1296 / 4975...
# Обрабатываем ссылку 1297 / 4975...
# Обрабатываем ссылку 1298 / 4975...
# Обрабатываем ссылку 1299 / 4975...
# Обрабатываем ссылку 1300 / 4975...
# Обрабатываем ссылку 1301 / 4975...
# Обрабатываем ссылку 1302 / 4975...
# Обрабатываем ссылку 1303 / 4975...
# Обрабатываем ссылку 1304 / 4975...
# Обрабатываем ссылку 1305 / 4975...
# Обрабатываем ссылку 1306 / 4975...
# Обрабатываем ссылку 1307 / 4975...
# Обрабатываем ссылку 1308 / 4975...
# Обрабатываем ссылку 1309 / 4975...
# Обрабатываем ссылку 1310 / 4975...
# Обрабатываем ссылку 1311 / 4975...
# Обрабатываем ссылку 1312 / 4975...
# Обрабатываем ссылку 1313 / 4975...
# Обрабатываем ссылку 1314 / 4975...
# Обрабатываем ссылку 1315 / 4975...
# Обрабатываем ссылку 1316 / 4975...
# Обрабатываем ссылку 1317 / 4975...
# Обрабатываем ссылку 1318 / 4975...
# Обрабатываем ссылку 1319 / 4975...
# Обрабатываем ссылку 1320 / 4975...
# Обрабатываем ссылку 1321 / 4975...
# Обрабатываем ссылку 1322 / 4975...
# Обрабатываем ссылку 1323 / 4975...
# Обрабатываем ссылку 1324 / 4975...
# Обрабатываем ссылку 1325 / 4975...
# Обрабатываем ссылку 1326 / 4975...
# Обрабатываем ссылку 1327 / 4975...
# Обрабатываем ссылку 1328 / 4975...
# Обрабатываем ссылку 1329 / 4975...
# Обрабатываем ссылку 1330 / 4975...
# Обрабатываем ссылку 1331 / 4975...
# Обрабатываем ссылку 1332 / 4975...
# Обрабатываем ссылку 1333 / 4975...
# Обрабатываем ссылку 1334 / 4975...
# Обрабатываем ссылку 1335 / 4975...
# Обрабатываем ссылку 1336 / 4975...
# Обрабатываем ссылку 1337 / 4975...
# Обрабатываем ссылку 1338 / 4975...
# Обрабатываем ссылку 1339 / 4975...
# Обрабатываем ссылку 1340 / 4975...
# Обрабатываем ссылку 1341 / 4975...
# Обрабатываем ссылку 1342 / 4975...
# Обрабатываем ссылку 1343 / 4975...
# Обрабатываем ссылку 1344 / 4975...
# Обрабатываем ссылку 1345 / 4975...
# Обрабатываем ссылку 1346 / 4975...
# Обрабатываем ссылку 1347 / 4975...
# Обрабатываем ссылку 1348 / 4975...
# Обрабатываем ссылку 1349 / 4975...
# Обрабатываем ссылку 1350 / 4975...
# Обрабатываем ссылку 1351 / 4975...
# Обрабатываем ссылку 1352 / 4975...
# Обрабатываем ссылку 1353 / 4975...
# Обрабатываем ссылку 1354 / 4975...
# Обрабатываем ссылку 1355 / 4975...
# Обрабатываем ссылку 1356 / 4975...
# Обрабатываем ссылку 1357 / 4975...
# Обрабатываем ссылку 1358 / 4975...
# Обрабатываем ссылку 1359 / 4975...
# Обрабатываем ссылку 1360 / 4975...
# Обрабатываем ссылку 1361 / 4975...
# Обрабатываем ссылку 1362 / 4975...
# Обрабатываем ссылку 1363 / 4975...
# Обрабатываем ссылку 1364 / 4975...
# Обрабатываем ссылку 1365 / 4975...
# Обрабатываем ссылку 1366 / 4975...
# Обрабатываем ссылку 1367 / 4975...
# Обрабатываем ссылку 1368 / 4975...
# Обрабатываем ссылку 1369 / 4975...
# Обрабатываем ссылку 1370 / 4975...
# Обрабатываем ссылку 1371 / 4975...
# Обрабатываем ссылку 1372 / 4975...
# Обрабатываем ссылку 1373 / 4975...
# Обрабатываем ссылку 1374 / 4975...
# Обрабатываем ссылку 1375 / 4975...
# Обрабатываем ссылку 1376 / 4975...
# Обрабатываем ссылку 1377 / 4975...
# Обрабатываем ссылку 1379 / 4975...
# Обрабатываем ссылку 1380 / 4975...
# Обрабатываем ссылку 1381 / 4975...
# Обрабатываем ссылку 1382 / 4975...
# Обрабатываем ссылку 1383 / 4975...
# Обрабатываем ссылку 1384 / 4975...
# Обрабатываем ссылку 1385 / 4975...
# Обрабатываем ссылку 1386 / 4975...
# Обрабатываем ссылку 1387 / 4975...
# Обрабатываем ссылку 1388 / 4975...
# Обрабатываем ссылку 1389 / 4975...
# Обрабатываем ссылку 1390 / 4975...
# Обрабатываем ссылку 1391 / 4975...
# Обрабатываем ссылку 1392 / 4975...
# Обрабатываем ссылку 1393 / 4975...
# Обрабатываем ссылку 1394 / 4975...
# Обрабатываем ссылку 1395 / 4975...
# Обрабатываем ссылку 1396 / 4975...
# Обрабатываем ссылку 1397 / 4975...
# Обрабатываем ссылку 1398 / 4975...
# Обрабатываем ссылку 1399 / 4975...
# Обрабатываем ссылку 1400 / 4975...
# Обрабатываем ссылку 1401 / 4975...
# Обрабатываем ссылку 1402 / 4975...
# Обрабатываем ссылку 1403 / 4975...
# Обрабатываем ссылку 1404 / 4975...
# ...
# Обрабатываем ссылку 4518 / 4975...
# Обрабатываем ссылку 4519 / 4975...
# Обрабатываем ссылку 4520 / 4975...
# Обрабатываем ссылку 4521 / 4975...
# Обрабатываем ссылку 4522 / 4975...
# Обрабатываем ссылку 4523 / 4975...
# Обрабатываем ссылку 4524 / 4975...
# Обрабатываем ссылку 4525 / 4975...
# Обрабатываем ссылку 4526 / 4975...
# Обрабатываем ссылку 4527 / 4975...
# Обрабатываем ссылку 4528 / 4975...
# Обрабатываем ссылку 4529 / 4975...
# Обрабатываем ссылку 4530 / 4975...
# Обрабатываем ссылку 4531 / 4975...
# Обрабатываем ссылку 4532 / 4975...
# Обрабатываем ссылку 4533 / 4975...
# Обрабатываем ссылку 4534 / 4975...
# Обрабатываем ссылку 4535 / 4975...
# Обрабатываем ссылку 4536 / 4975...
# Обрабатываем ссылку 4537 / 4975...
# Обрабатываем ссылку 4538 / 4975...
# Обрабатываем ссылку 4539 / 4975...
# Обрабатываем ссылку 4540 / 4975...
# Обрабатываем ссылку 4541 / 4975...
# Обрабатываем ссылку 4542 / 4975...
# Обрабатываем ссылку 4543 / 4975...
# Обрабатываем ссылку 4544 / 4975...
# Обрабатываем ссылку 4545 / 4975...
# Обрабатываем ссылку 4546 / 4975...
# Обрабатываем ссылку 4547 / 4975...
# Обрабатываем ссылку 4548 / 4975...
# Обрабатываем ссылку 4549 / 4975...
# Обрабатываем ссылку 4550 / 4975...
# Обрабатываем ссылку 4551 / 4975...
# Обрабатываем ссылку 4552 / 4975...
# Обрабатываем ссылку 4553 / 4975...
# Обрабатываем ссылку 4554 / 4975...
# Обрабатываем ссылку 4555 / 4975...
# Обрабатываем ссылку 4556 / 4975...
# Обрабатываем ссылку 4557 / 4975...
# Обрабатываем ссылку 4558 / 4975...
# Обрабатываем ссылку 4559 / 4975...
# Обрабатываем ссылку 4560 / 4975...
# Обрабатываем ссылку 4561 / 4975...
# Обрабатываем ссылку 4562 / 4975...
# Обрабатываем ссылку 4563 / 4975...
# Обрабатываем ссылку 4564 / 4975...
# Обрабатываем ссылку 4565 / 4975...
# Обрабатываем ссылку 4566 / 4975...
# Обрабатываем ссылку 4567 / 4975...
# Обрабатываем ссылку 4568 / 4975...
# Обрабатываем ссылку 4569 / 4975...
# Обрабатываем ссылку 4570 / 4975...
# Обрабатываем ссылку 4571 / 4975...
# Обрабатываем ссылку 4572 / 4975...
# Обрабатываем ссылку 4573 / 4975...
# Обрабатываем ссылку 4574 / 4975...
# Обрабатываем ссылку 4575 / 4975...
# Обрабатываем ссылку 4576 / 4975...
# Обрабатываем ссылку 4577 / 4975...
# Обрабатываем ссылку 4578 / 4975...
# Обрабатываем ссылку 4579 / 4975...
# Обрабатываем ссылку 4580 / 4975...
# Обрабатываем ссылку 4581 / 4975...
# Обрабатываем ссылку 4582 / 4975...
# Обрабатываем ссылку 4583 / 4975...
# Обрабатываем ссылку 4584 / 4975...
# Обрабатываем ссылку 4585 / 4975...
# Обрабатываем ссылку 4586 / 4975...
# Обрабатываем ссылку 4587 / 4975...
# Обрабатываем ссылку 4588 / 4975...
# Обрабатываем ссылку 4589 / 4975...
# Обрабатываем ссылку 4590 / 4975...
# Обрабатываем ссылку 4591 / 4975...
# Обрабатываем ссылку 4592 / 4975...
# Обрабатываем ссылку 4593 / 4975...
# Обрабатываем ссылку 4594 / 4975...
# Обрабатываем ссылку 4595 / 4975...
# Обрабатываем ссылку 4596 / 4975...
# Обрабатываем ссылку 4597 / 4975...
# Обрабатываем ссылку 4598 / 4975...
# Обрабатываем ссылку 4599 / 4975...
# Обрабатываем ссылку 4600 / 4975...
# Обрабатываем ссылку 4601 / 4975...
# Обрабатываем ссылку 4602 / 4975...
# Обрабатываем ссылку 4603 / 4975...
# Обрабатываем ссылку 4604 / 4975...
# Обрабатываем ссылку 4605 / 4975...
# Обрабатываем ссылку 4606 / 4975...
# Обрабатываем ссылку 4607 / 4975...
# Обрабатываем ссылку 4608 / 4975...
# Обрабатываем ссылку 4609 / 4975...
# Обрабатываем ссылку 4610 / 4975...
# Обрабатываем ссылку 4611 / 4975...
# Обрабатываем ссылку 4612 / 4975...
# Обрабатываем ссылку 4613 / 4975...
# Обрабатываем ссылку 4614 / 4975...
# Обрабатываем ссылку 4615 / 4975...
# Обрабатываем ссылку 4616 / 4975...
# Обрабатываем ссылку 4617 / 4975...
# Обрабатываем ссылку 4618 / 4975...
# Обрабатываем ссылку 4619 / 4975...
# Обрабатываем ссылку 4620 / 4975...
# Обрабатываем ссылку 4621 / 4975...
# Обрабатываем ссылку 4622 / 4975...
# Обрабатываем ссылку 4623 / 4975...
# Обрабатываем ссылку 4624 / 4975...
# Обрабатываем ссылку 4625 / 4975...
# Обрабатываем ссылку 4626 / 4975...
# Обрабатываем ссылку 4627 / 4975...
# Обрабатываем ссылку 4628 / 4975...
# Обрабатываем ссылку 4629 / 4975...
# Обрабатываем ссылку 4630 / 4975...
# Обрабатываем ссылку 4631 / 4975...
# Обрабатываем ссылку 4632 / 4975...
# Обрабатываем ссылку 4633 / 4975...
# Обрабатываем ссылку 4634 / 4975...
# Обрабатываем ссылку 4635 / 4975...
# Обрабатываем ссылку 4636 / 4975...
# Обрабатываем ссылку 4637 / 4975...
# Обрабатываем ссылку 4638 / 4975...
# Обрабатываем ссылку 4639 / 4975...
# Обрабатываем ссылку 4640 / 4975...
# Обрабатываем ссылку 4641 / 4975...
# Обрабатываем ссылку 4642 / 4975...
# Обрабатываем ссылку 4643 / 4975...
# Обрабатываем ссылку 4644 / 4975...
# Обрабатываем ссылку 4645 / 4975...
# Обрабатываем ссылку 4646 / 4975...
# Обрабатываем ссылку 4647 / 4975...
# Обрабатываем ссылку 4648 / 4975...
# Обрабатываем ссылку 4649 / 4975...
# Обрабатываем ссылку 4650 / 4975...
# Обрабатываем ссылку 4651 / 4975...
# Обрабатываем ссылку 4652 / 4975...
# Обрабатываем ссылку 4653 / 4975...
# Обрабатываем ссылку 4654 / 4975...
# Обрабатываем ссылку 4655 / 4975...
# Обрабатываем ссылку 4656 / 4975...
# Обрабатываем ссылку 4657 / 4975...
# Обрабатываем ссылку 4658 / 4975...
# Обрабатываем ссылку 4659 / 4975...
# Обрабатываем ссылку 4660 / 4975...
# Обрабатываем ссылку 4661 / 4975...
# Обрабатываем ссылку 4662 / 4975...
# Обрабатываем ссылку 4663 / 4975...
# Обрабатываем ссылку 4664 / 4975...
# Обрабатываем ссылку 4665 / 4975...
# Обрабатываем ссылку 4666 / 4975...
# Обрабатываем ссылку 4667 / 4975...
# Обрабатываем ссылку 4668 / 4975...
# Обрабатываем ссылку 4669 / 4975...
# Обрабатываем ссылку 4670 / 4975...
# Обрабатываем ссылку 4671 / 4975...
# Обрабатываем ссылку 4672 / 4975...
# Обрабатываем ссылку 4673 / 4975...
# Обрабатываем ссылку 4674 / 4975...
# Обрабатываем ссылку 4675 / 4975...
# Обрабатываем ссылку 4676 / 4975...
# Обрабатываем ссылку 4677 / 4975...
# Обрабатываем ссылку 4678 / 4975...
# Обрабатываем ссылку 4679 / 4975...
# Обрабатываем ссылку 4680 / 4975...
# Обрабатываем ссылку 4681 / 4975...
# Обрабатываем ссылку 4682 / 4975...
# Обрабатываем ссылку 4683 / 4975...
# Обрабатываем ссылку 4684 / 4975...
# Обрабатываем ссылку 4685 / 4975...
# Обрабатываем ссылку 4686 / 4975...
# Обрабатываем ссылку 4687 / 4975...
# Обрабатываем ссылку 4688 / 4975...
# Обрабатываем ссылку 4689 / 4975...
# Обрабатываем ссылку 4690 / 4975...
# Обрабатываем ссылку 4691 / 4975...
# Обрабатываем ссылку 4692 / 4975...
# Обрабатываем ссылку 4693 / 4975...
# Обрабатываем ссылку 4694 / 4975...
# Обрабатываем ссылку 4695 / 4975...
# Обрабатываем ссылку 4696 / 4975...
# Обрабатываем ссылку 4697 / 4975...
# Обрабатываем ссылку 4698 / 4975...
# Обрабатываем ссылку 4699 / 4975...
# Обрабатываем ссылку 4700 / 4975...
# Обрабатываем ссылку 4701 / 4975...
# Обрабатываем ссылку 4702 / 4975...
# Обрабатываем ссылку 4703 / 4975...
# Обрабатываем ссылку 4704 / 4975...
# Обрабатываем ссылку 4705 / 4975...
# Обрабатываем ссылку 4706 / 4975...
# Обрабатываем ссылку 4707 / 4975...
# Обрабатываем ссылку 4708 / 4975...
# Обрабатываем ссылку 4709 / 4975...
# Обрабатываем ссылку 4710 / 4975...
# Обрабатываем ссылку 4711 / 4975...
# Обрабатываем ссылку 4712 / 4975...
# Обрабатываем ссылку 4713 / 4975...
# Обрабатываем ссылку 4714 / 4975...
# Обрабатываем ссылку 4715 / 4975...
# Обрабатываем ссылку 4716 / 4975...
# Обрабатываем ссылку 4717 / 4975...
# Обрабатываем ссылку 4718 / 4975...
# Обрабатываем ссылку 4719 / 4975...
# Обрабатываем ссылку 4720 / 4975...
# Обрабатываем ссылку 4721 / 4975...
# Обрабатываем ссылку 4722 / 4975...
# Обрабатываем ссылку 4723 / 4975...
# Обрабатываем ссылку 4724 / 4975...
# Обрабатываем ссылку 4725 / 4975...
# Обрабатываем ссылку 4726 / 4975...
# Обрабатываем ссылку 4727 / 4975...
# Обрабатываем ссылку 4728 / 4975...
# Обрабатываем ссылку 4729 / 4975...
# Обрабатываем ссылку 4730 / 4975...
# Обрабатываем ссылку 4731 / 4975...
# Обрабатываем ссылку 4732 / 4975...
# Обрабатываем ссылку 4733 / 4975...
# Обрабатываем ссылку 4734 / 4975...
# Обрабатываем ссылку 4735 / 4975...
# Обрабатываем ссылку 4736 / 4975...
# Обрабатываем ссылку 4737 / 4975...
# Обрабатываем ссылку 4738 / 4975...
# Обрабатываем ссылку 4739 / 4975...
# Обрабатываем ссылку 4740 / 4975...
# Обрабатываем ссылку 4741 / 4975...
# Обрабатываем ссылку 4742 / 4975...
# Обрабатываем ссылку 4743 / 4975...
# Обрабатываем ссылку 4744 / 4975...
# Обрабатываем ссылку 4745 / 4975...
# Обрабатываем ссылку 4746 / 4975...
# Обрабатываем ссылку 4747 / 4975...
# Обрабатываем ссылку 4748 / 4975...
# Обрабатываем ссылку 4749 / 4975...
# Обрабатываем ссылку 4750 / 4975...
# Обрабатываем ссылку 4751 / 4975...
# Обрабатываем ссылку 4752 / 4975...
# Обрабатываем ссылку 4753 / 4975...
# Обрабатываем ссылку 4754 / 4975...
# Обрабатываем ссылку 4755 / 4975...
# Обрабатываем ссылку 4756 / 4975...
# Обрабатываем ссылку 4757 / 4975...
# Обрабатываем ссылку 4758 / 4975...
# Обрабатываем ссылку 4759 / 4975...
# Обрабатываем ссылку 4761 / 4975...
# Обрабатываем ссылку 4762 / 4975...
# Обрабатываем ссылку 4763 / 4975...
# Обрабатываем ссылку 4764 / 4975...
# Обрабатываем ссылку 4765 / 4975...
# Обрабатываем ссылку 4766 / 4975...
# Обрабатываем ссылку 4767 / 4975...
# Обрабатываем ссылку 4768 / 4975...
# Обрабатываем ссылку 4769 / 4975...
# Обрабатываем ссылку 4770 / 4975...
# Обрабатываем ссылку 4771 / 4975...
# Обрабатываем ссылку 4772 / 4975...
# Обрабатываем ссылку 4773 / 4975...
# Обрабатываем ссылку 4774 / 4975...
# Обрабатываем ссылку 4775 / 4975...
# Обрабатываем ссылку 4776 / 4975...
# Обрабатываем ссылку 4777 / 4975...
# Обрабатываем ссылку 4778 / 4975...
# Обрабатываем ссылку 4779 / 4975...
# Обрабатываем ссылку 4780 / 4975...
# Обрабатываем ссылку 4781 / 4975...
# Обрабатываем ссылку 4782 / 4975...
# Обрабатываем ссылку 4783 / 4975...
# Обрабатываем ссылку 4784 / 4975...
# Обрабатываем ссылку 4785 / 4975...
# Обрабатываем ссылку 4786 / 4975...
# Обрабатываем ссылку 4787 / 4975...
# Обрабатываем ссылку 4788 / 4975...
# Обрабатываем ссылку 4789 / 4975...
# Обрабатываем ссылку 4790 / 4975...
# Обрабатываем ссылку 4791 / 4975...
# Обрабатываем ссылку 4792 / 4975...
# Обрабатываем ссылку 4793 / 4975...
# Обрабатываем ссылку 4794 / 4975...
# Обрабатываем ссылку 4795 / 4975...
# Обрабатываем ссылку 4796 / 4975...
# Обрабатываем ссылку 4797 / 4975...
# Обрабатываем ссылку 4798 / 4975...
# Обрабатываем ссылку 4799 / 4975...
# Обрабатываем ссылку 4800 / 4975...
# Обрабатываем ссылку 4801 / 4975...
# Обрабатываем ссылку 4802 / 4975...
# Обрабатываем ссылку 4803 / 4975...
# Обрабатываем ссылку 4804 / 4975...
# Обрабатываем ссылку 4805 / 4975...
# Обрабатываем ссылку 4806 / 4975...
# Обрабатываем ссылку 4807 / 4975...
# Обрабатываем ссылку 4808 / 4975...
# Обрабатываем ссылку 4809 / 4975...
# Обрабатываем ссылку 4810 / 4975...
# Обрабатываем ссылку 4811 / 4975...
# Обрабатываем ссылку 4812 / 4975...
# Обрабатываем ссылку 4813 / 4975...
# Обрабатываем ссылку 4814 / 4975...
# Обрабатываем ссылку 4815 / 4975...
# Обрабатываем ссылку 4816 / 4975...
# Обрабатываем ссылку 4817 / 4975...
# Обрабатываем ссылку 4818 / 4975...
# Обрабатываем ссылку 4819 / 4975...
# Обрабатываем ссылку 4820 / 4975...
# Обрабатываем ссылку 4821 / 4975...
# Обрабатываем ссылку 4822 / 4975...
# Обрабатываем ссылку 4823 / 4975...
# Обрабатываем ссылку 4824 / 4975...
# Обрабатываем ссылку 4825 / 4975...
# Обрабатываем ссылку 4826 / 4975...
# Обрабатываем ссылку 4827 / 4975...
# Обрабатываем ссылку 4828 / 4975...
# Обрабатываем ссылку 4829 / 4975...
# Обрабатываем ссылку 4830 / 4975...
# Обрабатываем ссылку 4831 / 4975...
# Обрабатываем ссылку 4832 / 4975...
# Обрабатываем ссылку 4833 / 4975...
# Обрабатываем ссылку 4834 / 4975...
# Обрабатываем ссылку 4835 / 4975...
# Обрабатываем ссылку 4836 / 4975...
# Обрабатываем ссылку 4837 / 4975...
# Обрабатываем ссылку 4838 / 4975...
# Обрабатываем ссылку 4839 / 4975...
# Обрабатываем ссылку 4840 / 4975...
# Обрабатываем ссылку 4841 / 4975...
# Обрабатываем ссылку 4842 / 4975...
# Обрабатываем ссылку 4843 / 4975...
# Обрабатываем ссылку 4844 / 4975...
# Обрабатываем ссылку 4845 / 4975...
# Обрабатываем ссылку 4846 / 4975...
# Обрабатываем ссылку 4847 / 4975...
# Обрабатываем ссылку 4848 / 4975...
# Обрабатываем ссылку 4849 / 4975...
# Обрабатываем ссылку 4850 / 4975...
# Обрабатываем ссылку 4851 / 4975...
# Обрабатываем ссылку 4852 / 4975...
# Обрабатываем ссылку 4853 / 4975...
# Обрабатываем ссылку 4854 / 4975...
# Обрабатываем ссылку 4855 / 4975...
# Обрабатываем ссылку 4856 / 4975...
# Обрабатываем ссылку 4857 / 4975...
# Обрабатываем ссылку 4858 / 4975...
# Обрабатываем ссылку 4859 / 4975...
# Обрабатываем ссылку 4860 / 4975...
# Обрабатываем ссылку 4861 / 4975...
# Обрабатываем ссылку 4862 / 4975...
# Обрабатываем ссылку 4863 / 4975...
# Обрабатываем ссылку 4864 / 4975...
# Обрабатываем ссылку 4865 / 4975...
# Обрабатываем ссылку 4866 / 4975...
# Обрабатываем ссылку 4867 / 4975...
# Обрабатываем ссылку 4868 / 4975...
# Обрабатываем ссылку 4869 / 4975...
# Обрабатываем ссылку 4870 / 4975...
# Обрабатываем ссылку 4871 / 4975...
# Обрабатываем ссылку 4872 / 4975...
# Обрабатываем ссылку 4873 / 4975...
# Обрабатываем ссылку 4874 / 4975...
# Обрабатываем ссылку 4875 / 4975...
# Обрабатываем ссылку 4876 / 4975...
# Обрабатываем ссылку 4877 / 4975...
# Обрабатываем ссылку 4878 / 4975...
# Обрабатываем ссылку 4879 / 4975...
# Обрабатываем ссылку 4880 / 4975...
# Обрабатываем ссылку 4881 / 4975...
# Обрабатываем ссылку 4882 / 4975...
# Обрабатываем ссылку 4883 / 4975...
# Обрабатываем ссылку 4884 / 4975...
# Обрабатываем ссылку 4885 / 4975...
# Обрабатываем ссылку 4886 / 4975...
# Обрабатываем ссылку 4887 / 4975...
# Обрабатываем ссылку 4888 / 4975...
# Обрабатываем ссылку 4889 / 4975...
# Обрабатываем ссылку 4890 / 4975...
# Обрабатываем ссылку 4891 / 4975...
# Обрабатываем ссылку 4892 / 4975...
# Обрабатываем ссылку 4893 / 4975...
# Обрабатываем ссылку 4894 / 4975...
# Обрабатываем ссылку 4895 / 4975...
# Обрабатываем ссылку 4896 / 4975...
# Обрабатываем ссылку 4897 / 4975...
# Обрабатываем ссылку 4898 / 4975...
# Обрабатываем ссылку 4899 / 4975...
# Обрабатываем ссылку 4900 / 4975...
# Обрабатываем ссылку 4901 / 4975...
# Обрабатываем ссылку 4902 / 4975...
# Обрабатываем ссылку 4903 / 4975...
# Обрабатываем ссылку 4904 / 4975...
# Обрабатываем ссылку 4905 / 4975...
# Обрабатываем ссылку 4906 / 4975...
# Обрабатываем ссылку 4907 / 4975...
# Обрабатываем ссылку 4908 / 4975...
# Обрабатываем ссылку 4909 / 4975...
# Обрабатываем ссылку 4910 / 4975...
# Обрабатываем ссылку 4911 / 4975...
# Обрабатываем ссылку 4912 / 4975...
# Обрабатываем ссылку 4913 / 4975...
# Обрабатываем ссылку 4914 / 4975...
# Обрабатываем ссылку 4915 / 4975...
# Обрабатываем ссылку 4916 / 4975...
# Обрабатываем ссылку 4917 / 4975...
# Обрабатываем ссылку 4918 / 4975...
# Обрабатываем ссылку 4919 / 4975...
# Обрабатываем ссылку 4920 / 4975...
# Обрабатываем ссылку 4921 / 4975...
# Обрабатываем ссылку 4922 / 4975...
# Обрабатываем ссылку 4923 / 4975...
# Обрабатываем ссылку 4924 / 4975...
# Обрабатываем ссылку 4925 / 4975...
# Обрабатываем ссылку 4926 / 4975...
# Обрабатываем ссылку 4927 / 4975...
# Обрабатываем ссылку 4928 / 4975...
# Обрабатываем ссылку 4929 / 4975...
# Обрабатываем ссылку 4930 / 4975...
# Обрабатываем ссылку 4931 / 4975...
# Обрабатываем ссылку 4932 / 4975...
# Обрабатываем ссылку 4933 / 4975...
# Обрабатываем ссылку 4934 / 4975...
# Обрабатываем ссылку 4935 / 4975...
# Обрабатываем ссылку 4936 / 4975...
# Обрабатываем ссылку 4937 / 4975...
# Обрабатываем ссылку 4938 / 4975...
# Обрабатываем ссылку 4939 / 4975...
# Обрабатываем ссылку 4940 / 4975...
# Обрабатываем ссылку 4941 / 4975...
# Обрабатываем ссылку 4942 / 4975...
# Обрабатываем ссылку 4943 / 4975...
# Обрабатываем ссылку 4944 / 4975...
# Обрабатываем ссылку 4945 / 4975...
# Обрабатываем ссылку 4946 / 4975...
# Обрабатываем ссылку 4947 / 4975...
# Обрабатываем ссылку 4948 / 4975...
# Обрабатываем ссылку 4949 / 4975...
# Обрабатываем ссылку 4950 / 4975...
# Обрабатываем ссылку 4951 / 4975...
# Обрабатываем ссылку 4952 / 4975...
# Обрабатываем ссылку 4953 / 4975...
# Обрабатываем ссылку 4954 / 4975...
# Обрабатываем ссылку 4955 / 4975...
# Обрабатываем ссылку 4956 / 4975...
# Обрабатываем ссылку 4957 / 4975...
# Обрабатываем ссылку 4958 / 4975...
# Обрабатываем ссылку 4959 / 4975...
# Обрабатываем ссылку 4960 / 4975...
# Обрабатываем ссылку 4961 / 4975...
# Обрабатываем ссылку 4962 / 4975...
# Обрабатываем ссылку 4963 / 4975...
# Обрабатываем ссылку 4964 / 4975...
# Обрабатываем ссылку 4965 / 4975...
# Обрабатываем ссылку 4966 / 4975...
# Обрабатываем ссылку 4967 / 4975...
# Обрабатываем ссылку 4968 / 4975...
# Обрабатываем ссылку 4969 / 4975...
# Обрабатываем ссылку 4970 / 4975...
# Обрабатываем ссылку 4971 / 4975...
# Обрабатываем ссылку 4972 / 4975...
# Обрабатываем ссылку 4973 / 4975...
# Обрабатываем ссылку 4974 / 4975...
# Обрабатываем ссылку 4975 / 4975...

# %%
urls = [i for i in neg_data]
results_neg = await bank_data(urls)
# Out:
# Обрабатываем ссылку 1 / 4975...
# Обрабатываем ссылку 2 / 4975...
# Обрабатываем ссылку 3 / 4975...
# Обрабатываем ссылку 4 / 4975...
# Обрабатываем ссылку 5 / 4975...
# Обрабатываем ссылку 6 / 4975...
# Обрабатываем ссылку 7 / 4975...
# Обрабатываем ссылку 8 / 4975...
# Обрабатываем ссылку 9 / 4975...
# Обрабатываем ссылку 10 / 4975...
# Обрабатываем ссылку 11 / 4975...
# Обрабатываем ссылку 12 / 4975...
# Обрабатываем ссылку 13 / 4975...
# Обрабатываем ссылку 14 / 4975...
# Обрабатываем ссылку 15 / 4975...
# Обрабатываем ссылку 16 / 4975...
# Обрабатываем ссылку 17 / 4975...
# Обрабатываем ссылку 18 / 4975...
# Обрабатываем ссылку 19 / 4975...
# Обрабатываем ссылку 20 / 4975...
# Обрабатываем ссылку 21 / 4975...
# Обрабатываем ссылку 22 / 4975...
# Обрабатываем ссылку 23 / 4975...
# Обрабатываем ссылку 24 / 4975...
# Обрабатываем ссылку 25 / 4975...
# Обрабатываем ссылку 26 / 4975...
# Обрабатываем ссылку 27 / 4975...
# Обрабатываем ссылку 28 / 4975...
# Обрабатываем ссылку 29 / 4975...
# Обрабатываем ссылку 30 / 4975...
# Обрабатываем ссылку 31 / 4975...
# Обрабатываем ссылку 32 / 4975...
# Обрабатываем ссылку 33 / 4975...
# Обрабатываем ссылку 34 / 4975...
# Обрабатываем ссылку 35 / 4975...
# Обрабатываем ссылку 36 / 4975...
# Обрабатываем ссылку 37 / 4975...
# Обрабатываем ссылку 38 / 4975...
# Обрабатываем ссылку 39 / 4975...
# Обрабатываем ссылку 40 / 4975...
# Обрабатываем ссылку 41 / 4975...
# Обрабатываем ссылку 42 / 4975...
# Обрабатываем ссылку 43 / 4975...
# Обрабатываем ссылку 44 / 4975...
# Обрабатываем ссылку 45 / 4975...
# Обрабатываем ссылку 46 / 4975...
# Обрабатываем ссылку 47 / 4975...
# Обрабатываем ссылку 48 / 4975...
# Обрабатываем ссылку 49 / 4975...
# Обрабатываем ссылку 50 / 4975...
# Обрабатываем ссылку 51 / 4975...
# Обрабатываем ссылку 52 / 4975...
# Обрабатываем ссылку 53 / 4975...
# Обрабатываем ссылку 54 / 4975...
# Обрабатываем ссылку 55 / 4975...
# Обрабатываем ссылку 56 / 4975...
# Обрабатываем ссылку 57 / 4975...
# Обрабатываем ссылку 58 / 4975...
# Обрабатываем ссылку 59 / 4975...
# Обрабатываем ссылку 60 / 4975...
# Обрабатываем ссылку 61 / 4975...
# Обрабатываем ссылку 62 / 4975...
# Обрабатываем ссылку 63 / 4975...
# Обрабатываем ссылку 64 / 4975...
# Обрабатываем ссылку 65 / 4975...
# Обрабатываем ссылку 66 / 4975...
# Обрабатываем ссылку 67 / 4975...
# Обрабатываем ссылку 68 / 4975...
# Обрабатываем ссылку 69 / 4975...
# Обрабатываем ссылку 70 / 4975...
# Обрабатываем ссылку 71 / 4975...
# Обрабатываем ссылку 72 / 4975...
# Обрабатываем ссылку 73 / 4975...
# Обрабатываем ссылку 74 / 4975...
# Обрабатываем ссылку 75 / 4975...
# Обрабатываем ссылку 76 / 4975...
# Обрабатываем ссылку 77 / 4975...
# Обрабатываем ссылку 78 / 4975...
# Обрабатываем ссылку 79 / 4975...
# Обрабатываем ссылку 80 / 4975...
# Обрабатываем ссылку 81 / 4975...
# Обрабатываем ссылку 82 / 4975...
# Обрабатываем ссылку 83 / 4975...
# Обрабатываем ссылку 84 / 4975...
# Обрабатываем ссылку 85 / 4975...
# Обрабатываем ссылку 86 / 4975...
# Обрабатываем ссылку 87 / 4975...
# Обрабатываем ссылку 88 / 4975...
# Обрабатываем ссылку 89 / 4975...
# Обрабатываем ссылку 90 / 4975...
# Обрабатываем ссылку 91 / 4975...
# Обрабатываем ссылку 92 / 4975...
# Обрабатываем ссылку 93 / 4975...
# Обрабатываем ссылку 94 / 4975...
# Обрабатываем ссылку 95 / 4975...
# Обрабатываем ссылку 96 / 4975...
# Обрабатываем ссылку 97 / 4975...
# Обрабатываем ссылку 98 / 4975...
# Обрабатываем ссылку 99 / 4975...
# Обрабатываем ссылку 100 / 4975...
# Обрабатываем ссылку 101 / 4975...
# Обрабатываем ссылку 102 / 4975...
# Обрабатываем ссылку 103 / 4975...
# Обрабатываем ссылку 104 / 4975...
# Обрабатываем ссылку 105 / 4975...
# Обрабатываем ссылку 106 / 4975...
# Обрабатываем ссылку 107 / 4975...
# Обрабатываем ссылку 108 / 4975...
# Обрабатываем ссылку 109 / 4975...
# Обрабатываем ссылку 110 / 4975...
# Обрабатываем ссылку 111 / 4975...
# Обрабатываем ссылку 112 / 4975...
# Обрабатываем ссылку 113 / 4975...
# Обрабатываем ссылку 114 / 4975...
# Обрабатываем ссылку 115 / 4975...
# Обрабатываем ссылку 116 / 4975...
# Обрабатываем ссылку 117 / 4975...
# Обрабатываем ссылку 118 / 4975...
# Обрабатываем ссылку 119 / 4975...
# Обрабатываем ссылку 120 / 4975...
# Обрабатываем ссылку 121 / 4975...
# Обрабатываем ссылку 122 / 4975...
# Обрабатываем ссылку 123 / 4975...
# Обрабатываем ссылку 124 / 4975...
# Обрабатываем ссылку 125 / 4975...
# Обрабатываем ссылку 126 / 4975...
# Обрабатываем ссылку 127 / 4975...
# Обрабатываем ссылку 128 / 4975...
# Обрабатываем ссылку 129 / 4975...
# Обрабатываем ссылку 130 / 4975...
# Обрабатываем ссылку 131 / 4975...
# Обрабатываем ссылку 132 / 4975...
# Обрабатываем ссылку 133 / 4975...
# Обрабатываем ссылку 134 / 4975...
# Обрабатываем ссылку 135 / 4975...
# Обрабатываем ссылку 136 / 4975...
# Обрабатываем ссылку 137 / 4975...
# Обрабатываем ссылку 138 / 4975...
# Обрабатываем ссылку 139 / 4975...
# Обрабатываем ссылку 140 / 4975...
# Обрабатываем ссылку 141 / 4975...
# Обрабатываем ссылку 142 / 4975...
# Обрабатываем ссылку 143 / 4975...
# Обрабатываем ссылку 144 / 4975...
# Обрабатываем ссылку 145 / 4975...
# Обрабатываем ссылку 146 / 4975...
# Обрабатываем ссылку 147 / 4975...
# Обрабатываем ссылку 148 / 4975...
# Обрабатываем ссылку 149 / 4975...
# Обрабатываем ссылку 150 / 4975...
# Обрабатываем ссылку 151 / 4975...
# Обрабатываем ссылку 152 / 4975...
# Обрабатываем ссылку 153 / 4975...
# Обрабатываем ссылку 154 / 4975...
# Обрабатываем ссылку 155 / 4975...
# Обрабатываем ссылку 156 / 4975...
# Обрабатываем ссылку 157 / 4975...
# Обрабатываем ссылку 158 / 4975...
# Обрабатываем ссылку 159 / 4975...
# Обрабатываем ссылку 160 / 4975...
# Обрабатываем ссылку 161 / 4975...
# Обрабатываем ссылку 162 / 4975...
# Обрабатываем ссылку 163 / 4975...
# Обрабатываем ссылку 164 / 4975...
# Обрабатываем ссылку 165 / 4975...
# Обрабатываем ссылку 166 / 4975...
# Обрабатываем ссылку 167 / 4975...
# Обрабатываем ссылку 168 / 4975...
# Обрабатываем ссылку 169 / 4975...
# Обрабатываем ссылку 170 / 4975...
# Обрабатываем ссылку 171 / 4975...
# Обрабатываем ссылку 172 / 4975...
# Обрабатываем ссылку 173 / 4975...
# Обрабатываем ссылку 174 / 4975...
# Обрабатываем ссылку 175 / 4975...
# Обрабатываем ссылку 176 / 4975...
# Обрабатываем ссылку 177 / 4975...
# Обрабатываем ссылку 178 / 4975...
# Обрабатываем ссылку 179 / 4975...
# Обрабатываем ссылку 180 / 4975...
# Обрабатываем ссылку 181 / 4975...
# Обрабатываем ссылку 182 / 4975...
# Обрабатываем ссылку 183 / 4975...
# Обрабатываем ссылку 184 / 4975...
# Обрабатываем ссылку 185 / 4975...
# Обрабатываем ссылку 186 / 4975...
# Обрабатываем ссылку 187 / 4975...
# Обрабатываем ссылку 188 / 4975...
# Обрабатываем ссылку 189 / 4975...
# Обрабатываем ссылку 190 / 4975...
# Обрабатываем ссылку 191 / 4975...
# Обрабатываем ссылку 192 / 4975...
# Обрабатываем ссылку 193 / 4975...
# Обрабатываем ссылку 194 / 4975...
# Обрабатываем ссылку 195 / 4975...
# Обрабатываем ссылку 196 / 4975...
# Обрабатываем ссылку 197 / 4975...
# Обрабатываем ссылку 198 / 4975...
# Обрабатываем ссылку 199 / 4975...
# Обрабатываем ссылку 200 / 4975...
# Обрабатываем ссылку 201 / 4975...
# Обрабатываем ссылку 202 / 4975...
# Обрабатываем ссылку 203 / 4975...
# Обрабатываем ссылку 204 / 4975...
# Обрабатываем ссылку 205 / 4975...
# Обрабатываем ссылку 206 / 4975...
# Обрабатываем ссылку 207 / 4975...
# Обрабатываем ссылку 208 / 4975...
# Обрабатываем ссылку 209 / 4975...
# Обрабатываем ссылку 210 / 4975...
# Обрабатываем ссылку 211 / 4975...
# Обрабатываем ссылку 212 / 4975...
# Обрабатываем ссылку 213 / 4975...
# Обрабатываем ссылку 214 / 4975...
# Обрабатываем ссылку 215 / 4975...
# Обрабатываем ссылку 216 / 4975...
# Обрабатываем ссылку 217 / 4975...
# Обрабатываем ссылку 218 / 4975...
# Обрабатываем ссылку 219 / 4975...
# Обрабатываем ссылку 220 / 4975...
# Обрабатываем ссылку 221 / 4975...
# Обрабатываем ссылку 222 / 4975...
# Обрабатываем ссылку 223 / 4975...
# Обрабатываем ссылку 224 / 4975...
# Обрабатываем ссылку 225 / 4975...
# Обрабатываем ссылку 226 / 4975...
# Обрабатываем ссылку 227 / 4975...
# Обрабатываем ссылку 228 / 4975...
# Обрабатываем ссылку 229 / 4975...
# Обрабатываем ссылку 230 / 4975...
# Обрабатываем ссылку 231 / 4975...
# Обрабатываем ссылку 232 / 4975...
# Обрабатываем ссылку 233 / 4975...
# Обрабатываем ссылку 234 / 4975...
# Обрабатываем ссылку 235 / 4975...
# Обрабатываем ссылку 236 / 4975...
# Обрабатываем ссылку 237 / 4975...
# Обрабатываем ссылку 238 / 4975...
# Обрабатываем ссылку 239 / 4975...
# Обрабатываем ссылку 240 / 4975...
# Обрабатываем ссылку 241 / 4975...
# Обрабатываем ссылку 242 / 4975...
# Обрабатываем ссылку 243 / 4975...
# Обрабатываем ссылку 244 / 4975...
# Обрабатываем ссылку 245 / 4975...
# Обрабатываем ссылку 246 / 4975...
# Обрабатываем ссылку 247 / 4975...
# Обрабатываем ссылку 248 / 4975...
# Обрабатываем ссылку 249 / 4975...
# Обрабатываем ссылку 250 / 4975...
# Обрабатываем ссылку 251 / 4975...
# Обрабатываем ссылку 252 / 4975...
# Обрабатываем ссылку 253 / 4975...
# Обрабатываем ссылку 254 / 4975...
# Обрабатываем ссылку 255 / 4975...
# Обрабатываем ссылку 256 / 4975...
# Обрабатываем ссылку 257 / 4975...
# Обрабатываем ссылку 258 / 4975...
# Обрабатываем ссылку 259 / 4975...
# Обрабатываем ссылку 260 / 4975...
# Обрабатываем ссылку 261 / 4975...
# Обрабатываем ссылку 262 / 4975...
# Обрабатываем ссылку 263 / 4975...
# Обрабатываем ссылку 264 / 4975...
# Обрабатываем ссылку 265 / 4975...
# Обрабатываем ссылку 266 / 4975...
# Обрабатываем ссылку 267 / 4975...
# Обрабатываем ссылку 268 / 4975...
# Обрабатываем ссылку 269 / 4975...
# Обрабатываем ссылку 270 / 4975...
# Обрабатываем ссылку 271 / 4975...
# Обрабатываем ссылку 272 / 4975...
# Обрабатываем ссылку 273 / 4975...
# Обрабатываем ссылку 274 / 4975...
# Обрабатываем ссылку 275 / 4975...
# Обрабатываем ссылку 276 / 4975...
# Обрабатываем ссылку 277 / 4975...
# Обрабатываем ссылку 278 / 4975...
# Обрабатываем ссылку 280 / 4975...
# Обрабатываем ссылку 281 / 4975...
# Обрабатываем ссылку 282 / 4975...
# Обрабатываем ссылку 283 / 4975...
# Обрабатываем ссылку 284 / 4975...
# Обрабатываем ссылку 285 / 4975...
# Обрабатываем ссылку 286 / 4975...
# Обрабатываем ссылку 287 / 4975...
# Обрабатываем ссылку 288 / 4975...
# Обрабатываем ссылку 289 / 4975...
# Обрабатываем ссылку 290 / 4975...
# Обрабатываем ссылку 291 / 4975...
# Обрабатываем ссылку 292 / 4975...
# Обрабатываем ссылку 293 / 4975...
# Обрабатываем ссылку 294 / 4975...
# Обрабатываем ссылку 295 / 4975...
# Обрабатываем ссылку 296 / 4975...
# Обрабатываем ссылку 297 / 4975...
# Обрабатываем ссылку 298 / 4975...
# Обрабатываем ссылку 299 / 4975...
# Обрабатываем ссылку 300 / 4975...
# Обрабатываем ссылку 301 / 4975...
# Обрабатываем ссылку 302 / 4975...
# Обрабатываем ссылку 303 / 4975...
# Обрабатываем ссылку 305 / 4975...
# Обрабатываем ссылку 306 / 4975...
# Обрабатываем ссылку 307 / 4975...
# Обрабатываем ссылку 308 / 4975...
# Обрабатываем ссылку 309 / 4975...
# Обрабатываем ссылку 310 / 4975...
# Обрабатываем ссылку 311 / 4975...
# Обрабатываем ссылку 312 / 4975...
# Обрабатываем ссылку 313 / 4975...
# Обрабатываем ссылку 314 / 4975...
# Обрабатываем ссылку 315 / 4975...
# Обрабатываем ссылку 316 / 4975...
# Обрабатываем ссылку 317 / 4975...
# Обрабатываем ссылку 318 / 4975...
# Обрабатываем ссылку 319 / 4975...
# Обрабатываем ссылку 320 / 4975...
# Обрабатываем ссылку 321 / 4975...
# Обрабатываем ссылку 322 / 4975...
# Обрабатываем ссылку 323 / 4975...
# Обрабатываем ссылку 324 / 4975...
# Обрабатываем ссылку 325 / 4975...
# Обрабатываем ссылку 326 / 4975...
# Обрабатываем ссылку 327 / 4975...
# Обрабатываем ссылку 328 / 4975...
# Обрабатываем ссылку 329 / 4975...
# Обрабатываем ссылку 330 / 4975...
# Обрабатываем ссылку 331 / 4975...
# Обрабатываем ссылку 332 / 4975...
# Обрабатываем ссылку 333 / 4975...
# Обрабатываем ссылку 334 / 4975...
# Обрабатываем ссылку 335 / 4975...
# Обрабатываем ссылку 336 / 4975...
# Обрабатываем ссылку 337 / 4975...
# Обрабатываем ссылку 338 / 4975...
# Обрабатываем ссылку 339 / 4975...
# Обрабатываем ссылку 341 / 4975...
# Обрабатываем ссылку 342 / 4975...
# Обрабатываем ссылку 343 / 4975...
# Обрабатываем ссылку 344 / 4975...
# Обрабатываем ссылку 345 / 4975...
# Обрабатываем ссылку 346 / 4975...
# Обрабатываем ссылку 347 / 4975...
# Обрабатываем ссылку 348 / 4975...
# Обрабатываем ссылку 349 / 4975...
# Обрабатываем ссылку 350 / 4975...
# Обрабатываем ссылку 353 / 4975...
# Обрабатываем ссылку 354 / 4975...
# Обрабатываем ссылку 355 / 4975...
# Обрабатываем ссылку 356 / 4975...
# Обрабатываем ссылку 357 / 4975...
# Обрабатываем ссылку 358 / 4975...
# Обрабатываем ссылку 359 / 4975...
# Обрабатываем ссылку 360 / 4975...
# Обрабатываем ссылку 361 / 4975...
# Обрабатываем ссылку 362 / 4975...
# Обрабатываем ссылку 363 / 4975...
# Обрабатываем ссылку 364 / 4975...
# Обрабатываем ссылку 365 / 4975...
# Обрабатываем ссылку 366 / 4975...
# Обрабатываем ссылку 367 / 4975...
# Обрабатываем ссылку 368 / 4975...
# Обрабатываем ссылку 369 / 4975...
# Обрабатываем ссылку 370 / 4975...
# Обрабатываем ссылку 372 / 4975...
# Обрабатываем ссылку 373 / 4975...
# Обрабатываем ссылку 374 / 4975...
# Обрабатываем ссылку 375 / 4975...
# Обрабатываем ссылку 376 / 4975...
# Обрабатываем ссылку 377 / 4975...
# Обрабатываем ссылку 378 / 4975...
# Обрабатываем ссылку 379 / 4975...
# Обрабатываем ссылку 380 / 4975...
# Обрабатываем ссылку 381 / 4975...
# Обрабатываем ссылку 382 / 4975...
# Обрабатываем ссылку 383 / 4975...
# Обрабатываем ссылку 384 / 4975...
# Обрабатываем ссылку 385 / 4975...
# Обрабатываем ссылку 386 / 4975...
# Обрабатываем ссылку 387 / 4975...
# Обрабатываем ссылку 388 / 4975...
# Обрабатываем ссылку 389 / 4975...
# Обрабатываем ссылку 390 / 4975...
# Обрабатываем ссылку 391 / 4975...
# Обрабатываем ссылку 392 / 4975...
# Обрабатываем ссылку 393 / 4975...
# Обрабатываем ссылку 394 / 4975...
# Обрабатываем ссылку 395 / 4975...
# Обрабатываем ссылку 396 / 4975...
# Обрабатываем ссылку 397 / 4975...
# Обрабатываем ссылку 398 / 4975...
# Обрабатываем ссылку 399 / 4975...
# Обрабатываем ссылку 400 / 4975...
# Обрабатываем ссылку 401 / 4975...
# Обрабатываем ссылку 402 / 4975...
# Обрабатываем ссылку 403 / 4975...
# Обрабатываем ссылку 404 / 4975...
# Обрабатываем ссылку 405 / 4975...
# Обрабатываем ссылку 406 / 4975...
# Обрабатываем ссылку 407 / 4975...
# Обрабатываем ссылку 408 / 4975...
# Обрабатываем ссылку 409 / 4975...
# Обрабатываем ссылку 410 / 4975...
# Обрабатываем ссылку 411 / 4975...
# Обрабатываем ссылку 412 / 4975...
# Обрабатываем ссылку 413 / 4975...
# Обрабатываем ссылку 414 / 4975...
# Обрабатываем ссылку 415 / 4975...
# Обрабатываем ссылку 416 / 4975...
# Обрабатываем ссылку 417 / 4975...
# Обрабатываем ссылку 418 / 4975...
# Обрабатываем ссылку 419 / 4975...
# Обрабатываем ссылку 420 / 4975...
# Обрабатываем ссылку 421 / 4975...
# Обрабатываем ссылку 422 / 4975...
# Обрабатываем ссылку 423 / 4975...
# Обрабатываем ссылку 424 / 4975...
# Обрабатываем ссылку 425 / 4975...
# Обрабатываем ссылку 426 / 4975...
# Обрабатываем ссылку 427 / 4975...
# Обрабатываем ссылку 428 / 4975...
# Обрабатываем ссылку 429 / 4975...
# Обрабатываем ссылку 430 / 4975...
# Обрабатываем ссылку 431 / 4975...
# Обрабатываем ссылку 432 / 4975...
# Обрабатываем ссылку 433 / 4975...
# Обрабатываем ссылку 434 / 4975...
# Обрабатываем ссылку 435 / 4975...
# Обрабатываем ссылку 436 / 4975...
# Обрабатываем ссылку 437 / 4975...
# Обрабатываем ссылку 438 / 4975...
# Обрабатываем ссылку 439 / 4975...
# Обрабатываем ссылку 440 / 4975...
# Обрабатываем ссылку 441 / 4975...
# Обрабатываем ссылку 442 / 4975...
# Обрабатываем ссылку 444 / 4975...
# Обрабатываем ссылку 445 / 4975...
# Обрабатываем ссылку 446 / 4975...
# Обрабатываем ссылку 447 / 4975...
# Обрабатываем ссылку 448 / 4975...
# Обрабатываем ссылку 449 / 4975...
# Обрабатываем ссылку 450 / 4975...
# Обрабатываем ссылку 451 / 4975...
# Обрабатываем ссылку 452 / 4975...
# Обрабатываем ссылку 453 / 4975...
# Обрабатываем ссылку 454 / 4975...
# Обрабатываем ссылку 455 / 4975...
# Обрабатываем ссылку 456 / 4975...
# Обрабатываем ссылку 457 / 4975...
# Обрабатываем ссылку 458 / 4975...
# Обрабатываем ссылку 459 / 4975...
# Обрабатываем ссылку 460 / 4975...
# Обрабатываем ссылку 461 / 4975...
# Обрабатываем ссылку 462 / 4975...
# Обрабатываем ссылку 463 / 4975...
# Обрабатываем ссылку 464 / 4975...
# Обрабатываем ссылку 465 / 4975...
# Обрабатываем ссылку 466 / 4975...
# Обрабатываем ссылку 467 / 4975...
# Обрабатываем ссылку 468 / 4975...
# Обрабатываем ссылку 469 / 4975...
# Обрабатываем ссылку 470 / 4975...
# Обрабатываем ссылку 471 / 4975...
# Обрабатываем ссылку 472 / 4975...
# Обрабатываем ссылку 473 / 4975...
# Обрабатываем ссылку 474 / 4975...
# Обрабатываем ссылку 475 / 4975...
# Обрабатываем ссылку 476 / 4975...
# Обрабатываем ссылку 477 / 4975...
# Обрабатываем ссылку 478 / 4975...
# Обрабатываем ссылку 479 / 4975...
# Обрабатываем ссылку 480 / 4975...
# Обрабатываем ссылку 481 / 4975...
# Обрабатываем ссылку 482 / 4975...
# Обрабатываем ссылку 483 / 4975...
# Обрабатываем ссылку 484 / 4975...
# Обрабатываем ссылку 485 / 4975...
# Обрабатываем ссылку 486 / 4975...
# Обрабатываем ссылку 487 / 4975...
# Обрабатываем ссылку 488 / 4975...
# Обрабатываем ссылку 489 / 4975...
# Обрабатываем ссылку 490 / 4975...
# Обрабатываем ссылку 491 / 4975...
# Обрабатываем ссылку 492 / 4975...
# Обрабатываем ссылку 493 / 4975...
# Обрабатываем ссылку 494 / 4975...
# Обрабатываем ссылку 495 / 4975...
# Обрабатываем ссылку 496 / 4975...
# Обрабатываем ссылку 497 / 4975...
# Обрабатываем ссылку 498 / 4975...
# Обрабатываем ссылку 499 / 4975...
# Обрабатываем ссылку 500 / 4975...
# Обрабатываем ссылку 501 / 4975...
# Обрабатываем ссылку 502 / 4975...
# Обрабатываем ссылку 503 / 4975...
# Обрабатываем ссылку 504 / 4975...
# Обрабатываем ссылку 505 / 4975...
# Обрабатываем ссылку 506 / 4975...
# Обрабатываем ссылку 507 / 4975...
# Обрабатываем ссылку 508 / 4975...
# Обрабатываем ссылку 509 / 4975...
# Обрабатываем ссылку 510 / 4975...
# Обрабатываем ссылку 511 / 4975...
# Обрабатываем ссылку 512 / 4975...
# Обрабатываем ссылку 513 / 4975...
# Обрабатываем ссылку 514 / 4975...
# Обрабатываем ссылку 515 / 4975...
# Обрабатываем ссылку 516 / 4975...
# Обрабатываем ссылку 517 / 4975...
# Обрабатываем ссылку 518 / 4975...
# Обрабатываем ссылку 519 / 4975...
# Обрабатываем ссылку 521 / 4975...
# Обрабатываем ссылку 522 / 4975...
# Обрабатываем ссылку 523 / 4975...
# Обрабатываем ссылку 524 / 4975...
# Обрабатываем ссылку 526 / 4975...
# Обрабатываем ссылку 527 / 4975...
# Обрабатываем ссылку 528 / 4975...
# Обрабатываем ссылку 529 / 4975...
# Обрабатываем ссылку 531 / 4975...
# Обрабатываем ссылку 532 / 4975...
# Обрабатываем ссылку 533 / 4975...
# Обрабатываем ссылку 534 / 4975...
# Обрабатываем ссылку 535 / 4975...
# Обрабатываем ссылку 536 / 4975...
# Обрабатываем ссылку 537 / 4975...
# Обрабатываем ссылку 538 / 4975...
# Обрабатываем ссылку 539 / 4975...
# Обрабатываем ссылку 540 / 4975...
# Обрабатываем ссылку 541 / 4975...
# Обрабатываем ссылку 542 / 4975...
# Обрабатываем ссылку 543 / 4975...
# Обрабатываем ссылку 544 / 4975...
# Обрабатываем ссылку 545 / 4975...
# Обрабатываем ссылку 546 / 4975...
# Обрабатываем ссылку 547 / 4975...
# Обрабатываем ссылку 548 / 4975...
# Обрабатываем ссылку 549 / 4975...
# Обрабатываем ссылку 550 / 4975...
# Обрабатываем ссылку 551 / 4975...
# Обрабатываем ссылку 552 / 4975...
# Обрабатываем ссылку 553 / 4975...
# Обрабатываем ссылку 554 / 4975...
# Обрабатываем ссылку 555 / 4975...
# Обрабатываем ссылку 556 / 4975...
# Обрабатываем ссылку 557 / 4975...
# Обрабатываем ссылку 558 / 4975...
# Обрабатываем ссылку 559 / 4975...
# Обрабатываем ссылку 560 / 4975...
# Обрабатываем ссылку 561 / 4975...
# Обрабатываем ссылку 562 / 4975...
# Обрабатываем ссылку 563 / 4975...
# Обрабатываем ссылку 564 / 4975...
# Обрабатываем ссылку 565 / 4975...
# Обрабатываем ссылку 566 / 4975...
# Обрабатываем ссылку 567 / 4975...
# Обрабатываем ссылку 568 / 4975...
# Обрабатываем ссылку 569 / 4975...
# Обрабатываем ссылку 570 / 4975...
# Обрабатываем ссылку 571 / 4975...
# Обрабатываем ссылку 572 / 4975...
# Обрабатываем ссылку 573 / 4975...
# Обрабатываем ссылку 574 / 4975...
# Обрабатываем ссылку 575 / 4975...
# Обрабатываем ссылку 576 / 4975...
# Обрабатываем ссылку 577 / 4975...
# Обрабатываем ссылку 578 / 4975...
# Обрабатываем ссылку 579 / 4975...
# Обрабатываем ссылку 580 / 4975...
# Обрабатываем ссылку 581 / 4975...
# Обрабатываем ссылку 582 / 4975...
# Обрабатываем ссылку 583 / 4975...
# Обрабатываем ссылку 584 / 4975...
# Обрабатываем ссылку 585 / 4975...
# Обрабатываем ссылку 586 / 4975...
# Обрабатываем ссылку 587 / 4975...
# Обрабатываем ссылку 588 / 4975...
# Обрабатываем ссылку 589 / 4975...
# Обрабатываем ссылку 590 / 4975...
# Обрабатываем ссылку 591 / 4975...
# Обрабатываем ссылку 592 / 4975...
# Обрабатываем ссылку 593 / 4975...
# Обрабатываем ссылку 594 / 4975...
# Обрабатываем ссылку 595 / 4975...
# Обрабатываем ссылку 596 / 4975...
# Обрабатываем ссылку 597 / 4975...
# Обрабатываем ссылку 598 / 4975...
# Обрабатываем ссылку 599 / 4975...
# Обрабатываем ссылку 600 / 4975...
# Обрабатываем ссылку 601 / 4975...
# Обрабатываем ссылку 602 / 4975...
# Обрабатываем ссылку 603 / 4975...
# Обрабатываем ссылку 604 / 4975...
# Обрабатываем ссылку 605 / 4975...
# Обрабатываем ссылку 606 / 4975...
# Обрабатываем ссылку 607 / 4975...
# Обрабатываем ссылку 608 / 4975...
# Обрабатываем ссылку 609 / 4975...
# Обрабатываем ссылку 610 / 4975...
# Обрабатываем ссылку 611 / 4975...
# Обрабатываем ссылку 612 / 4975...
# Обрабатываем ссылку 613 / 4975...
# Обрабатываем ссылку 614 / 4975...
# Обрабатываем ссылку 615 / 4975...
# Обрабатываем ссылку 616 / 4975...
# Обрабатываем ссылку 617 / 4975...
# Обрабатываем ссылку 618 / 4975...
# Обрабатываем ссылку 619 / 4975...
# Обрабатываем ссылку 620 / 4975...
# Обрабатываем ссылку 621 / 4975...
# Обрабатываем ссылку 622 / 4975...
# Обрабатываем ссылку 623 / 4975...
# Обрабатываем ссылку 624 / 4975...
# Обрабатываем ссылку 625 / 4975...
# Обрабатываем ссылку 626 / 4975...
# Обрабатываем ссылку 627 / 4975...
# Обрабатываем ссылку 628 / 4975...
# Обрабатываем ссылку 629 / 4975...
# Обрабатываем ссылку 630 / 4975...
# Обрабатываем ссылку 631 / 4975...
# Обрабатываем ссылку 632 / 4975...
# Обрабатываем ссылку 633 / 4975...
# Обрабатываем ссылку 634 / 4975...
# Обрабатываем ссылку 635 / 4975...
# Обрабатываем ссылку 636 / 4975...
# Обрабатываем ссылку 637 / 4975...
# Обрабатываем ссылку 638 / 4975...
# Обрабатываем ссылку 639 / 4975...
# Обрабатываем ссылку 640 / 4975...
# Обрабатываем ссылку 641 / 4975...
# Обрабатываем ссылку 642 / 4975...
# Обрабатываем ссылку 643 / 4975...
# Обрабатываем ссылку 644 / 4975...
# Обрабатываем ссылку 645 / 4975...
# Обрабатываем ссылку 646 / 4975...
# Обрабатываем ссылку 647 / 4975...
# Обрабатываем ссылку 648 / 4975...
# Обрабатываем ссылку 649 / 4975...
# Обрабатываем ссылку 650 / 4975...
# Обрабатываем ссылку 651 / 4975...
# Обрабатываем ссылку 652 / 4975...
# Обрабатываем ссылку 653 / 4975...
# Обрабатываем ссылку 654 / 4975...
# Обрабатываем ссылку 655 / 4975...
# Обрабатываем ссылку 656 / 4975...
# Обрабатываем ссылку 657 / 4975...
# Обрабатываем ссылку 658 / 4975...
# Обрабатываем ссылку 659 / 4975...
# Обрабатываем ссылку 660 / 4975...
# Обрабатываем ссылку 661 / 4975...
# Обрабатываем ссылку 662 / 4975...
# Обрабатываем ссылку 663 / 4975...
# Обрабатываем ссылку 664 / 4975...
# Обрабатываем ссылку 665 / 4975...
# Обрабатываем ссылку 666 / 4975...
# Обрабатываем ссылку 667 / 4975...
# Обрабатываем ссылку 668 / 4975...
# Обрабатываем ссылку 669 / 4975...
# Обрабатываем ссылку 670 / 4975...
# Обрабатываем ссылку 671 / 4975...
# Обрабатываем ссылку 672 / 4975...
# Обрабатываем ссылку 673 / 4975...
# Обрабатываем ссылку 674 / 4975...
# Обрабатываем ссылку 675 / 4975...
# Обрабатываем ссылку 676 / 4975...
# Обрабатываем ссылку 677 / 4975...
# Обрабатываем ссылку 678 / 4975...
# Обрабатываем ссылку 679 / 4975...
# Обрабатываем ссылку 680 / 4975...
# Обрабатываем ссылку 681 / 4975...
# Обрабатываем ссылку 682 / 4975...
# Обрабатываем ссылку 683 / 4975...
# Обрабатываем ссылку 684 / 4975...
# Обрабатываем ссылку 685 / 4975...
# Обрабатываем ссылку 686 / 4975...
# Обрабатываем ссылку 687 / 4975...
# Обрабатываем ссылку 688 / 4975...
# Обрабатываем ссылку 689 / 4975...
# Обрабатываем ссылку 690 / 4975...
# Обрабатываем ссылку 691 / 4975...
# Обрабатываем ссылку 692 / 4975...
# Обрабатываем ссылку 693 / 4975...
# Обрабатываем ссылку 694 / 4975...
# Обрабатываем ссылку 695 / 4975...
# Обрабатываем ссылку 696 / 4975...
# Обрабатываем ссылку 697 / 4975...
# Обрабатываем ссылку 698 / 4975...
# Обрабатываем ссылку 699 / 4975...
# Обрабатываем ссылку 700 / 4975...
# Обрабатываем ссылку 701 / 4975...
# Обрабатываем ссылку 702 / 4975...
# Обрабатываем ссылку 703 / 4975...
# Обрабатываем ссылку 704 / 4975...
# Обрабатываем ссылку 705 / 4975...
# Обрабатываем ссылку 706 / 4975...
# Обрабатываем ссылку 707 / 4975...
# Обрабатываем ссылку 708 / 4975...
# Обрабатываем ссылку 709 / 4975...
# Обрабатываем ссылку 710 / 4975...
# Обрабатываем ссылку 711 / 4975...
# Обрабатываем ссылку 712 / 4975...
# Обрабатываем ссылку 713 / 4975...
# Обрабатываем ссылку 714 / 4975...
# Обрабатываем ссылку 715 / 4975...
# Обрабатываем ссылку 716 / 4975...
# Обрабатываем ссылку 717 / 4975...
# Обрабатываем ссылку 718 / 4975...
# Обрабатываем ссылку 719 / 4975...
# Обрабатываем ссылку 720 / 4975...
# Обрабатываем ссылку 721 / 4975...
# Обрабатываем ссылку 722 / 4975...
# Обрабатываем ссылку 723 / 4975...
# Обрабатываем ссылку 724 / 4975...
# Обрабатываем ссылку 725 / 4975...
# Обрабатываем ссылку 726 / 4975...
# Обрабатываем ссылку 727 / 4975...
# Обрабатываем ссылку 728 / 4975...
# Обрабатываем ссылку 729 / 4975...
# Обрабатываем ссылку 730 / 4975...
# Обрабатываем ссылку 731 / 4975...
# Обрабатываем ссылку 732 / 4975...
# Обрабатываем ссылку 733 / 4975...
# Обрабатываем ссылку 734 / 4975...
# Обрабатываем ссылку 735 / 4975...
# Обрабатываем ссылку 736 / 4975...
# Обрабатываем ссылку 737 / 4975...
# Обрабатываем ссылку 738 / 4975...
# Обрабатываем ссылку 739 / 4975...
# Обрабатываем ссылку 740 / 4975...
# Обрабатываем ссылку 741 / 4975...
# Обрабатываем ссылку 742 / 4975...
# Обрабатываем ссылку 743 / 4975...
# Обрабатываем ссылку 744 / 4975...
# Обрабатываем ссылку 745 / 4975...
# Обрабатываем ссылку 746 / 4975...
# Обрабатываем ссылку 747 / 4975...
# Обрабатываем ссылку 748 / 4975...
# Обрабатываем ссылку 749 / 4975...
# Обрабатываем ссылку 750 / 4975...
# Обрабатываем ссылку 751 / 4975...
# Обрабатываем ссылку 752 / 4975...
# Обрабатываем ссылку 753 / 4975...
# Обрабатываем ссылку 754 / 4975...
# Обрабатываем ссылку 755 / 4975...
# Обрабатываем ссылку 756 / 4975...
# Обрабатываем ссылку 757 / 4975...
# Обрабатываем ссылку 758 / 4975...
# Обрабатываем ссылку 759 / 4975...
# Обрабатываем ссылку 760 / 4975...
# Обрабатываем ссылку 761 / 4975...
# Обрабатываем ссылку 762 / 4975...
# Обрабатываем ссылку 763 / 4975...
# Обрабатываем ссылку 764 / 4975...
# Обрабатываем ссылку 765 / 4975...
# Обрабатываем ссылку 766 / 4975...
# Обрабатываем ссылку 767 / 4975...
# Обрабатываем ссылку 768 / 4975...
# Обрабатываем ссылку 769 / 4975...
# Обрабатываем ссылку 770 / 4975...
# Обрабатываем ссылку 771 / 4975...
# Обрабатываем ссылку 772 / 4975...
# Обрабатываем ссылку 773 / 4975...
# Обрабатываем ссылку 774 / 4975...
# Обрабатываем ссылку 775 / 4975...
# Обрабатываем ссылку 776 / 4975...
# Обрабатываем ссылку 777 / 4975...
# Обрабатываем ссылку 778 / 4975...
# Обрабатываем ссылку 779 / 4975...
# Обрабатываем ссылку 780 / 4975...
# Обрабатываем ссылку 781 / 4975...
# Обрабатываем ссылку 782 / 4975...
# Обрабатываем ссылку 783 / 4975...
# Обрабатываем ссылку 784 / 4975...
# Обрабатываем ссылку 785 / 4975...
# Обрабатываем ссылку 786 / 4975...
# Обрабатываем ссылку 787 / 4975...
# Обрабатываем ссылку 788 / 4975...
# Обрабатываем ссылку 789 / 4975...
# Обрабатываем ссылку 790 / 4975...
# Обрабатываем ссылку 791 / 4975...
# Обрабатываем ссылку 792 / 4975...
# Обрабатываем ссылку 793 / 4975...
# Обрабатываем ссылку 794 / 4975...
# Обрабатываем ссылку 795 / 4975...
# Обрабатываем ссылку 796 / 4975...
# Обрабатываем ссылку 797 / 4975...
# Обрабатываем ссылку 798 / 4975...
# Обрабатываем ссылку 799 / 4975...
# Обрабатываем ссылку 800 / 4975...
# Обрабатываем ссылку 801 / 4975...
# Обрабатываем ссылку 802 / 4975...
# Обрабатываем ссылку 803 / 4975...
# Обрабатываем ссылку 804 / 4975...
# Обрабатываем ссылку 805 / 4975...
# Обрабатываем ссылку 806 / 4975...
# Обрабатываем ссылку 807 / 4975...
# Обрабатываем ссылку 808 / 4975...
# Обрабатываем ссылку 809 / 4975...
# Обрабатываем ссылку 810 / 4975...
# Обрабатываем ссылку 811 / 4975...
# Обрабатываем ссылку 812 / 4975...
# Обрабатываем ссылку 813 / 4975...
# Обрабатываем ссылку 814 / 4975...
# Обрабатываем ссылку 815 / 4975...
# Обрабатываем ссылку 816 / 4975...
# Обрабатываем ссылку 817 / 4975...
# Обрабатываем ссылку 818 / 4975...
# Обрабатываем ссылку 819 / 4975...
# Обрабатываем ссылку 820 / 4975...
# Обрабатываем ссылку 821 / 4975...
# Обрабатываем ссылку 822 / 4975...
# Обрабатываем ссылку 823 / 4975...
# Обрабатываем ссылку 824 / 4975...
# Обрабатываем ссылку 825 / 4975...
# Обрабатываем ссылку 826 / 4975...
# Обрабатываем ссылку 827 / 4975...
# Обрабатываем ссылку 828 / 4975...
# Обрабатываем ссылку 829 / 4975...
# Обрабатываем ссылку 830 / 4975...
# Обрабатываем ссылку 831 / 4975...
# Обрабатываем ссылку 832 / 4975...
# Обрабатываем ссылку 833 / 4975...
# Обрабатываем ссылку 834 / 4975...
# Обрабатываем ссылку 835 / 4975...
# Обрабатываем ссылку 836 / 4975...
# Обрабатываем ссылку 837 / 4975...
# Обрабатываем ссылку 838 / 4975...
# Обрабатываем ссылку 839 / 4975...
# Обрабатываем ссылку 840 / 4975...
# Обрабатываем ссылку 841 / 4975...
# Обрабатываем ссылку 842 / 4975...
# Обрабатываем ссылку 843 / 4975...
# Обрабатываем ссылку 844 / 4975...
# Обрабатываем ссылку 845 / 4975...
# Обрабатываем ссылку 846 / 4975...
# Обрабатываем ссылку 847 / 4975...
# Обрабатываем ссылку 848 / 4975...
# Обрабатываем ссылку 849 / 4975...
# Обрабатываем ссылку 850 / 4975...
# Обрабатываем ссылку 851 / 4975...
# Обрабатываем ссылку 852 / 4975...
# Обрабатываем ссылку 853 / 4975...
# Обрабатываем ссылку 854 / 4975...
# Обрабатываем ссылку 855 / 4975...
# Обрабатываем ссылку 856 / 4975...
# Обрабатываем ссылку 857 / 4975...
# Обрабатываем ссылку 858 / 4975...
# Обрабатываем ссылку 859 / 4975...
# Обрабатываем ссылку 860 / 4975...
# Обрабатываем ссылку 861 / 4975...
# Обрабатываем ссылку 862 / 4975...
# Обрабатываем ссылку 863 / 4975...
# Обрабатываем ссылку 864 / 4975...
# Обрабатываем ссылку 865 / 4975...
# Обрабатываем ссылку 866 / 4975...
# Обрабатываем ссылку 867 / 4975...
# Обрабатываем ссылку 868 / 4975...
# Обрабатываем ссылку 869 / 4975...
# Обрабатываем ссылку 870 / 4975...
# Обрабатываем ссылку 871 / 4975...
# Обрабатываем ссылку 872 / 4975...
# Обрабатываем ссылку 873 / 4975...
# Обрабатываем ссылку 874 / 4975...
# Обрабатываем ссылку 875 / 4975...
# Обрабатываем ссылку 876 / 4975...
# Обрабатываем ссылку 877 / 4975...
# Обрабатываем ссылку 878 / 4975...
# Обрабатываем ссылку 879 / 4975...
# Обрабатываем ссылку 880 / 4975...
# Обрабатываем ссылку 881 / 4975...
# Обрабатываем ссылку 882 / 4975...
# Обрабатываем ссылку 883 / 4975...
# Обрабатываем ссылку 884 / 4975...
# Обрабатываем ссылку 885 / 4975...
# Обрабатываем ссылку 886 / 4975...
# Обрабатываем ссылку 887 / 4975...
# Обрабатываем ссылку 888 / 4975...
# Обрабатываем ссылку 889 / 4975...
# Обрабатываем ссылку 890 / 4975...
# Обрабатываем ссылку 891 / 4975...
# Обрабатываем ссылку 892 / 4975...
# Обрабатываем ссылку 893 / 4975...
# Обрабатываем ссылку 894 / 4975...
# Обрабатываем ссылку 895 / 4975...
# Обрабатываем ссылку 896 / 4975...
# Обрабатываем ссылку 897 / 4975...
# Обрабатываем ссылку 898 / 4975...
# Обрабатываем ссылку 899 / 4975...
# Обрабатываем ссылку 900 / 4975...
# Обрабатываем ссылку 901 / 4975...
# Обрабатываем ссылку 902 / 4975...
# Обрабатываем ссылку 903 / 4975...
# Обрабатываем ссылку 904 / 4975...
# Обрабатываем ссылку 905 / 4975...
# Обрабатываем ссылку 906 / 4975...
# Обрабатываем ссылку 907 / 4975...
# Обрабатываем ссылку 908 / 4975...
# Обрабатываем ссылку 909 / 4975...
# Обрабатываем ссылку 910 / 4975...
# Обрабатываем ссылку 911 / 4975...
# Обрабатываем ссылку 912 / 4975...
# Обрабатываем ссылку 913 / 4975...
# Обрабатываем ссылку 914 / 4975...
# Обрабатываем ссылку 915 / 4975...
# Обрабатываем ссылку 916 / 4975...
# Обрабатываем ссылку 917 / 4975...
# Обрабатываем ссылку 918 / 4975...
# Обрабатываем ссылку 919 / 4975...
# Обрабатываем ссылку 920 / 4975...
# Обрабатываем ссылку 921 / 4975...
# Обрабатываем ссылку 922 / 4975...
# Обрабатываем ссылку 923 / 4975...
# Обрабатываем ссылку 924 / 4975...
# Обрабатываем ссылку 925 / 4975...
# Обрабатываем ссылку 926 / 4975...
# Обрабатываем ссылку 927 / 4975...
# Обрабатываем ссылку 928 / 4975...
# Обрабатываем ссылку 929 / 4975...
# Обрабатываем ссылку 930 / 4975...
# Обрабатываем ссылку 931 / 4975...
# Обрабатываем ссылку 932 / 4975...
# Обрабатываем ссылку 933 / 4975...
# Обрабатываем ссылку 934 / 4975...
# Обрабатываем ссылку 935 / 4975...
# Обрабатываем ссылку 936 / 4975...
# Обрабатываем ссылку 937 / 4975...
# Обрабатываем ссылку 938 / 4975...
# Обрабатываем ссылку 939 / 4975...
# Обрабатываем ссылку 940 / 4975...
# Обрабатываем ссылку 941 / 4975...
# Обрабатываем ссылку 942 / 4975...
# Обрабатываем ссылку 943 / 4975...
# Обрабатываем ссылку 944 / 4975...
# Обрабатываем ссылку 945 / 4975...
# Обрабатываем ссылку 946 / 4975...
# Обрабатываем ссылку 947 / 4975...
# Обрабатываем ссылку 948 / 4975...
# Обрабатываем ссылку 949 / 4975...
# Обрабатываем ссылку 950 / 4975...
# Обрабатываем ссылку 951 / 4975...
# Обрабатываем ссылку 952 / 4975...
# Обрабатываем ссылку 953 / 4975...
# Обрабатываем ссылку 954 / 4975...
# Обрабатываем ссылку 955 / 4975...
# Обрабатываем ссылку 956 / 4975...
# Обрабатываем ссылку 957 / 4975...
# Обрабатываем ссылку 958 / 4975...
# Обрабатываем ссылку 959 / 4975...
# Обрабатываем ссылку 960 / 4975...
# Обрабатываем ссылку 961 / 4975...
# Обрабатываем ссылку 962 / 4975...
# Обрабатываем ссылку 963 / 4975...
# Обрабатываем ссылку 964 / 4975...
# Обрабатываем ссылку 965 / 4975...
# Обрабатываем ссылку 966 / 4975...
# Обрабатываем ссылку 967 / 4975...
# Обрабатываем ссылку 968 / 4975...
# Обрабатываем ссылку 969 / 4975...
# Обрабатываем ссылку 970 / 4975...
# Обрабатываем ссылку 971 / 4975...
# Обрабатываем ссылку 972 / 4975...
# Обрабатываем ссылку 973 / 4975...
# Обрабатываем ссылку 974 / 4975...
# Обрабатываем ссылку 975 / 4975...
# Обрабатываем ссылку 976 / 4975...
# Обрабатываем ссылку 977 / 4975...
# Обрабатываем ссылку 978 / 4975...
# Обрабатываем ссылку 979 / 4975...
# Обрабатываем ссылку 980 / 4975...
# Обрабатываем ссылку 981 / 4975...
# Обрабатываем ссылку 982 / 4975...
# Обрабатываем ссылку 983 / 4975...
# Обрабатываем ссылку 984 / 4975...
# Обрабатываем ссылку 985 / 4975...
# Обрабатываем ссылку 986 / 4975...
# Обрабатываем ссылку 987 / 4975...
# Обрабатываем ссылку 988 / 4975...
# Обрабатываем ссылку 989 / 4975...
# Обрабатываем ссылку 990 / 4975...
# Обрабатываем ссылку 991 / 4975...
# Обрабатываем ссылку 992 / 4975...
# Обрабатываем ссылку 993 / 4975...
# Обрабатываем ссылку 994 / 4975...
# Обрабатываем ссылку 995 / 4975...
# Обрабатываем ссылку 996 / 4975...
# Обрабатываем ссылку 997 / 4975...
# Обрабатываем ссылку 998 / 4975...
# Обрабатываем ссылку 999 / 4975...
# Обрабатываем ссылку 1000 / 4975...
# Обрабатываем ссылку 1001 / 4975...
# Обрабатываем ссылку 1002 / 4975...
# Обрабатываем ссылку 1003 / 4975...
# Обрабатываем ссылку 1004 / 4975...
# Обрабатываем ссылку 1005 / 4975...
# Обрабатываем ссылку 1006 / 4975...
# Обрабатываем ссылку 1007 / 4975...
# Обрабатываем ссылку 1008 / 4975...
# Обрабатываем ссылку 1009 / 4975...
# Обрабатываем ссылку 1010 / 4975...
# Обрабатываем ссылку 1011 / 4975...
# Обрабатываем ссылку 1012 / 4975...
# Обрабатываем ссылку 1013 / 4975...
# Обрабатываем ссылку 1014 / 4975...
# Обрабатываем ссылку 1015 / 4975...
# Обрабатываем ссылку 1016 / 4975...
# Обрабатываем ссылку 1017 / 4975...
# Обрабатываем ссылку 1018 / 4975...
# Обрабатываем ссылку 1019 / 4975...
# Обрабатываем ссылку 1020 / 4975...
# Обрабатываем ссылку 1021 / 4975...
# Обрабатываем ссылку 1022 / 4975...
# Обрабатываем ссылку 1023 / 4975...
# Обрабатываем ссылку 1024 / 4975...
# Обрабатываем ссылку 1025 / 4975...
# Обрабатываем ссылку 1026 / 4975...
# Обрабатываем ссылку 1027 / 4975...
# Обрабатываем ссылку 1028 / 4975...
# Обрабатываем ссылку 1029 / 4975...
# Обрабатываем ссылку 1030 / 4975...
# Обрабатываем ссылку 1031 / 4975...
# Обрабатываем ссылку 1032 / 4975...
# Обрабатываем ссылку 1033 / 4975...
# Обрабатываем ссылку 1034 / 4975...
# Обрабатываем ссылку 1035 / 4975...
# Обрабатываем ссылку 1036 / 4975...
# Обрабатываем ссылку 1037 / 4975...
# Обрабатываем ссылку 1038 / 4975...
# Обрабатываем ссылку 1039 / 4975...
# Обрабатываем ссылку 1040 / 4975...
# Обрабатываем ссылку 1041 / 4975...
# Обрабатываем ссылку 1042 / 4975...
# Обрабатываем ссылку 1043 / 4975...
# Обрабатываем ссылку 1044 / 4975...
# Обрабатываем ссылку 1045 / 4975...
# Обрабатываем ссылку 1046 / 4975...
# Обрабатываем ссылку 1047 / 4975...
# Обрабатываем ссылку 1048 / 4975...
# Обрабатываем ссылку 1049 / 4975...
# Обрабатываем ссылку 1050 / 4975...
# Обрабатываем ссылку 1051 / 4975...
# Обрабатываем ссылку 1052 / 4975...
# Обрабатываем ссылку 1053 / 4975...
# Обрабатываем ссылку 1054 / 4975...
# Обрабатываем ссылку 1055 / 4975...
# Обрабатываем ссылку 1056 / 4975...
# Обрабатываем ссылку 1057 / 4975...
# Обрабатываем ссылку 1058 / 4975...
# Обрабатываем ссылку 1059 / 4975...
# Обрабатываем ссылку 1060 / 4975...
# Обрабатываем ссылку 1061 / 4975...
# Обрабатываем ссылку 1062 / 4975...
# Обрабатываем ссылку 1063 / 4975...
# Обрабатываем ссылку 1064 / 4975...
# Обрабатываем ссылку 1065 / 4975...
# Обрабатываем ссылку 1066 / 4975...
# Обрабатываем ссылку 1067 / 4975...
# Обрабатываем ссылку 1068 / 4975...
# Обрабатываем ссылку 1069 / 4975...
# Обрабатываем ссылку 1070 / 4975...
# Обрабатываем ссылку 1071 / 4975...
# Обрабатываем ссылку 1072 / 4975...
# Обрабатываем ссылку 1073 / 4975...
# Обрабатываем ссылку 1074 / 4975...
# Обрабатываем ссылку 1075 / 4975...
# Обрабатываем ссылку 1076 / 4975...
# Обрабатываем ссылку 1077 / 4975...
# Обрабатываем ссылку 1078 / 4975...
# Обрабатываем ссылку 1079 / 4975...
# Обрабатываем ссылку 1080 / 4975...
# Обрабатываем ссылку 1081 / 4975...
# Обрабатываем ссылку 1082 / 4975...
# Обрабатываем ссылку 1083 / 4975...
# Обрабатываем ссылку 1084 / 4975...
# Обрабатываем ссылку 1085 / 4975...
# Обрабатываем ссылку 1086 / 4975...
# Обрабатываем ссылку 1087 / 4975...
# Обрабатываем ссылку 1088 / 4975...
# Обрабатываем ссылку 1089 / 4975...
# Обрабатываем ссылку 1090 / 4975...
# Обрабатываем ссылку 1091 / 4975...
# Обрабатываем ссылку 1092 / 4975...
# Обрабатываем ссылку 1093 / 4975...
# Обрабатываем ссылку 1094 / 4975...
# Обрабатываем ссылку 1095 / 4975...
# Обрабатываем ссылку 1096 / 4975...
# Обрабатываем ссылку 1097 / 4975...
# Обрабатываем ссылку 1098 / 4975...
# Обрабатываем ссылку 1099 / 4975...
# Обрабатываем ссылку 1100 / 4975...
# Обрабатываем ссылку 1101 / 4975...
# Обрабатываем ссылку 1102 / 4975...
# Обрабатываем ссылку 1103 / 4975...
# Обрабатываем ссылку 1104 / 4975...
# Обрабатываем ссылку 1105 / 4975...
# Обрабатываем ссылку 1106 / 4975...
# Обрабатываем ссылку 1107 / 4975...
# Обрабатываем ссылку 1108 / 4975...
# Обрабатываем ссылку 1109 / 4975...
# Обрабатываем ссылку 1110 / 4975...
# Обрабатываем ссылку 1111 / 4975...
# Обрабатываем ссылку 1112 / 4975...
# Обрабатываем ссылку 1113 / 4975...
# Обрабатываем ссылку 1114 / 4975...
# Обрабатываем ссылку 1115 / 4975...
# Обрабатываем ссылку 1116 / 4975...
# Обрабатываем ссылку 1117 / 4975...
# Обрабатываем ссылку 1118 / 4975...
# Обрабатываем ссылку 1119 / 4975...
# Обрабатываем ссылку 1120 / 4975...
# Обрабатываем ссылку 1121 / 4975...
# Обрабатываем ссылку 1122 / 4975...
# Обрабатываем ссылку 1123 / 4975...
# Обрабатываем ссылку 1124 / 4975...
# Обрабатываем ссылку 1125 / 4975...
# Обрабатываем ссылку 1126 / 4975...
# Обрабатываем ссылку 1127 / 4975...
# Обрабатываем ссылку 1128 / 4975...
# Обрабатываем ссылку 1129 / 4975...
# Обрабатываем ссылку 1130 / 4975...
# Обрабатываем ссылку 1131 / 4975...
# Обрабатываем ссылку 1132 / 4975...
# Обрабатываем ссылку 1133 / 4975...
# Обрабатываем ссылку 1134 / 4975...
# Обрабатываем ссылку 1135 / 4975...
# Обрабатываем ссылку 1136 / 4975...
# Обрабатываем ссылку 1137 / 4975...
# Обрабатываем ссылку 1138 / 4975...
# Обрабатываем ссылку 1139 / 4975...
# Обрабатываем ссылку 1140 / 4975...
# Обрабатываем ссылку 1141 / 4975...
# Обрабатываем ссылку 1142 / 4975...
# Обрабатываем ссылку 1143 / 4975...
# Обрабатываем ссылку 1144 / 4975...
# Обрабатываем ссылку 1145 / 4975...
# Обрабатываем ссылку 1146 / 4975...
# Обрабатываем ссылку 1147 / 4975...
# Обрабатываем ссылку 1148 / 4975...
# Обрабатываем ссылку 1149 / 4975...
# Обрабатываем ссылку 1150 / 4975...
# Обрабатываем ссылку 1151 / 4975...
# Обрабатываем ссылку 1152 / 4975...
# Обрабатываем ссылку 1153 / 4975...
# Обрабатываем ссылку 1154 / 4975...
# Обрабатываем ссылку 1155 / 4975...
# Обрабатываем ссылку 1156 / 4975...
# Обрабатываем ссылку 1157 / 4975...
# Обрабатываем ссылку 1158 / 4975...
# Обрабатываем ссылку 1159 / 4975...
# Обрабатываем ссылку 1160 / 4975...
# Обрабатываем ссылку 1161 / 4975...
# Обрабатываем ссылку 1162 / 4975...
# Обрабатываем ссылку 1163 / 4975...
# Обрабатываем ссылку 1164 / 4975...
# Обрабатываем ссылку 1165 / 4975...
# Обрабатываем ссылку 1166 / 4975...
# Обрабатываем ссылку 1167 / 4975...
# Обрабатываем ссылку 1168 / 4975...
# Обрабатываем ссылку 1169 / 4975...
# Обрабатываем ссылку 1170 / 4975...
# Обрабатываем ссылку 1171 / 4975...
# Обрабатываем ссылку 1172 / 4975...
# Обрабатываем ссылку 1173 / 4975...
# Обрабатываем ссылку 1174 / 4975...
# Обрабатываем ссылку 1175 / 4975...
# Обрабатываем ссылку 1176 / 4975...
# Обрабатываем ссылку 1177 / 4975...
# Обрабатываем ссылку 1178 / 4975...
# Обрабатываем ссылку 1179 / 4975...
# Обрабатываем ссылку 1180 / 4975...
# Обрабатываем ссылку 1181 / 4975...
# Обрабатываем ссылку 1182 / 4975...
# Обрабатываем ссылку 1183 / 4975...
# Обрабатываем ссылку 1184 / 4975...
# Обрабатываем ссылку 1185 / 4975...
# Обрабатываем ссылку 1186 / 4975...
# Обрабатываем ссылку 1187 / 4975...
# Обрабатываем ссылку 1188 / 4975...
# Обрабатываем ссылку 1189 / 4975...
# Обрабатываем ссылку 1190 / 4975...
# Обрабатываем ссылку 1191 / 4975...
# Обрабатываем ссылку 1192 / 4975...
# Обрабатываем ссылку 1193 / 4975...
# Обрабатываем ссылку 1194 / 4975...
# Обрабатываем ссылку 1195 / 4975...
# Обрабатываем ссылку 1196 / 4975...
# Обрабатываем ссылку 1197 / 4975...
# Обрабатываем ссылку 1198 / 4975...
# Обрабатываем ссылку 1199 / 4975...
# Обрабатываем ссылку 1200 / 4975...
# Обрабатываем ссылку 1201 / 4975...
# Обрабатываем ссылку 1202 / 4975...
# Обрабатываем ссылку 1203 / 4975...
# Обрабатываем ссылку 1204 / 4975...
# Обрабатываем ссылку 1205 / 4975...
# Обрабатываем ссылку 1206 / 4975...
# Обрабатываем ссылку 1207 / 4975...
# Обрабатываем ссылку 1208 / 4975...
# Обрабатываем ссылку 1209 / 4975...
# Обрабатываем ссылку 1210 / 4975...
# Обрабатываем ссылку 1211 / 4975...
# Обрабатываем ссылку 1212 / 4975...
# Обрабатываем ссылку 1213 / 4975...
# Обрабатываем ссылку 1214 / 4975...
# Обрабатываем ссылку 1215 / 4975...
# Обрабатываем ссылку 1216 / 4975...
# Обрабатываем ссылку 1217 / 4975...
# Обрабатываем ссылку 1218 / 4975...
# Обрабатываем ссылку 1219 / 4975...
# Обрабатываем ссылку 1220 / 4975...
# Обрабатываем ссылку 1221 / 4975...
# Обрабатываем ссылку 1222 / 4975...
# Обрабатываем ссылку 1223 / 4975...
# Обрабатываем ссылку 1224 / 4975...
# Обрабатываем ссылку 1225 / 4975...
# Обрабатываем ссылку 1226 / 4975...
# Обрабатываем ссылку 1227 / 4975...
# Обрабатываем ссылку 1228 / 4975...
# Обрабатываем ссылку 1229 / 4975...
# Обрабатываем ссылку 1230 / 4975...
# Обрабатываем ссылку 1231 / 4975...
# Обрабатываем ссылку 1232 / 4975...
# Обрабатываем ссылку 1233 / 4975...
# Обрабатываем ссылку 1234 / 4975...
# Обрабатываем ссылку 1235 / 4975...
# Обрабатываем ссылку 1236 / 4975...
# Обрабатываем ссылку 1237 / 4975...
# Обрабатываем ссылку 1238 / 4975...
# Обрабатываем ссылку 1239 / 4975...
# Обрабатываем ссылку 1240 / 4975...
# Обрабатываем ссылку 1241 / 4975...
# Обрабатываем ссылку 1242 / 4975...
# Обрабатываем ссылку 1243 / 4975...
# Обрабатываем ссылку 1244 / 4975...
# Обрабатываем ссылку 1245 / 4975...
# Обрабатываем ссылку 1246 / 4975...
# Обрабатываем ссылку 1247 / 4975...
# Обрабатываем ссылку 1248 / 4975...
# Обрабатываем ссылку 1249 / 4975...
# Обрабатываем ссылку 1250 / 4975...
# Обрабатываем ссылку 1251 / 4975...
# Обрабатываем ссылку 1252 / 4975...
# Обрабатываем ссылку 1253 / 4975...
# Обрабатываем ссылку 1254 / 4975...
# Обрабатываем ссылку 1255 / 4975...
# Обрабатываем ссылку 1256 / 4975...
# Обрабатываем ссылку 1257 / 4975...
# Обрабатываем ссылку 1258 / 4975...
# Обрабатываем ссылку 1259 / 4975...
# Обрабатываем ссылку 1260 / 4975...
# Обрабатываем ссылку 1261 / 4975...
# Обрабатываем ссылку 1262 / 4975...
# Обрабатываем ссылку 1263 / 4975...
# Обрабатываем ссылку 1264 / 4975...
# Обрабатываем ссылку 1265 / 4975...
# Обрабатываем ссылку 1266 / 4975...
# Обрабатываем ссылку 1267 / 4975...
# Обрабатываем ссылку 1268 / 4975...
# Обрабатываем ссылку 1269 / 4975...
# Обрабатываем ссылку 1270 / 4975...
# Обрабатываем ссылку 1271 / 4975...
# Обрабатываем ссылку 1272 / 4975...
# Обрабатываем ссылку 1273 / 4975...
# Обрабатываем ссылку 1274 / 4975...
# Обрабатываем ссылку 1275 / 4975...
# Обрабатываем ссылку 1276 / 4975...
# Обрабатываем ссылку 1277 / 4975...
# Обрабатываем ссылку 1278 / 4975...
# Обрабатываем ссылку 1279 / 4975...
# Обрабатываем ссылку 1280 / 4975...
# Обрабатываем ссылку 1281 / 4975...
# Обрабатываем ссылку 1282 / 4975...
# Обрабатываем ссылку 1283 / 4975...
# Обрабатываем ссылку 1284 / 4975...
# Обрабатываем ссылку 1285 / 4975...
# Обрабатываем ссылку 1286 / 4975...
# Обрабатываем ссылку 1287 / 4975...
# Обрабатываем ссылку 1288 / 4975...
# Обрабатываем ссылку 1289 / 4975...
# Обрабатываем ссылку 1290 / 4975...
# Обрабатываем ссылку 1291 / 4975...
# Обрабатываем ссылку 1292 / 4975...
# Обрабатываем ссылку 1293 / 4975...
# Обрабатываем ссылку 1294 / 4975...
# Обрабатываем ссылку 1295 / 4975...
# Обрабатываем ссылку 1296 / 4975...
# Обрабатываем ссылку 1297 / 4975...
# Обрабатываем ссылку 1298 / 4975...
# Обрабатываем ссылку 1299 / 4975...
# Обрабатываем ссылку 1300 / 4975...
# Обрабатываем ссылку 1301 / 4975...
# Обрабатываем ссылку 1302 / 4975...
# Обрабатываем ссылку 1303 / 4975...
# Обрабатываем ссылку 1304 / 4975...
# Обрабатываем ссылку 1305 / 4975...
# Обрабатываем ссылку 1306 / 4975...
# Обрабатываем ссылку 1307 / 4975...
# Обрабатываем ссылку 1308 / 4975...
# Обрабатываем ссылку 1309 / 4975...
# Обрабатываем ссылку 1310 / 4975...
# Обрабатываем ссылку 1311 / 4975...
# Обрабатываем ссылку 1312 / 4975...
# Обрабатываем ссылку 1313 / 4975...
# Обрабатываем ссылку 1314 / 4975...
# Обрабатываем ссылку 1315 / 4975...
# Обрабатываем ссылку 1316 / 4975...
# Обрабатываем ссылку 1317 / 4975...
# Обрабатываем ссылку 1318 / 4975...
# Обрабатываем ссылку 1319 / 4975...
# Обрабатываем ссылку 1320 / 4975...
# Обрабатываем ссылку 1321 / 4975...
# Обрабатываем ссылку 1322 / 4975...
# Обрабатываем ссылку 1323 / 4975...
# Обрабатываем ссылку 1324 / 4975...
# Обрабатываем ссылку 1325 / 4975...
# Обрабатываем ссылку 1326 / 4975...
# Обрабатываем ссылку 1327 / 4975...
# Обрабатываем ссылку 1328 / 4975...
# Обрабатываем ссылку 1329 / 4975...
# Обрабатываем ссылку 1330 / 4975...
# Обрабатываем ссылку 1331 / 4975...
# Обрабатываем ссылку 1332 / 4975...
# Обрабатываем ссылку 1333 / 4975...
# Обрабатываем ссылку 1334 / 4975...
# Обрабатываем ссылку 1335 / 4975...
# Обрабатываем ссылку 1336 / 4975...
# Обрабатываем ссылку 1337 / 4975...
# Обрабатываем ссылку 1338 / 4975...
# Обрабатываем ссылку 1339 / 4975...
# Обрабатываем ссылку 1340 / 4975...
# Обрабатываем ссылку 1341 / 4975...
# Обрабатываем ссылку 1342 / 4975...
# Обрабатываем ссылку 1343 / 4975...
# Обрабатываем ссылку 1344 / 4975...
# Обрабатываем ссылку 1345 / 4975...
# Обрабатываем ссылку 1346 / 4975...
# Обрабатываем ссылку 1347 / 4975...
# Обрабатываем ссылку 1348 / 4975...
# Обрабатываем ссылку 1349 / 4975...
# Обрабатываем ссылку 1350 / 4975...
# Обрабатываем ссылку 1351 / 4975...
# Обрабатываем ссылку 1352 / 4975...
# Обрабатываем ссылку 1353 / 4975...
# Обрабатываем ссылку 1354 / 4975...
# Обрабатываем ссылку 1355 / 4975...
# Обрабатываем ссылку 1356 / 4975...
# Обрабатываем ссылку 1357 / 4975...
# Обрабатываем ссылку 1358 / 4975...
# Обрабатываем ссылку 1359 / 4975...
# Обрабатываем ссылку 1360 / 4975...
# Обрабатываем ссылку 1361 / 4975...
# Обрабатываем ссылку 1362 / 4975...
# Обрабатываем ссылку 1363 / 4975...
# Обрабатываем ссылку 1364 / 4975...
# Обрабатываем ссылку 1365 / 4975...
# Обрабатываем ссылку 1366 / 4975...
# Обрабатываем ссылку 1367 / 4975...
# Обрабатываем ссылку 1368 / 4975...
# Обрабатываем ссылку 1369 / 4975...
# Обрабатываем ссылку 1370 / 4975...
# Обрабатываем ссылку 1371 / 4975...
# Обрабатываем ссылку 1372 / 4975...
# Обрабатываем ссылку 1373 / 4975...
# Обрабатываем ссылку 1374 / 4975...
# Обрабатываем ссылку 1375 / 4975...
# Обрабатываем ссылку 1376 / 4975...
# Обрабатываем ссылку 1377 / 4975...
# Обрабатываем ссылку 1378 / 4975...
# Обрабатываем ссылку 1379 / 4975...
# Обрабатываем ссылку 1380 / 4975...
# Обрабатываем ссылку 1381 / 4975...
# Обрабатываем ссылку 1382 / 4975...
# Обрабатываем ссылку 1383 / 4975...
# Обрабатываем ссылку 1384 / 4975...
# Обрабатываем ссылку 1385 / 4975...
# Обрабатываем ссылку 1386 / 4975...
# Обрабатываем ссылку 1387 / 4975...
# Обрабатываем ссылку 1388 / 4975...
# Обрабатываем ссылку 1389 / 4975...
# Обрабатываем ссылку 1390 / 4975...
# Обрабатываем ссылку 1391 / 4975...
# Обрабатываем ссылку 1392 / 4975...
# Обрабатываем ссылку 1393 / 4975...
# Обрабатываем ссылку 1394 / 4975...
# Обрабатываем ссылку 1395 / 4975...
# Обрабатываем ссылку 1396 / 4975...
# Обрабатываем ссылку 1397 / 4975...
# Обрабатываем ссылку 1398 / 4975...
# Обрабатываем ссылку 1399 / 4975...
# Обрабатываем ссылку 1400 / 4975...
# Обрабатываем ссылку 1401 / 4975...
# Обрабатываем ссылку 1402 / 4975...
# Обрабатываем ссылку 1403 / 4975...
# Обрабатываем ссылку 1404 / 4975...
# Обрабатываем ссылку 1405 / 4975...
# Обрабатываем ссылку 1406 / 4975...
# Обрабатываем ссылку 1407 / 4975...
# Обрабатываем ссылку 1408 / 4975...
# Обрабатываем ссылку 1409 / 4975...
# Обрабатываем ссылку 1410 / 4975...
# Обрабатываем ссылку 1411 / 4975...
# Обрабатываем ссылку 1412 / 4975...
# ...
# Обрабатываем ссылку 4503 / 4975...
# Обрабатываем ссылку 4504 / 4975...
# Обрабатываем ссылку 4505 / 4975...
# Обрабатываем ссылку 4506 / 4975...
# Обрабатываем ссылку 4507 / 4975...
# Обрабатываем ссылку 4508 / 4975...
# Обрабатываем ссылку 4509 / 4975...
# Обрабатываем ссылку 4510 / 4975...
# Обрабатываем ссылку 4511 / 4975...
# Обрабатываем ссылку 4512 / 4975...
# Обрабатываем ссылку 4513 / 4975...
# Обрабатываем ссылку 4514 / 4975...
# Обрабатываем ссылку 4515 / 4975...
# Обрабатываем ссылку 4516 / 4975...
# Обрабатываем ссылку 4517 / 4975...
# Обрабатываем ссылку 4518 / 4975...
# Обрабатываем ссылку 4519 / 4975...
# Обрабатываем ссылку 4520 / 4975...
# Обрабатываем ссылку 4521 / 4975...
# Обрабатываем ссылку 4522 / 4975...
# Обрабатываем ссылку 4523 / 4975...
# Обрабатываем ссылку 4524 / 4975...
# Обрабатываем ссылку 4525 / 4975...
# Обрабатываем ссылку 4526 / 4975...
# Обрабатываем ссылку 4527 / 4975...
# Обрабатываем ссылку 4528 / 4975...
# Обрабатываем ссылку 4529 / 4975...
# Обрабатываем ссылку 4530 / 4975...
# Обрабатываем ссылку 4531 / 4975...
# Обрабатываем ссылку 4532 / 4975...
# Обрабатываем ссылку 4533 / 4975...
# Обрабатываем ссылку 4534 / 4975...
# Обрабатываем ссылку 4535 / 4975...
# Обрабатываем ссылку 4536 / 4975...
# Обрабатываем ссылку 4537 / 4975...
# Обрабатываем ссылку 4538 / 4975...
# Обрабатываем ссылку 4539 / 4975...
# Обрабатываем ссылку 4540 / 4975...
# Обрабатываем ссылку 4541 / 4975...
# Обрабатываем ссылку 4542 / 4975...
# Обрабатываем ссылку 4543 / 4975...
# Обрабатываем ссылку 4544 / 4975...
# Обрабатываем ссылку 4545 / 4975...
# Обрабатываем ссылку 4546 / 4975...
# Обрабатываем ссылку 4547 / 4975...
# Обрабатываем ссылку 4548 / 4975...
# Обрабатываем ссылку 4549 / 4975...
# Обрабатываем ссылку 4550 / 4975...
# Обрабатываем ссылку 4551 / 4975...
# Обрабатываем ссылку 4552 / 4975...
# Обрабатываем ссылку 4553 / 4975...
# Обрабатываем ссылку 4554 / 4975...
# Обрабатываем ссылку 4555 / 4975...
# Обрабатываем ссылку 4556 / 4975...
# Обрабатываем ссылку 4557 / 4975...
# Обрабатываем ссылку 4558 / 4975...
# Обрабатываем ссылку 4559 / 4975...
# Обрабатываем ссылку 4560 / 4975...
# Обрабатываем ссылку 4561 / 4975...
# Обрабатываем ссылку 4562 / 4975...
# Обрабатываем ссылку 4563 / 4975...
# Обрабатываем ссылку 4564 / 4975...
# Обрабатываем ссылку 4565 / 4975...
# Обрабатываем ссылку 4566 / 4975...
# Обрабатываем ссылку 4567 / 4975...
# Обрабатываем ссылку 4568 / 4975...
# Обрабатываем ссылку 4569 / 4975...
# Обрабатываем ссылку 4570 / 4975...
# Обрабатываем ссылку 4571 / 4975...
# Обрабатываем ссылку 4572 / 4975...
# Обрабатываем ссылку 4573 / 4975...
# Обрабатываем ссылку 4574 / 4975...
# Обрабатываем ссылку 4575 / 4975...
# Обрабатываем ссылку 4576 / 4975...
# Обрабатываем ссылку 4577 / 4975...
# Обрабатываем ссылку 4578 / 4975...
# Обрабатываем ссылку 4579 / 4975...
# Обрабатываем ссылку 4580 / 4975...
# Обрабатываем ссылку 4581 / 4975...
# Обрабатываем ссылку 4582 / 4975...
# Обрабатываем ссылку 4583 / 4975...
# Обрабатываем ссылку 4584 / 4975...
# Обрабатываем ссылку 4585 / 4975...
# Обрабатываем ссылку 4586 / 4975...
# Обрабатываем ссылку 4587 / 4975...
# Обрабатываем ссылку 4588 / 4975...
# Обрабатываем ссылку 4589 / 4975...
# Обрабатываем ссылку 4590 / 4975...
# Обрабатываем ссылку 4591 / 4975...
# Обрабатываем ссылку 4592 / 4975...
# Обрабатываем ссылку 4593 / 4975...
# Обрабатываем ссылку 4594 / 4975...
# Обрабатываем ссылку 4595 / 4975...
# Обрабатываем ссылку 4596 / 4975...
# Обрабатываем ссылку 4597 / 4975...
# Обрабатываем ссылку 4598 / 4975...
# Обрабатываем ссылку 4599 / 4975...
# Обрабатываем ссылку 4600 / 4975...
# Обрабатываем ссылку 4601 / 4975...
# Обрабатываем ссылку 4602 / 4975...
# Обрабатываем ссылку 4603 / 4975...
# Обрабатываем ссылку 4604 / 4975...
# Обрабатываем ссылку 4605 / 4975...
# Обрабатываем ссылку 4606 / 4975...
# Обрабатываем ссылку 4607 / 4975...
# Обрабатываем ссылку 4608 / 4975...
# Обрабатываем ссылку 4609 / 4975...
# Обрабатываем ссылку 4610 / 4975...
# Обрабатываем ссылку 4611 / 4975...
# Обрабатываем ссылку 4612 / 4975...
# Обрабатываем ссылку 4613 / 4975...
# Обрабатываем ссылку 4614 / 4975...
# Обрабатываем ссылку 4615 / 4975...
# Обрабатываем ссылку 4616 / 4975...
# Обрабатываем ссылку 4617 / 4975...
# Обрабатываем ссылку 4618 / 4975...
# Обрабатываем ссылку 4619 / 4975...
# Обрабатываем ссылку 4620 / 4975...
# Обрабатываем ссылку 4621 / 4975...
# Обрабатываем ссылку 4622 / 4975...
# Обрабатываем ссылку 4623 / 4975...
# Обрабатываем ссылку 4624 / 4975...
# Обрабатываем ссылку 4625 / 4975...
# Обрабатываем ссылку 4626 / 4975...
# Обрабатываем ссылку 4627 / 4975...
# Обрабатываем ссылку 4628 / 4975...
# Обрабатываем ссылку 4629 / 4975...
# Обрабатываем ссылку 4630 / 4975...
# Обрабатываем ссылку 4631 / 4975...
# Обрабатываем ссылку 4632 / 4975...
# Обрабатываем ссылку 4633 / 4975...
# Обрабатываем ссылку 4634 / 4975...
# Обрабатываем ссылку 4635 / 4975...
# Обрабатываем ссылку 4636 / 4975...
# Обрабатываем ссылку 4637 / 4975...
# Обрабатываем ссылку 4638 / 4975...
# Обрабатываем ссылку 4639 / 4975...
# Обрабатываем ссылку 4640 / 4975...
# Обрабатываем ссылку 4641 / 4975...
# Обрабатываем ссылку 4642 / 4975...
# Обрабатываем ссылку 4643 / 4975...
# Обрабатываем ссылку 4644 / 4975...
# Обрабатываем ссылку 4645 / 4975...
# Обрабатываем ссылку 4646 / 4975...
# Обрабатываем ссылку 4647 / 4975...
# Обрабатываем ссылку 4648 / 4975...
# Обрабатываем ссылку 4649 / 4975...
# Обрабатываем ссылку 4650 / 4975...
# Обрабатываем ссылку 4651 / 4975...
# Обрабатываем ссылку 4652 / 4975...
# Обрабатываем ссылку 4653 / 4975...
# Обрабатываем ссылку 4654 / 4975...
# Обрабатываем ссылку 4655 / 4975...
# Обрабатываем ссылку 4656 / 4975...
# Обрабатываем ссылку 4657 / 4975...
# Обрабатываем ссылку 4658 / 4975...
# Обрабатываем ссылку 4659 / 4975...
# Обрабатываем ссылку 4660 / 4975...
# Обрабатываем ссылку 4661 / 4975...
# Обрабатываем ссылку 4662 / 4975...
# Обрабатываем ссылку 4663 / 4975...
# Обрабатываем ссылку 4664 / 4975...
# Обрабатываем ссылку 4665 / 4975...
# Обрабатываем ссылку 4666 / 4975...
# Обрабатываем ссылку 4667 / 4975...
# Обрабатываем ссылку 4668 / 4975...
# Обрабатываем ссылку 4669 / 4975...
# Обрабатываем ссылку 4670 / 4975...
# Обрабатываем ссылку 4671 / 4975...
# Обрабатываем ссылку 4672 / 4975...
# Обрабатываем ссылку 4673 / 4975...
# Обрабатываем ссылку 4674 / 4975...
# Обрабатываем ссылку 4675 / 4975...
# Обрабатываем ссылку 4676 / 4975...
# Обрабатываем ссылку 4677 / 4975...
# Обрабатываем ссылку 4678 / 4975...
# Обрабатываем ссылку 4679 / 4975...
# Обрабатываем ссылку 4680 / 4975...
# Обрабатываем ссылку 4681 / 4975...
# Обрабатываем ссылку 4682 / 4975...
# Обрабатываем ссылку 4683 / 4975...
# Обрабатываем ссылку 4684 / 4975...
# Обрабатываем ссылку 4685 / 4975...
# Обрабатываем ссылку 4686 / 4975...
# Обрабатываем ссылку 4687 / 4975...
# Обрабатываем ссылку 4688 / 4975...
# Обрабатываем ссылку 4689 / 4975...
# Обрабатываем ссылку 4690 / 4975...
# Обрабатываем ссылку 4691 / 4975...
# Обрабатываем ссылку 4692 / 4975...
# Обрабатываем ссылку 4693 / 4975...
# Обрабатываем ссылку 4694 / 4975...
# Обрабатываем ссылку 4695 / 4975...
# Обрабатываем ссылку 4696 / 4975...
# Обрабатываем ссылку 4697 / 4975...
# Обрабатываем ссылку 4698 / 4975...
# Обрабатываем ссылку 4699 / 4975...
# Обрабатываем ссылку 4700 / 4975...
# Обрабатываем ссылку 4701 / 4975...
# Обрабатываем ссылку 4702 / 4975...
# Обрабатываем ссылку 4703 / 4975...
# Обрабатываем ссылку 4704 / 4975...
# Обрабатываем ссылку 4705 / 4975...
# Обрабатываем ссылку 4706 / 4975...
# Обрабатываем ссылку 4707 / 4975...
# Обрабатываем ссылку 4708 / 4975...
# Обрабатываем ссылку 4709 / 4975...
# Обрабатываем ссылку 4710 / 4975...
# Обрабатываем ссылку 4711 / 4975...
# Обрабатываем ссылку 4712 / 4975...
# Обрабатываем ссылку 4713 / 4975...
# Обрабатываем ссылку 4714 / 4975...
# Обрабатываем ссылку 4715 / 4975...
# Обрабатываем ссылку 4716 / 4975...
# Обрабатываем ссылку 4717 / 4975...
# Обрабатываем ссылку 4718 / 4975...
# Обрабатываем ссылку 4719 / 4975...
# Обрабатываем ссылку 4720 / 4975...
# Обрабатываем ссылку 4721 / 4975...
# Обрабатываем ссылку 4722 / 4975...
# Обрабатываем ссылку 4723 / 4975...
# Обрабатываем ссылку 4724 / 4975...
# Обрабатываем ссылку 4725 / 4975...
# Обрабатываем ссылку 4726 / 4975...
# Обрабатываем ссылку 4727 / 4975...
# Обрабатываем ссылку 4728 / 4975...
# Обрабатываем ссылку 4729 / 4975...
# Обрабатываем ссылку 4730 / 4975...
# Обрабатываем ссылку 4731 / 4975...
# Обрабатываем ссылку 4732 / 4975...
# Обрабатываем ссылку 4733 / 4975...
# Обрабатываем ссылку 4734 / 4975...
# Обрабатываем ссылку 4735 / 4975...
# Обрабатываем ссылку 4736 / 4975...
# Обрабатываем ссылку 4737 / 4975...
# Обрабатываем ссылку 4738 / 4975...
# Обрабатываем ссылку 4739 / 4975...
# Обрабатываем ссылку 4740 / 4975...
# Обрабатываем ссылку 4741 / 4975...
# Обрабатываем ссылку 4742 / 4975...
# Обрабатываем ссылку 4743 / 4975...
# Обрабатываем ссылку 4744 / 4975...
# Обрабатываем ссылку 4745 / 4975...
# Обрабатываем ссылку 4746 / 4975...
# Обрабатываем ссылку 4747 / 4975...
# Обрабатываем ссылку 4748 / 4975...
# Обрабатываем ссылку 4749 / 4975...
# Обрабатываем ссылку 4750 / 4975...
# Обрабатываем ссылку 4751 / 4975...
# Обрабатываем ссылку 4752 / 4975...
# Обрабатываем ссылку 4753 / 4975...
# Обрабатываем ссылку 4754 / 4975...
# Обрабатываем ссылку 4755 / 4975...
# Обрабатываем ссылку 4756 / 4975...
# Обрабатываем ссылку 4757 / 4975...
# Обрабатываем ссылку 4758 / 4975...
# Обрабатываем ссылку 4759 / 4975...
# Обрабатываем ссылку 4760 / 4975...
# Обрабатываем ссылку 4761 / 4975...
# Обрабатываем ссылку 4762 / 4975...
# Обрабатываем ссылку 4763 / 4975...
# Обрабатываем ссылку 4764 / 4975...
# Обрабатываем ссылку 4765 / 4975...
# Обрабатываем ссылку 4766 / 4975...
# Обрабатываем ссылку 4767 / 4975...
# Обрабатываем ссылку 4768 / 4975...
# Обрабатываем ссылку 4769 / 4975...
# Обрабатываем ссылку 4770 / 4975...
# Обрабатываем ссылку 4771 / 4975...
# Обрабатываем ссылку 4772 / 4975...
# Обрабатываем ссылку 4773 / 4975...
# Обрабатываем ссылку 4774 / 4975...
# Обрабатываем ссылку 4775 / 4975...
# Обрабатываем ссылку 4776 / 4975...
# Обрабатываем ссылку 4777 / 4975...
# Обрабатываем ссылку 4778 / 4975...
# Обрабатываем ссылку 4779 / 4975...
# Обрабатываем ссылку 4780 / 4975...
# Обрабатываем ссылку 4781 / 4975...
# Обрабатываем ссылку 4782 / 4975...
# Обрабатываем ссылку 4783 / 4975...
# Обрабатываем ссылку 4784 / 4975...
# Обрабатываем ссылку 4785 / 4975...
# Обрабатываем ссылку 4786 / 4975...
# Обрабатываем ссылку 4787 / 4975...
# Обрабатываем ссылку 4788 / 4975...
# Обрабатываем ссылку 4789 / 4975...
# Обрабатываем ссылку 4790 / 4975...
# Обрабатываем ссылку 4791 / 4975...
# Обрабатываем ссылку 4792 / 4975...
# Обрабатываем ссылку 4793 / 4975...
# Обрабатываем ссылку 4794 / 4975...
# Обрабатываем ссылку 4795 / 4975...
# Обрабатываем ссылку 4796 / 4975...
# Обрабатываем ссылку 4797 / 4975...
# Обрабатываем ссылку 4798 / 4975...
# Обрабатываем ссылку 4799 / 4975...
# Обрабатываем ссылку 4800 / 4975...
# Обрабатываем ссылку 4801 / 4975...
# Обрабатываем ссылку 4802 / 4975...
# Обрабатываем ссылку 4803 / 4975...
# Обрабатываем ссылку 4804 / 4975...
# Обрабатываем ссылку 4805 / 4975...
# Обрабатываем ссылку 4806 / 4975...
# Обрабатываем ссылку 4807 / 4975...
# Обрабатываем ссылку 4808 / 4975...
# Обрабатываем ссылку 4809 / 4975...
# Обрабатываем ссылку 4810 / 4975...
# Обрабатываем ссылку 4811 / 4975...
# Обрабатываем ссылку 4812 / 4975...
# Обрабатываем ссылку 4813 / 4975...
# Обрабатываем ссылку 4814 / 4975...
# Обрабатываем ссылку 4815 / 4975...
# Обрабатываем ссылку 4816 / 4975...
# Обрабатываем ссылку 4817 / 4975...
# Обрабатываем ссылку 4818 / 4975...
# Обрабатываем ссылку 4819 / 4975...
# Обрабатываем ссылку 4820 / 4975...
# Обрабатываем ссылку 4821 / 4975...
# Обрабатываем ссылку 4822 / 4975...
# Обрабатываем ссылку 4823 / 4975...
# Обрабатываем ссылку 4824 / 4975...
# Обрабатываем ссылку 4825 / 4975...
# Обрабатываем ссылку 4826 / 4975...
# Обрабатываем ссылку 4827 / 4975...
# Обрабатываем ссылку 4828 / 4975...
# Обрабатываем ссылку 4829 / 4975...
# Обрабатываем ссылку 4830 / 4975...
# Обрабатываем ссылку 4831 / 4975...
# Обрабатываем ссылку 4832 / 4975...
# Обрабатываем ссылку 4833 / 4975...
# Обрабатываем ссылку 4834 / 4975...
# Обрабатываем ссылку 4835 / 4975...
# Обрабатываем ссылку 4836 / 4975...
# Обрабатываем ссылку 4837 / 4975...
# Обрабатываем ссылку 4838 / 4975...
# Обрабатываем ссылку 4839 / 4975...
# Обрабатываем ссылку 4840 / 4975...
# Обрабатываем ссылку 4841 / 4975...
# Обрабатываем ссылку 4842 / 4975...
# Обрабатываем ссылку 4843 / 4975...
# Обрабатываем ссылку 4844 / 4975...
# Обрабатываем ссылку 4845 / 4975...
# Обрабатываем ссылку 4846 / 4975...
# Обрабатываем ссылку 4847 / 4975...
# Обрабатываем ссылку 4848 / 4975...
# Обрабатываем ссылку 4849 / 4975...
# Обрабатываем ссылку 4850 / 4975...
# Обрабатываем ссылку 4851 / 4975...
# Обрабатываем ссылку 4852 / 4975...
# Обрабатываем ссылку 4853 / 4975...
# Обрабатываем ссылку 4854 / 4975...
# Обрабатываем ссылку 4855 / 4975...
# Обрабатываем ссылку 4856 / 4975...
# Обрабатываем ссылку 4857 / 4975...
# Обрабатываем ссылку 4858 / 4975...
# Обрабатываем ссылку 4859 / 4975...
# Обрабатываем ссылку 4860 / 4975...
# Обрабатываем ссылку 4861 / 4975...
# Обрабатываем ссылку 4862 / 4975...
# Обрабатываем ссылку 4863 / 4975...
# Обрабатываем ссылку 4864 / 4975...
# Обрабатываем ссылку 4865 / 4975...
# Обрабатываем ссылку 4866 / 4975...
# Обрабатываем ссылку 4868 / 4975...
# Обрабатываем ссылку 4870 / 4975...
# Обрабатываем ссылку 4871 / 4975...
# Обрабатываем ссылку 4873 / 4975...
# Обрабатываем ссылку 4875 / 4975...
# Обрабатываем ссылку 4876 / 4975...
# Обрабатываем ссылку 4877 / 4975...
# Обрабатываем ссылку 4878 / 4975...
# Обрабатываем ссылку 4879 / 4975...
# Обрабатываем ссылку 4880 / 4975...
# Обрабатываем ссылку 4882 / 4975...
# Обрабатываем ссылку 4885 / 4975...
# Обрабатываем ссылку 4886 / 4975...
# Обрабатываем ссылку 4887 / 4975...
# Обрабатываем ссылку 4888 / 4975...
# Обрабатываем ссылку 4889 / 4975...
# Обрабатываем ссылку 4890 / 4975...
# Обрабатываем ссылку 4891 / 4975...
# Обрабатываем ссылку 4893 / 4975...
# Обрабатываем ссылку 4894 / 4975...
# Обрабатываем ссылку 4895 / 4975...
# Обрабатываем ссылку 4896 / 4975...
# Обрабатываем ссылку 4898 / 4975...
# Обрабатываем ссылку 4899 / 4975...
# Обрабатываем ссылку 4900 / 4975...
# Обрабатываем ссылку 4902 / 4975...
# Обрабатываем ссылку 4903 / 4975...
# Обрабатываем ссылку 4904 / 4975...
# Обрабатываем ссылку 4905 / 4975...
# Обрабатываем ссылку 4907 / 4975...
# Обрабатываем ссылку 4909 / 4975...
# Обрабатываем ссылку 4910 / 4975...
# Обрабатываем ссылку 4911 / 4975...
# Обрабатываем ссылку 4912 / 4975...
# Обрабатываем ссылку 4913 / 4975...
# Обрабатываем ссылку 4914 / 4975...
# Обрабатываем ссылку 4915 / 4975...
# Обрабатываем ссылку 4916 / 4975...
# Обрабатываем ссылку 4917 / 4975...
# Обрабатываем ссылку 4918 / 4975...
# Обрабатываем ссылку 4919 / 4975...
# Обрабатываем ссылку 4920 / 4975...
# Обрабатываем ссылку 4921 / 4975...
# Обрабатываем ссылку 4922 / 4975...
# Обрабатываем ссылку 4923 / 4975...
# Обрабатываем ссылку 4924 / 4975...
# Обрабатываем ссылку 4925 / 4975...
# Обрабатываем ссылку 4926 / 4975...
# Обрабатываем ссылку 4927 / 4975...
# Обрабатываем ссылку 4928 / 4975...
# Обрабатываем ссылку 4929 / 4975...
# Обрабатываем ссылку 4930 / 4975...
# Обрабатываем ссылку 4931 / 4975...
# Обрабатываем ссылку 4932 / 4975...
# Обрабатываем ссылку 4933 / 4975...
# Обрабатываем ссылку 4934 / 4975...
# Обрабатываем ссылку 4935 / 4975...
# Обрабатываем ссылку 4936 / 4975...
# Обрабатываем ссылку 4937 / 4975...
# Обрабатываем ссылку 4938 / 4975...
# Обрабатываем ссылку 4939 / 4975...
# Обрабатываем ссылку 4940 / 4975...
# Обрабатываем ссылку 4941 / 4975...
# Обрабатываем ссылку 4942 / 4975...
# Обрабатываем ссылку 4943 / 4975...
# Обрабатываем ссылку 4944 / 4975...
# Обрабатываем ссылку 4945 / 4975...
# Обрабатываем ссылку 4946 / 4975...
# Обрабатываем ссылку 4947 / 4975...
# Обрабатываем ссылку 4948 / 4975...
# Обрабатываем ссылку 4949 / 4975...
# Обрабатываем ссылку 4951 / 4975...
# Обрабатываем ссылку 4952 / 4975...
# Обрабатываем ссылку 4953 / 4975...
# Обрабатываем ссылку 4954 / 4975...
# Обрабатываем ссылку 4956 / 4975...
# Обрабатываем ссылку 4957 / 4975...
# Обрабатываем ссылку 4958 / 4975...
# Обрабатываем ссылку 4960 / 4975...
# Обрабатываем ссылку 4961 / 4975...
# Обрабатываем ссылку 4962 / 4975...
# Обрабатываем ссылку 4963 / 4975...
# Обрабатываем ссылку 4964 / 4975...
# Обрабатываем ссылку 4965 / 4975...
# Обрабатываем ссылку 4966 / 4975...
# Обрабатываем ссылку 4967 / 4975...
# Обрабатываем ссылку 4968 / 4975...
# Обрабатываем ссылку 4970 / 4975...
# Обрабатываем ссылку 4971 / 4975...
# Обрабатываем ссылку 4972 / 4975...
# Обрабатываем ссылку 4973 / 4975...
# Обрабатываем ссылку 4974 / 4975...
# Обрабатываем ссылку 4975 / 4975...

# %%
results_pos[:3]
# Out:
# [{'url': 'https://www.banki.ru/services/responses/bank/response/11747735/',
#   'text': ['\n\t30 июня был открыт накопительный счёт, процент за июнь не выплачен, ставка не отобразилась. Четкой прописанной ставки около счета в мобильном приложении нет. Пришлось узнавать через чат. Проценты за июль выплачены в размере 17 годовых. В августе    также четко процент накопительного счета не отобразился. В таблице процентов банка 17 процентов поменялись на 19. \r\n\r\nЛично я получила за август  вознаграждение по ставке 5 процентов, т.к. якобы это третий месяц вклада, приветственная ставка не применяется. Вопрос: почему четко не отображен процент счета в личном кабинете? Деньги можно было вывести под более удачный процент.Потерянная выгода в банке МТС. Последний день месяца засчитывается в приветственную ставку. Информации по счету достоверной нет, расплывчатая таблица процентов.\n'],
#   'date': '\n\t\t\t22.09.2024 17:28\n\t\t',
#   'city': ['Нижний Тагил (Свердловская область)'],
#   'bank_name': ['Администратор народного рейтинга', 'МТС Банк'],
#   'theme': '\n\t\tЗапутанный процент\n\t'},
#  {'url': 'https://www.banki.ru/services/responses/bank/response/11746786/',
#   'text': ['\n20.09.2024 я перевела со своего кошелька на "Финуслугах" 60000 рублей на свою кредитную карту в МТС-банке после чего с меня взяли комиссию 3000 руб ! Я написала об этом в чат МТС-банка, где мне ответили, что так как первод был осуществлен от юрлица, то по договору кредитной карты с меня взяли комиссию 5% от суммы. \r\n\r\nЯ об этом ничего не знала, иначе перевела бы деньги на свой счет в другом, нормальном, банке, который не берет комиссию за перевод собственных средств! Прочитала здесь в отзывах, что я не единственная, кто попал в такую ситуацию. Надеюсь, что мне вернут удержанную комиссию и в дальнейшем "Финуслуги" будут предупреждать какие банки берут деньги за вывод собственных средств!\n'],
#   'date': '\n\t\t\t21.09.2024 16:31\n\t\t',
#   'city': ['Москва'],
#   'bank_name': ['Администратор народного рейтинга', 'МТС Банк'],
#   'theme': '\n\t\tКомиссия за перевод с "Финуслуг"\n\t'},
#  {'url': 'https://www.banki.ru/services/responses/bank/response/11745617/',
#   'text': ['\nОбменивали валюту в отделении КАМКОМБАНКА на Комендантском пр 21. Найти отделение было легко, благодаря банки.ру нашли лучший курс в городе) зарезервировали сумму заранее, пришли, быстро все обменяли. Сотрудница приятная, доброжелательная, клиентоориентированая) все понравилось. Рекомендую данный банк и отделение\n'],
#   'date': '\n\t\t\t20.09.2024 15:45\n\t\t',
#   'city': ['Санкт-Петербург'],
#   'bank_name': ['Администратор народного рейтинга', 'КАМКОМБАНК'],
#   'theme': '\n\t\tОбмен валюты\n\t'}]

# %%
results_neg[:3]
# Out:
# [{'url': 'https://www.banki.ru/services/responses/bank/response/11748640/',
#   'text': ['\nПосле оплаты не пришло на почту письмо с ваучером. До техподдержки дозвониться не смог. Первый раз попробовал позвонить в субботу, но так как был выходной, не удивился, что свободных операторов не нашлось. Во второй раз сделал звонок в понедельник, сначала бот отправил ссылку на чат, которая в приложении не открылась (происходила ошибка). Позвонил во второй раз, попросил перевести на оператора, время ожидания было слишком долгим. Самостоятельно чат в приложении банка также не нашёл (в меню есть только пункт "Позвонить нам"). На сайте чат поддержки не работает, кнопка отправки не кликабельна.\n'],
#   'date': '\n\t\t\t23.09.2024 14:47\n\t\t',
#   'city': ['Калининград (Калининградская область)'],
#   'bank_name': ['МТС Банк', 'user-247419471967'],
#   'theme': '\n\t\tПроблема с оплатой chatGPT\n\t'},
#  {'url': 'https://www.banki.ru/services/responses/bank/response/11747156/',
#   'text': ['\nпрошла неделя, как курьер привëз мне дебетовую карту.. Но я так и не могу стать клиентом банка.. Карта не проходит активацию.. Звонки в банк бесполезны.. Жаль..\nне менее 300 символов?.. и что мне ещë написать?.. я всë сказал.. коротко и по существу.. наставлю точек.. 🤣\n'],
#   'date': '\n\t\t\t22.09.2024 04:10\n\t\t',
#   'city': ['Красноярск (Красноярский край)'],
#   'bank_name': ['Уралсиб', 'user4258044'],
#   'theme': '\n\t\tАктивация карты\n\t'},
#  {'url': 'https://www.banki.ru/services/responses/bank/response/11745363/',
#   'text': ['\nВ сервисе МТС деньги при переводе 150 рублей с баланса одного номера на другой выскочило окно :\nНужна проверка\nЗаметили подозрительную активность с этого устройства. Нужно убедиться, что ваши данные в безопасности: поможем по телефону 8 800 250-0-520 или в ближайшем отделении\nВ поддержке МТС банка после 20 минут дозвона грубо посылают в МТС, в поддержке МТС вежливо посылают в МТС банк.\nЧто за скотское отношение к клиентам !!!\nБуду направлять жалобы в надзорные.\n'],
#   'date': '\n\t\t\t20.09.2024 13:08\n\t\t',
#   'city': ['Усть-Лабинск (Краснодарский край)'],
#   'bank_name': ['МТС Банк', 'фридман'],
#   'theme': '\n\t\tНужна проверка. Заметили подозрительную активность с этого устройства. Нужно убедиться, что ваши данные в безопасности\n\t'}]

# %%
df_pos = pd.DataFrame(results_pos)

# %%
df_neg = pd.DataFrame(results_neg)

# %% [markdown]
#     Собранные данные очищаем с помощью регулярных выражений и на основе них формируем датафрейм.

# %%
import re  # Импортируем библиотеку регулярных выражений

# Определяем функцию для очистки текстового столбца
def clean_text_column(df, column_name):
    cleaned_text = []  # Создаем список для хранения очищенных текстов
    
    # Проходим по всем значениям в указанном столбце DataFrame
    for value in df[column_name]:  
        # Находим и объединяем все фрагменты текста, начинающиеся с буквы (русские) 
        string = ' '.join(re.findall(r'[А-Яа-я].+', str(value)))
        
        # Убираем лишние символы и форматы, оставляя только допустимые
        string = re.sub(r'\\r|\\n|[^А-Яа-я0-9\s.,\-–"]+', '', string)
        # Удаляем HTML-теги </p> из текста
        string = re.sub('</p>', '', string)
        
        # Добавляем очищенное значение в список
        cleaned_text.append(string)
    
    # Возвращаем список очищенных текстов
    return cleaned_text

# Применяем очистку текста к столбцу 'text' в DataFrame df_neg
df_neg['text'] = clean_text_column(df_neg, 'text')
# Применяем очистку текста к столбцу 'text' в DataFrame df_pos
df_pos['text'] = clean_text_column(df_pos, 'text')

# %%
def clean_text_column(df, column_name):
    cleaned_text = []    
    for value in df[column_name]:  
        string = ' '.join(re.findall(r'[А-Яа-я].+', str(value)))
        string = re.sub(r'\\r|\\n|[^А-Яа-я0-9\s.,\-–"]+', '', string)
        string = re.sub('</p>', '', string)
        
        cleaned_text.append(string)
    
    return cleaned_text

df_neg['text'] = clean_text_column(df_neg, 'text')
df_pos['text'] = clean_text_column(df_pos, 'text')

# %%
def clean_and_convert_dates(df, column_name):
    cleaned_dates = []
    
    for value in df[column_name]:  
        string = re.sub(r'\n\t\t\t|\n\t\t', '', str(value))
        
        try:
            date = pd.to_datetime(string, errors='coerce')  
        except Exception as e:
            date = pd.NaT  
            
        cleaned_dates.append(date)
    
    return cleaned_dates


df_neg['date'] = clean_and_convert_dates(df_neg, 'date')
df_pos['date'] = clean_and_convert_dates(df_pos, 'date')
# Out:
# C:\Users\js\AppData\Local\Temp\ipykernel_8996\54785669.py:8: UserWarning: Parsing dates in %d.%m.%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   date = pd.to_datetime(string, errors='coerce')

# %%
def clean_city_names(df, column_name):
    cleaned_cities = []

    for value in df[column_name]:
        string = re.sub(r"[\[\]\'\"]", '', str(value))
        cleaned_cities.append(string.strip())  # Удаляем лишние пробелы по краям

    return cleaned_cities

df_neg['city'] = clean_city_names(df_neg, 'city')
df_pos['city'] = clean_city_names(df_pos, 'city')

# %%
def extract_bank_names(row):
    value = row['bank_name']
    bank_names = []

    
    match = re.search(r'\[(.*?)\]', str(value))
    if match:
        bank_names_in_brackets = match.group(1)
        bank_parts = [name.strip() for name in bank_names_in_brackets.split(',')]

        
        if "Администратор" in bank_parts[0]:
            bank_names.append(bank_parts[1] if len(bank_parts) > 1 else None)
        else:
            bank_names.append(bank_parts[0])
    else:
        bank_names.append(None)  

    return bank_names[0]  


df_neg['bank_name'] = df_neg.apply(extract_bank_names, axis=1)
df_pos['bank_name'] = df_pos.apply(extract_bank_names, axis=1)

# %%
def clean_theme(df, column_name):
    cleaned_themes = []

    for value in df[column_name]:
        string = re.sub(r'\n\t\t|\n\t', '', str(value))
        cleaned_themes.append(string.strip()) 

    return cleaned_themes

df_neg['theme'] = clean_theme(df_neg, 'theme')
df_pos['theme'] = clean_theme(df_pos, 'theme')

# %%
df_neg.head(5)
# Out:
#                                                  url  \
# 0  https://www.banki.ru/services/responses/bank/r...
# 1  https://www.banki.ru/services/responses/bank/r...
# 2  https://www.banki.ru/services/responses/bank/r...
# 3  https://www.banki.ru/services/responses/bank/r...
# 4  https://www.banki.ru/services/responses/bank/r...
#
#                                                 text                date  \
# 0  После оплаты не пришло на почту письмо с вауче... 2024-09-23 14:47:00
# 1  прошла неделя, как курьер привз мне дебетовую ... 2024-09-22 04:10:00
# 2  В сервисе МТС деньги при переводе 150 рублей с... 2024-09-20 13:08:00
# 3  Пользоваться услугами банка МТС решать вам. Я ... 2024-09-20 09:09:00
# 4  Здравствуйте Являюсь, к сожалению, клиентом ба... 2024-09-19 20:42:00
#
#                                     city   bank_name  \
# 0  Калининград (Калининградская область)  'МТС Банк'
# 1         Красноярск (Красноярский край)   'Уралсиб'
# 2      Усть-Лабинск (Краснодарский край)  'МТС Банк'
# 3       Буденновск (Ставропольский край)  'МТС Банк'
# 4        Ульяновск (Ульяновская область)  'МТС Банк'
#
#                                                theme
# 0                         Проблема с оплатой chatGPT
# 1                                    Активация карты
# 2  Нужна проверка. Заметили подозрительную активн...
# 3         Моему возмущению нет предела! Часть первая
# 4  МТС банк - самый ужасный банк в моей жизни. Не...

# %%
def remove_quotes(df, column_name):
    df[column_name] = df[column_name].str.replace('"', '', regex=False).str.replace("'", '', regex=False)

df_neg['bank_name'] = remove_quotes(df_neg, 'bank_name')
df_pos['bank_name'] = remove_quotes(df_pos, 'bank_name')
df_neg.head(5)
# Out:
#                                                  url  \
# 0  https://www.banki.ru/services/responses/bank/r...
# 1  https://www.banki.ru/services/responses/bank/r...
# 2  https://www.banki.ru/services/responses/bank/r...
# 3  https://www.banki.ru/services/responses/bank/r...
# 4  https://www.banki.ru/services/responses/bank/r...
#
#                                                 text                date  \
# 0  После оплаты не пришло на почту письмо с вауче... 2024-09-23 14:47:00
# 1  прошла неделя, как курьер привз мне дебетовую ... 2024-09-22 04:10:00
# 2  В сервисе МТС деньги при переводе 150 рублей с... 2024-09-20 13:08:00
# 3  Пользоваться услугами банка МТС решать вам. Я ... 2024-09-20 09:09:00
# 4  Здравствуйте Являюсь, к сожалению, клиентом ба... 2024-09-19 20:42:00
#
#                                     city bank_name  \
# 0  Калининград (Калининградская область)      None
# 1         Красноярск (Красноярский край)      None
# 2      Усть-Лабинск (Краснодарский край)      None
# 3       Буденновск (Ставропольский край)      None
# 4        Ульяновск (Ульяновская область)      None
#
#                                                theme
# 0                         Проблема с оплатой chatGPT
# 1                                    Активация карты
# 2  Нужна проверка. Заметили подозрительную активн...
# 3         Моему возмущению нет предела! Часть первая
# 4  МТС банк - самый ужасный банк в моей жизни. Не...

# %%
df_pos['coloring'] = 'pos'
df_neg['coloring'] = 'neg'

combined_df = pd.concat([df_pos, df_neg], ignore_index=True)

combined_df = combined_df.sample(frac=1, random_state=1).reset_index(drop=True)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9903 entries, 0 to 9902
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        9903 non-null   object
#  1   text       9903 non-null   object
#  2   date       9903 non-null   datetime64[ns]
#  3   city       9903 non-null   object
#  4   bank_name  0 non-null      object
#  5   theme      9903 non-null   object
#  6   coloring   9903 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 541.7+ KB

# %%
combined_df = combined_df.drop_duplicates()

# %%
combined_df.to_csv('data.csv')
